# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
#!pip install spotipy

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config
config.client_secret
# Out:
# '70c9f746187d4b94976e58afcb88cf64'

# %% [markdown]
# import sys
# sys.path.insert(1, '/content/drive/MyDrive/Credentials/')
# from config import *

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= Client_ID,
                                                           client_secret= Client_Secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q='Yann Tiersen', limit=5)
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['album']
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#      'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#      'id': '7JG0QwvJRzPILHEW1xHEJj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#        'width': 64}],
#      'name': 'Amélie (Original Soundtrack)',
#      'release_date': '2001-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 140733,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR91U0100002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'},
#     'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu',
#     'id': '4O2N861eOnF9q8EtpH8IJu',
#     'is_local': False,
#     'name': "Comptine d'un autre été, l'après-midi",
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7ELV10HZC94beTCa9B7n6y'},
#      'href': 'https://api.spotify.com/v1/albums/7ELV10HZC94beTCa9B7n6y',
#      'id': '7ELV10HZC94beTCa9B7n6y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c2d418a5d9c48111f43277cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c2d418a5d9c48111f43277cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c2d418a5d9c48111f43277cc',
#        'width': 64}],
#      'name': 'Cascade Street',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:7ELV10HZC94beTCa9B7n6y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 95093,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR24Q9639001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6UKrqWqzDTCYBCH2OXAMC3'},
#     'href': 'https://api.spotify.com/v1/tracks/6UKrqWqzDTCYBCH2OXAMC3',
#     'id': '6UKrqWqzDTCYBCH2OXAMC3',
#     'is_local': False,
#     'name': "I've Never Been There",
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31ee0059fd7c4ce875f7b4ffadf7215fb6f7aed4?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6UKrqWqzDTCYBCH2OXAMC3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#      'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#      'id': '7JG0QwvJRzPILHEW1xHEJj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#        'width': 64}],
#      'name': 'Amélie (Original Soundtrack)',
#      'release_date': '2001-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 158666,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR91U0100008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78IQDW7yyMzJavHiWqfBWR'},
#     'href': 'https://api.spotify.com/v1/tracks/78IQDW7yyMzJavHiWqfBWR',
#     'id': '78IQDW7yyMzJavHiWqfBWR',
#     'is_local': False,
#     'name': "La Valse d'Amélie - Version piano",
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/407027c7a504b96b4c09e104b424685dcb207ce4?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:78IQDW7yyMzJavHiWqfBWR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2OoKSVqFm7YSQDzCKOhzP6'},
#      'href': 'https://api.spotify.com/v1/albums/2OoKSVqFm7YSQDzCKOhzP6',
#      'id': '2OoKSVqFm7YSQDzCKOhzP6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aaf21fc7a914ec2787c62f7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aaf21fc7a914ec2787c62f7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aaf21fc7a914ec2787c62f7b',
#        'width': 64}],
#      'name': 'The Lighthouse',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:2OoKSVqFm7YSQDzCKOhzP6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 123000,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR24Q9839032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/03fImIJ7r7he62QmwI1Tyv'},
#     'href': 'https://api.spotify.com/v1/tracks/03fImIJ7r7he62QmwI1Tyv',
#     'id': '03fImIJ7r7he62QmwI1Tyv',
#     'is_local': False,
#     'name': 'The Drowned Girl - Edit',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/77c3e50db4871d80c25f140047625a22872a2f1b?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:03fImIJ7r7he62QmwI1Tyv'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#        'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#        'id': '00sazWvoTLOqg5MFwC68Um',
#        'name': 'Yann Tiersen',
#        'type': 'artist',
#        'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#      'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#      'id': '7JG0QwvJRzPILHEW1xHEJj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#        'width': 64}],
#      'name': 'Amélie (Original Soundtrack)',
#      'release_date': '2001-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#       'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#       'id': '00sazWvoTLOqg5MFwC68Um',
#       'name': 'Yann Tiersen',
#       'type': 'artist',
#       'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 135906,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR91U0100001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5BvNtcjn0DRBabxN3VymRK'},
#     'href': 'https://api.spotify.com/v1/tracks/5BvNtcjn0DRBabxN3VymRK',
#     'id': '5BvNtcjn0DRBabxN3VymRK',
#     'is_local': False,
#     'name': "La Valse d'Amélie - Version originale",
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/02be80958333bcaf227a1e74b0c074b249d0af47?cid=0912c34e16c349f28a330c0eba3cc52f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5BvNtcjn0DRBabxN3VymRK'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 2238}}

# %% [markdown]
# {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['US'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#                                  'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#                                  'id': '7JG0QwvJRzPILHEW1xHEJj',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#                                              'width': 64}],
#                                  'name': 'Amélie (Original Soundtrack)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 25,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['US'],
#                        'disc_number': 1,
#                        'duration_ms': 140733,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100002'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'},
#                        'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu',
#                        'id': '4O2N861eOnF9q8EtpH8IJu',
#                        'is_local': False,
#                        'name': "Comptine d'un autre été, l'après-midi",
#                        'popularity': 56,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RU',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7ELV10HZC94beTCa9B7n6y'},
#                                  'href': 'https://api.spotify.com/v1/albums/7ELV10HZC94beTCa9B7n6y',
#                                  'id': '7ELV10HZC94beTCa9B7n6y',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273c2d418a5d9c48111f43277cc',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02c2d418a5d9c48111f43277cc',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851c2d418a5d9c48111f43277cc',
#                                              'width': 64}],
#                                  'name': 'Cascade Street',
#                                  'release_date': '1996',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 20,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7ELV10HZC94beTCa9B7n6y'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'AZ',
#                                              'BA',
#                                              'BB',
#                                              'BD',
#                                              'BE',
#                                              'BF',
#                                              'BG',
#                                              'BH',
#                                              'BI',
#                                              'BJ',
#                                              'BN',
#                                              'BO',
#                                              'BR',
#                                              'BS',
#                                              'BT',
#                                              'BW',
#                                              'BY',
#                                              'BZ',
#                                              'CA',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CV',
#                                              'CW',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DJ',
#                                              'DK',
#                                              'DM',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FJ',
#                                              'FM',
#                                              'FR',
#                                              'GA',
#                                              'GB',
#                                              'GD',
#                                              'GE',
#                                              'GH',
#                                              'GM',
#                                              'GN',
#                                              'GQ',
#                                              'GR',
#                                              'GT',
#                                              'GW',
#                                              'GY',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HT',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JM',
#                                              'JO',
#                                              'JP',
#                                              'KE',
#                                              'KG',
#                                              'KH',
#                                              'KI',
#                                              'KM',
#                                              'KN',
#                                              'KR',
#                                              'KW',
#                                              'KZ',
#                                              'LA',
#                                              'LB',
#                                              'LC',
#                                              'LI',
#                                              'LK',
#                                              'LR',
#                                              'LS',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MG',
#                                              'MH',
#                                              'MK',
#                                              'ML',
#                                              'MN',
#                                              'MO',
#                                              'MR',
#                                              'MT',
#                                              'MU',
#                                              'MV',
#                                              'MW',
#                                              'MX',
#                                              'MY',
#                                              'MZ',
#                                              'NA',
#                                              'NE',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NP',
#                                              'NR',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PG',
#                                              'PH',
#                                              'PK',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PW',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'RW',
#                                              'SA',
#                                              'SB',
#                                              'SC',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SL',
#                                              'SM',
#                                              'SN',
#                                              'SR',
#                                              'ST',
#                                              'SV',
#                                              'SZ',
#                                              'TD',
#                                              'TG',
#                                              'TH',
#                                              'TL',
#                                              'TN',
#                                              'TO',
#                                              'TR',
#                                              'TT',
#                                              'TV',
#                                              'TW',
#                                              'TZ',
#                                              'UA',
#                                              'UG',
#                                              'US',
#                                              'UY',
#                                              'UZ',
#                                              'VC',
#                                              'VN',
#                                              'VU',
#                                              'WS',
#                                              'XK',
#                                              'ZA',
#                                              'ZM',
#                                              'ZW'],
#                        'disc_number': 1,
#                        'duration_ms': 95093,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR24Q9639001'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6UKrqWqzDTCYBCH2OXAMC3'},
#                        'href': 'https://api.spotify.com/v1/tracks/6UKrqWqzDTCYBCH2OXAMC3',
#                        'id': '6UKrqWqzDTCYBCH2OXAMC3',
#                        'is_local': False,
#                        'name': "I've Never Been There",
#                        'popularity': 57,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/31ee0059fd7c4ce875f7b4ffadf7215fb6f7aed4?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:6UKrqWqzDTCYBCH2OXAMC3'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['US'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#                                  'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#                                  'id': '7JG0QwvJRzPILHEW1xHEJj',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#                                              'width': 64}],
#                                  'name': 'Amélie (Original Soundtrack)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 25,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['US'],
#                        'disc_number': 1,
#                        'duration_ms': 158666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100008'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/78IQDW7yyMzJavHiWqfBWR'},
#                        'href': 'https://api.spotify.com/v1/tracks/78IQDW7yyMzJavHiWqfBWR',
#                        'id': '78IQDW7yyMzJavHiWqfBWR',
#                        'is_local': False,
#                        'name': "La Valse d'Amélie - Version piano",
#                        'popularity': 45,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/407027c7a504b96b4c09e104b424685dcb207ce4?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 19,
#                        'type': 'track',
#                        'uri': 'spotify:track:78IQDW7yyMzJavHiWqfBWR'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AG',
#                                                        'AL',
#                                                        'AM',
#                                                        'AO',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
#                                                        'AZ',
#                                                        'BA',
#                                                        'BB',
#                                                        'BD',
#                                                        'BE',
#                                                        'BF',
#                                                        'BG',
#                                                        'BH',
#                                                        'BI',
#                                                        'BJ',
#                                                        'BN',
#                                                        'BO',
#                                                        'BR',
#                                                        'BS',
#                                                        'BT',
#                                                        'BW',
#                                                        'BY',
#                                                        'BZ',
#                                                        'CA',
#                                                        'CH',
#                                                        'CI',
#                                                        'CL',
#                                                        'CM',
#                                                        'CO',
#                                                        'CR',
#                                                        'CV',
#                                                        'CW',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DE',
#                                                        'DJ',
#                                                        'DK',
#                                                        'DM',
#                                                        'DO',
#                                                        'DZ',
#                                                        'EC',
#                                                        'EE',
#                                                        'EG',
#                                                        'ES',
#                                                        'FI',
#                                                        'FJ',
#                                                        'FM',
#                                                        'FR',
#                                                        'GA',
#                                                        'GB',
#                                                        'GD',
#                                                        'GE',
#                                                        'GH',
#                                                        'GM',
#                                                        'GN',
#                                                        'GQ',
#                                                        'GR',
#                                                        'GT',
#                                                        'GW',
#                                                        'GY',
#                                                        'HK',
#                                                        'HN',
#                                                        'HR',
#                                                        'HT',
#                                                        'HU',
#                                                        'ID',
#                                                        'IE',
#                                                        'IL',
#                                                        'IN',
#                                                        'IS',
#                                                        'IT',
#                                                        'JM',
#                                                        'JO',
#                                                        'JP',
#                                                        'KE',
#                                                        'KG',
#                                                        'KH',
#                                                        'KI',
#                                                        'KM',
#                                                        'KN',
#                                                        'KR',
#                                                        'KW',
#                                                        'KZ',
#                                                        'LA',
#                                                        'LB',
#                                                        'LC',
#                                                        'LI',
#                                                        'LK',
#                                                        'LR',
#                                                        'LS',
#                                                        'LT',
#                                                        'LU',
#                                                        'LV',
#                                                        'MA',
#                                                        'MC',
#                                                        'MD',
#                                                        'ME',
#                                                        'MG',
#                                                        'MH',
#                                                        'MK',
#                                                        'ML',
#                                                        'MN',
#                                                        'MO',
#                                                        'MR',
#                                                        'MT',
#                                                        'MU',
#                                                        'MV',
#                                                        'MW',
#                                                        'MX',
#                                                        'MY',
#                                                        'MZ',
#                                                        'NA',
#                                                        'NE',
#                                                        'NG',
#                                                        'NI',
#                                                        'NL',
#                                                        'NO',
#                                                        'NP',
#                                                        'NR',
#                                                        'NZ',
#                                                        'OM',
#                                                        'PA',
#                                                        'PE',
#                                                        'PG',
#                                                        'PH',
#                                                        'PK',
#                                                        'PL',
#                                                        'PS',
#                                                        'PT',
#                                                        'PW',
#                                                        'PY',
#                                                        'QA',
#                                                        'RO',
#                                                        'RS',
#                                                        'RU',
#                                                        'RW',
#                                                        'SA',
#                                                        'SB',
#                                                        'SC',
#                                                        'SE',
#                                                        'SG',
#                                                        'SI',
#                                                        'SK',
#                                                        'SL',
#                                                        'SM',
#                                                        'SN',
#                                                        'SR',
#                                                        'ST',
#                                                        'SV',
#                                                        'SZ',
#                                                        'TD',
#                                                        'TG',
#                                                        'TH',
#                                                        'TL',
#                                                        'TN',
#                                                        'TO',
#                                                        'TR',
#                                                        'TT',
#                                                        'TV',
#                                                        'TW',
#                                                        'TZ',
#                                                        'UA',
#                                                        'UG',
#                                                        'US',
#                                                        'UY',
#                                                        'UZ',
#                                                        'VC',
#                                                        'VN',
#                                                        'VU',
#                                                        'WS',
#                                                        'XK',
#                                                        'ZA',
#                                                        'ZM',
#                                                        'ZW'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2OoKSVqFm7YSQDzCKOhzP6'},
#                                  'href': 'https://api.spotify.com/v1/albums/2OoKSVqFm7YSQDzCKOhzP6',
#                                  'id': '2OoKSVqFm7YSQDzCKOhzP6',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273aaf21fc7a914ec2787c62f7b',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02aaf21fc7a914ec2787c62f7b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851aaf21fc7a914ec2787c62f7b',
#                                              'width': 64}],
#                                  'name': 'The Lighthouse',
#                                  'release_date': '1998',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 2,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2OoKSVqFm7YSQDzCKOhzP6'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
#                                              'AR',
#                                              'AT',
#                                              'AU',
#                                              'AZ',
#                                              'BA',
#                                              'BB',
#                                              'BD',
#                                              'BE',
#                                              'BF',
#                                              'BG',
#                                              'BH',
#                                              'BI',
#                                              'BJ',
#                                              'BN',
#                                              'BO',
#                                              'BR',
#                                              'BS',
#                                              'BT',
#                                              'BW',
#                                              'BY',
#                                              'BZ',
#                                              'CA',
#                                              'CH',
#                                              'CI',
#                                              'CL',
#                                              'CM',
#                                              'CO',
#                                              'CR',
#                                              'CV',
#                                              'CW',
#                                              'CY',
#                                              'CZ',
#                                              'DE',
#                                              'DJ',
#                                              'DK',
#                                              'DM',
#                                              'DO',
#                                              'DZ',
#                                              'EC',
#                                              'EE',
#                                              'EG',
#                                              'ES',
#                                              'FI',
#                                              'FJ',
#                                              'FM',
#                                              'FR',
#                                              'GA',
#                                              'GB',
#                                              'GD',
#                                              'GE',
#                                              'GH',
#                                              'GM',
#                                              'GN',
#                                              'GQ',
#                                              'GR',
#                                              'GT',
#                                              'GW',
#                                              'GY',
#                                              'HK',
#                                              'HN',
#                                              'HR',
#                                              'HT',
#                                              'HU',
#                                              'ID',
#                                              'IE',
#                                              'IL',
#                                              'IN',
#                                              'IS',
#                                              'IT',
#                                              'JM',
#                                              'JO',
#                                              'JP',
#                                              'KE',
#                                              'KG',
#                                              'KH',
#                                              'KI',
#                                              'KM',
#                                              'KN',
#                                              'KR',
#                                              'KW',
#                                              'KZ',
#                                              'LA',
#                                              'LB',
#                                              'LC',
#                                              'LI',
#                                              'LK',
#                                              'LR',
#                                              'LS',
#                                              'LT',
#                                              'LU',
#                                              'LV',
#                                              'MA',
#                                              'MC',
#                                              'MD',
#                                              'ME',
#                                              'MG',
#                                              'MH',
#                                              'MK',
#                                              'ML',
#                                              'MN',
#                                              'MO',
#                                              'MR',
#                                              'MT',
#                                              'MU',
#                                              'MV',
#                                              'MW',
#                                              'MX',
#                                              'MY',
#                                              'MZ',
#                                              'NA',
#                                              'NE',
#                                              'NG',
#                                              'NI',
#                                              'NL',
#                                              'NO',
#                                              'NP',
#                                              'NR',
#                                              'NZ',
#                                              'OM',
#                                              'PA',
#                                              'PE',
#                                              'PG',
#                                              'PH',
#                                              'PK',
#                                              'PL',
#                                              'PS',
#                                              'PT',
#                                              'PW',
#                                              'PY',
#                                              'QA',
#                                              'RO',
#                                              'RS',
#                                              'RU',
#                                              'RW',
#                                              'SA',
#                                              'SB',
#                                              'SC',
#                                              'SE',
#                                              'SG',
#                                              'SI',
#                                              'SK',
#                                              'SL',
#                                              'SM',
#                                              'SN',
#                                              'SR',
#                                              'ST',
#                                              'SV',
#                                              'SZ',
#                                              'TD',
#                                              'TG',
#                                              'TH',
#                                              'TL',
#                                              'TN',
#                                              'TO',
#                                              'TR',
#                                              'TT',
#                                              'TV',
#                                              'TW',
#                                              'TZ',
#                                              'UA',
#                                              'UG',
#                                              'US',
#                                              'UY',
#                                              'UZ',
#                                              'VC',
#                                              'VN',
#                                              'VU',
#                                              'WS',
#                                              'XK',
#                                              'ZA',
#                                              'ZM',
#                                              'ZW'],
#                        'disc_number': 1,
#                        'duration_ms': 123000,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR24Q9839032'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/03fImIJ7r7he62QmwI1Tyv'},
#                        'href': 'https://api.spotify.com/v1/tracks/03fImIJ7r7he62QmwI1Tyv',
#                        'id': '03fImIJ7r7he62QmwI1Tyv',
#                        'is_local': False,
#                        'name': 'The Drowned Girl - Edit',
#                        'popularity': 54,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/77c3e50db4871d80c25f140047625a22872a2f1b?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:03fImIJ7r7he62QmwI1Tyv'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                               'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                               'id': '00sazWvoTLOqg5MFwC68Um',
#                                               'name': 'Yann Tiersen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                                  'available_markets': ['US'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#                                  'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#                                  'id': '7JG0QwvJRzPILHEW1xHEJj',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#                                              'width': 64}],
#                                  'name': 'Amélie (Original Soundtrack)',
#                                  'release_date': '2001-04-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 25,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#                                     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#                                     'id': '00sazWvoTLOqg5MFwC68Um',
#                                     'name': 'Yann Tiersen',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#                        'available_markets': ['US'],
#                        'disc_number': 1,
#                        'duration_ms': 135906,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'FR91U0100001'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5BvNtcjn0DRBabxN3VymRK'},
#                        'href': 'https://api.spotify.com/v1/tracks/5BvNtcjn0DRBabxN3VymRK',
#                        'id': '5BvNtcjn0DRBabxN3VymRK',
#                        'is_local': False,
#                        'name': "La Valse d'Amélie - Version originale",
#                        'popularity': 40,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/02be80958333bcaf227a1e74b0c074b249d0af47?cid=0912c34e16c349f28a330c0eba3cc52f',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:5BvNtcjn0DRBabxN3VymRK'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 2238}}

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#    'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#    'id': '7JG0QwvJRzPILHEW1xHEJj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#      'width': 64}],
#    'name': 'Amélie (Original Soundtrack)',
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 140733,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100002'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'},
#   'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu',
#   'id': '4O2N861eOnF9q8EtpH8IJu',
#   'is_local': False,
#   'name': "Comptine d'un autre été, l'après-midi",
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7ELV10HZC94beTCa9B7n6y'},
#    'href': 'https://api.spotify.com/v1/albums/7ELV10HZC94beTCa9B7n6y',
#    'id': '7ELV10HZC94beTCa9B7n6y',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c2d418a5d9c48111f43277cc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c2d418a5d9c48111f43277cc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c2d418a5d9c48111f43277cc',
#      'width': 64}],
#    'name': 'Cascade Street',
#    'release_date': '1996',
#    'release_date_precision': 'year',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:7ELV10HZC94beTCa9B7n6y'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 95093,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR24Q9639001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6UKrqWqzDTCYBCH2OXAMC3'},
#   'href': 'https://api.spotify.com/v1/tracks/6UKrqWqzDTCYBCH2OXAMC3',
#   'id': '6UKrqWqzDTCYBCH2OXAMC3',
#   'is_local': False,
#   'name': "I've Never Been There",
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/31ee0059fd7c4ce875f7b4ffadf7215fb6f7aed4?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6UKrqWqzDTCYBCH2OXAMC3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#    'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#    'id': '7JG0QwvJRzPILHEW1xHEJj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#      'width': 64}],
#    'name': 'Amélie (Original Soundtrack)',
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 158666,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100008'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/78IQDW7yyMzJavHiWqfBWR'},
#   'href': 'https://api.spotify.com/v1/tracks/78IQDW7yyMzJavHiWqfBWR',
#   'id': '78IQDW7yyMzJavHiWqfBWR',
#   'is_local': False,
#   'name': "La Valse d'Amélie - Version piano",
#   'popularity': 45,
#   'preview_url': 'https://p.scdn.co/mp3-preview/407027c7a504b96b4c09e104b424685dcb207ce4?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 19,
#   'type': 'track',
#   'uri': 'spotify:track:78IQDW7yyMzJavHiWqfBWR'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2OoKSVqFm7YSQDzCKOhzP6'},
#    'href': 'https://api.spotify.com/v1/albums/2OoKSVqFm7YSQDzCKOhzP6',
#    'id': '2OoKSVqFm7YSQDzCKOhzP6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273aaf21fc7a914ec2787c62f7b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02aaf21fc7a914ec2787c62f7b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851aaf21fc7a914ec2787c62f7b',
#      'width': 64}],
#    'name': 'The Lighthouse',
#    'release_date': '1998',
#    'release_date_precision': 'year',
#    'total_tracks': 2,
#    'type': 'album',
#    'uri': 'spotify:album:2OoKSVqFm7YSQDzCKOhzP6'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 123000,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR24Q9839032'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/03fImIJ7r7he62QmwI1Tyv'},
#   'href': 'https://api.spotify.com/v1/tracks/03fImIJ7r7he62QmwI1Tyv',
#   'id': '03fImIJ7r7he62QmwI1Tyv',
#   'is_local': False,
#   'name': 'The Drowned Girl - Edit',
#   'popularity': 54,
#   'preview_url': 'https://p.scdn.co/mp3-preview/77c3e50db4871d80c25f140047625a22872a2f1b?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:03fImIJ7r7he62QmwI1Tyv'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#      'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#      'id': '00sazWvoTLOqg5MFwC68Um',
#      'name': 'Yann Tiersen',
#      'type': 'artist',
#      'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#    'available_markets': ['US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#    'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#    'id': '7JG0QwvJRzPILHEW1xHEJj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#      'width': 64}],
#    'name': 'Amélie (Original Soundtrack)',
#    'release_date': '2001-04-23',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 135906,
#   'explicit': False,
#   'external_ids': {'isrc': 'FR91U0100001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5BvNtcjn0DRBabxN3VymRK'},
#   'href': 'https://api.spotify.com/v1/tracks/5BvNtcjn0DRBabxN3VymRK',
#   'id': '5BvNtcjn0DRBabxN3VymRK',
#   'is_local': False,
#   'name': "La Valse d'Amélie - Version originale",
#   'popularity': 40,
#   'preview_url': 'https://p.scdn.co/mp3-preview/02be80958333bcaf227a1e74b0c074b249d0af47?cid=0912c34e16c349f28a330c0eba3cc52f',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:5BvNtcjn0DRBabxN3VymRK'}]

# %%
len(results['tracks']['items'])
# Out:
# 5

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#     'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#     'id': '00sazWvoTLOqg5MFwC68Um',
#     'name': 'Yann Tiersen',
#     'type': 'artist',
#     'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#   'available_markets': ['US'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'},
#   'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj',
#   'id': '7JG0QwvJRzPILHEW1xHEJj',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b',
#     'width': 64}],
#   'name': 'Amélie (Original Soundtrack)',
#   'release_date': '2001-04-23',
#   'release_date_precision': 'day',
#   'total_tracks': 25,
#   'type': 'album',
#   'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'},
#    'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um',
#    'id': '00sazWvoTLOqg5MFwC68Um',
#    'name': 'Yann Tiersen',
#    'type': 'artist',
#    'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}],
#  'available_markets': ['US'],
#  'disc_number': 1,
#  'duration_ms': 140733,
#  'explicit': False,
#  'external_ids': {'isrc': 'FR91U0100002'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'},
#  'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu',
#  'id': '4O2N861eOnF9q8EtpH8IJu',
#  'is_local': False,
#  'name': "Comptine d'un autre été, l'après-midi",
#  'popularity': 56,
#  'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f',
#  'track_number': 4,
#  'type': 'track',
#  'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['id']
# Out:
# '4O2N861eOnF9q8EtpH8IJu'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['external_urls']['spotify']))
# Out:
# The name of song is: 'Comptine d'un autre été, l'après-midi' and the id is: https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu
# The name of song is: 'I've Never Been There' and the id is: https://open.spotify.com/track/6UKrqWqzDTCYBCH2OXAMC3
# The name of song is: 'La Valse d'Amélie - Version piano' and the id is: https://open.spotify.com/track/78IQDW7yyMzJavHiWqfBWR
# The name of song is: 'The Drowned Girl - Edit' and the id is: https://open.spotify.com/track/03fImIJ7r7he62QmwI1Tyv
# The name of song is: 'La Valse d'Amélie - Version originale' and the id is: https://open.spotify.com/track/5BvNtcjn0DRBabxN3VymRK

# %%
song["tracks"]["items"][0]['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-78319a80a2ce> in <module>()
# ----> 1 song["tracks"]["items"][0]['name']
#
# NameError: name 'song' is not defined

# %%
import pandas as pd

song = sp.search(q="comptine d'un autre été", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

print(my_dict)
my_dict_new = { key: [my_dict[key]] for key in list(my_dict.keys()) }
#my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)
# Out:
# {'danceability': 0.484, 'energy': 0.192, 'key': 2, 'loudness': -15.378, 'mode': 1, 'speechiness': 0.0465, 'acousticness': 0.991, 'instrumentalness': 0.908, 'liveness': 0.106, 'valence': 0.0559, 'tempo': 100.084, 'type': 'audio_features', 'id': '4O2N861eOnF9q8EtpH8IJu', 'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu', 'track_href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4O2N861eOnF9q8EtpH8IJu', 'duration_ms': 140733, 'time_signature': 4}
# {'danceability': [0.484], 'energy': [0.192], 'key': [2], 'loudness': [-15.378], 'mode': [1], 'speechiness': [0.0465], 'acousticness': [0.991], 'instrumentalness': [0.908], 'liveness': [0.106], 'valence': [0.0559], 'tempo': [100.084], 'type': ['audio_features'], 'id': ['4O2N861eOnF9q8EtpH8IJu'], 'uri': ['spotify:track:4O2N861eOnF9q8EtpH8IJu'], 'track_href': ['https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/4O2N861eOnF9q8EtpH8IJu'], 'duration_ms': [140733], 'time_signature': [4]}
#    danceability  energy  ...  duration_ms  time_signature
# 0         0.484   0.192  ...       140733               4
#
# [1 rows x 18 columns]

# %% [markdown]
# Let's search for songs of several artists

# %%
my_artists = ['Placebo','Marylin Manson','Janis Joplin']

my_dict = {}
#for artist in my_artists:
#    #result = sp.search(q=artist, limit= 50)
#    my_dict[artist] = sp.search(q=artist, limit= 50)

my_dict = {artist: sp.search(q=artist, limit= 50) for artist in my_artists}
#my_dict
my_dict.keys()
# Out:
# dict_keys(['Placebo', 'Marylin Manson', 'Janis Joplin'])

# %%
len(my_dict['Janis Joplin']['tracks']['items'])
# Out:
# 50

# %%
type(my_dict['Janis Joplin']['tracks']['items'][0])
# Out:
# dict

# %%
my_dict['Janis Joplin']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you can cosider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['US'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'}, 'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj', 'id': '7JG0QwvJRzPILHEW1xHEJj', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b', 'width': 64}], 'name': 'Amélie (Original Soundtrack)', 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 25, 'type': 'album', 'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['US'], 'disc_number': 1, 'duration_ms': 140733, 'explicit': False, 'external_ids': {'isrc': 'FR91U0100002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}, 'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu', 'id': '4O2N861eOnF9q8EtpH8IJu', 'is_local': False, 'name': "Comptine d'un autre été, l'après-midi", 'popularity': 56, 'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f', 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'}, {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7ELV10HZC94beTCa9B7n6y'}, 'href': 'https://api.spotify.com/v1/albums/7ELV10HZC94beTCa9B7n6y', 'id': '7ELV10HZC94beTCa9B7n6y', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273c2d418a5d9c48111f43277cc', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02c2d418a5d9c48111f43277cc', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851c2d418a5d9c48111f43277cc', 'width': 64}], 'name': 'Cascade Street', 'release_date': '1996', 'release_date ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=Yann+Tiersen&type=track&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  2238

# %% [markdown]
# ## Exploring the tracks

# %%
print("Total number of tracks: ",len(results["tracks"]["items"])) # 50 Tracks (as limited, it is the maximum)
print("Info of the first song: ",results["tracks"]["items"][0]) # Explore the first song 
print("The keys of the dictionary are: ",list(results["tracks"]["items"][0].keys())) # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# Total number of tracks:  5
# Info of the first song:  {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['US'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'}, 'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj', 'id': '7JG0QwvJRzPILHEW1xHEJj', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b', 'width': 64}], 'name': 'Amélie (Original Soundtrack)', 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 25, 'type': 'album', 'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['US'], 'disc_number': 1, 'duration_ms': 140733, 'explicit': False, 'external_ids': {'isrc': 'FR91U0100002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}, 'href': 'https://api.spotify.com/v1/tracks/4O2N861eOnF9q8EtpH8IJu', 'id': '4O2N861eOnF9q8EtpH8IJu', 'is_local': False, 'name': "Comptine d'un autre été, l'après-midi", 'popularity': 56, 'preview_url': 'https://p.scdn.co/mp3-preview/b6f6af8e3b58fb0fee23108124a26a397f88a94b?cid=0912c34e16c349f28a330c0eba3cc52f', 'track_number': 4, 'type': 'track', 'uri': 'spotify:track:4O2N861eOnF9q8EtpH8IJu'}
# The keys of the dictionary are:  ['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri']

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
print(results["tracks"]["items"][0]["album"]["release_date"]) #date in YYYY-MM-DD format
print("Songs in the album: ",results["tracks"]["items"][0]["album"]["total_tracks"]) #songs in the album
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}], 'available_markets': ['US'], 'external_urls': {'spotify': 'https://open.spotify.com/album/7JG0QwvJRzPILHEW1xHEJj'}, 'href': 'https://api.spotify.com/v1/albums/7JG0QwvJRzPILHEW1xHEJj', 'id': '7JG0QwvJRzPILHEW1xHEJj', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27301e41b3cb7d14f569756801b', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0201e41b3cb7d14f569756801b', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485101e41b3cb7d14f569756801b', 'width': 64}], 'name': 'Amélie (Original Soundtrack)', 'release_date': '2001-04-23', 'release_date_precision': 'day', 'total_tracks': 25, 'type': 'album', 'uri': 'spotify:album:7JG0QwvJRzPILHEW1xHEJj'}
# ['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00sazWvoTLOqg5MFwC68Um'}, 'href': 'https://api.spotify.com/v1/artists/00sazWvoTLOqg5MFwC68Um', 'id': '00sazWvoTLOqg5MFwC68Um', 'name': 'Yann Tiersen', 'type': 'artist', 'uri': 'spotify:artist:00sazWvoTLOqg5MFwC68Um'}]
# The album ID is:  7JG0QwvJRzPILHEW1xHEJj
# Amélie (Original Soundtrack)
# 2001-04-23
# Songs in the album:  25

# %% [markdown]
# ## Other info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:4O2N861eOnF9q8EtpH8IJu'

# %% [markdown]
# # Exploring songs

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
type(playlist)
# Out:
# dict

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5242
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'Raaban',
#  'Teriyaki Boyz',
#  'Skylar Grey',
#  'Sleepy Tom',
#  'Naomi Scott',
#  'Marilii',
#  'Radiohead',
#  'Dylan Playfair',
#  'Kurupt',
#  'Jez Dior',
#  'The Notorious B.I.G.',
#  'Lauv',
#  'SNBRN',
#  'Nekfeu',
#  'DripReport',
#  'Lene Marlin',
#  'Arrhult',
#  'SoMo',
#  'Subvrbs',
#  'Parliament Funkadelic',
#  'Omar Varela',
#  'Bass Modulators',
#  'Jhay Cortez',
#  'Zen Cafe',
#  'Gary Jules',
#  'Ilsey',
#  'TisaKorean',
#  'Shelco Garcia & Teenwolf',
#  'Jon-Jon',
#  'Sami Hedberg',
#  'V.I.C.',
#  'Marja',
#  'Wheatus',
#  '3NIGMA',
#  'Boys Noize',
#  'BESS',
#  'Seeb',
#  'Cutting Crew',
#  'Delaney Jane',
#  'Hotelli Vantaa',
#  'Aiko',
#  'Anne-Marie',
#  'Mariska & Pahat Sudet',
#  'KStewart',
#  'kent',
#  'DubVision',
#  'Daniel Powter',
#  'Kyler England',
#  'VilleGalle',
#  'XXXTENTACION',
#  'ABBA',
#  'Stormzy',
#  'Larray',
#  'Poju',
#  'DJ BL3ND',
#  'LiL Lotus',
#  'Phoebe Ryan',
#  'Röyksopp',
#  'Kevin Gates',
#  'Oliver Tree',
#  'Plustwo',
#  'Drake',
#  'Gotye',
#  'BROCKHAMPTON',
#  'Bryson Tiller',
#  'PnB Rock',
#  'Daft Punk',
#  'Neev',
#  'Hight',
#  'Hughie Thomasson',
#  'Ca$his',
#  'Teflon Brothers',
#  'Sebastian Ingrosso',
#  'Ms. Toi',
#  'Ricegum',
#  'Steven A. Clark',
#  'De La Ghetto',
#  'Sound Of Legend',
#  'Diddy - Dirty Money',
#  'Hayla',
#  'WTF!',
#  'Pyhimys',
#  'Victoria Justice',
#  'Jesse McCartney',
#  'Joel Adams',
#  'T.I.',
#  'Lexxmatiq',
#  'Cole Swindell',
#  'Maggie Lindemann',
#  'Cuban Doll',
#  'Max B',
#  'DJ Fresh',
#  'Gabriella Montez',
#  'So Loki',
#  'gnash',
#  'DJ Oku Luukkainen',
#  'Nicky Romero',
#  'Ella Henderson',
#  'Rita Ora',
#  'Leevi and the leavings',
#  'Six-Two',
#  'Matoma',
#  'Conrad Sewell',
#  'Astrid S',
#  'KC',
#  'Diplo',
#  'Jessie Reyez',
#  'Emily Osment',
#  'Lil Skies',
#  'Sub Urban',
#  'Ricky Montgomery',
#  'Jenna Alexa',
#  'dodie',
#  'The Moose',
#  'AJR',
#  'Ryan Tedder',
#  'Eve',
#  'View',
#  'Neon 2',
#  'Modern Talking',
#  'Starship',
#  'Absofacto',
#  'Bizarre',
#  'Alicia Keys',
#  'Lush & Simon',
#  'Alyson Stoner',
#  'Banx & Ranx',
#  'ROSALÍA',
#  'EDEN',
#  'The Rasmus',
#  'Preme',
#  'Haddaway',
#  'Mikael Gabriel',
#  'Regard',
#  'Yolanda Be Cool',
#  'MKDMSK',
#  'Third Party',
#  'Tuomas Holopainen',
#  'Juicy J',
#  'Flo Milli',
#  'Breakbot',
#  'Promoting Sounds',
#  'DNCE',
#  'Daler Mehndi',
#  'Lil Gotit',
#  'Kalle Kinos',
#  'Mac Miller',
#  'The Cataracs',
#  'Dixie',
#  'Joznez',
#  'Sexmane',
#  '916frosty',
#  'X Ambassadors',
#  'Jamie Foxx',
#  'Diamond D',
#  'Irfane',
#  'Sasha Sloan',
#  'Rixton',
#  'Spekti',
#  'Marc Stout',
#  'Laura Närhi',
#  '9lokknine',
#  'Drake Bell',
#  'Thomas Doherty',
#  'Will Sparks',
#  'The Cab',
#  '*NSYNC',
#  'Paul Rey',
#  'Piso 21',
#  'ZaeHD & CEO',
#  'Young Curt',
#  'Axel Kala',
#  'Jhené Aiko',
#  'Hayley Kiyoko',
#  'Ozzy Osbourne',
#  'Goody Grace',
#  'JoJo',
#  'Bryce',
#  'Cameron Boyce',
#  'Pepe Willberg',
#  'Borgeous',
#  'Kaash Paige',
#  'Dagny',
#  'Jasmine Thompson',
#  'Aly & AJ',
#  'iLOVEFRiDAY',
#  'Afro Bros',
#  'Gala',
#  'Sigala',
#  'Anna Maria Perez de Taglé',
#  'Westside Connection',
#  'BigKlit',
#  'TheHxliday',
#  'Kesh Kesh',
#  'Imanbek',
#  'Dopebwoy',
#  'costee',
#  'Yasmine Yamajako',
#  'Malo',
#  'Bobby Shmurda',
#  'Eurythmics',
#  'Audrey Mika',
#  'BeatKing',
#  'Cascada',
#  'Jake Reese',
#  'Reino Nordin',
#  'Eldis',
#  'Madison Beer',
#  'Portugal. The Man',
#  'Lennon Stella',
#  'Lovely Peaches',
#  'Nicholas Fraser',
#  'Mack 10',
#  'Luniz',
#  'Cordae',
#  'DeJ Loaf',
#  'Showtek & Justin Prime',
#  'Cosmo Sheldrake',
#  'Lil Kayla',
#  'Thomas & Friends',
#  'YG',
#  'Tom & Hills',
#  'Joyner Lucas',
#  'BloodPop®',
#  'Conor Maynard',
#  'Dave Audé for Awestruck Productions, Inc.',
#  'Céline Dion',
#  'Brooks',
#  'INNA',
#  'ibe',
#  'Janna',
#  'Grace Grundy',
#  'D.O.D',
#  'Culture Beat',
#  'N.E.R.D',
#  'Ying Yang Twins',
#  'Pykäri',
#  'Little Mix',
#  'Fabolous',
#  '3OH!3',
#  '3robi',
#  'Ayah Marar',
#  'Jannika B',
#  'eli.',
#  'Tate McRae',
#  'Riverdale Cast',
#  'Oliver Heldens',
#  'A7S',
#  'Sam Fischer',
#  'Kraantje Pappie',
#  'Haneri',
#  'Life of Boris',
#  'Zoe Nash',
#  'Wynter Gordon',
#  'Jaden',
#  'Georgi Kay',
#  'Drax Project',
#  'MC Eiht',
#  'Mumford & Sons',
#  'Hausmylly',
#  'Kat Dahlia',
#  'Touko',
#  'LunchMoney Lewis',
#  'Descemer Bueno',
#  'John & Michel',
#  'Shapov',
#  'MGI',
#  'Timi Lexikon',
#  'Michael Bublé',
#  'Mikky Ekko',
#  'J. Davi$',
#  'Brando',
#  'Handsome Luke',
#  'Gente De Zona',
#  'The Goo Goo Dolls',
#  'Koffee',
#  'Matias',
#  'Shelley FKA DRAM',
#  'Mr. Collipark',
#  'Mitchell Hope',
#  'Tyla Yaweh',
#  'Imagine Dragons',
#  '112',
#  'RONNIE',
#  'Cast of Shake It Up: Break It Down',
#  'Ella Eyre',
#  'Bryan Rice',
#  'Matthew Wilder',
#  'LIFE',
#  'Mannie Fresh',
#  'GraphicMuzik',
#  'Brennan Heart',
#  'Elle King',
#  'Alexia',
#  'Alex Newell',
#  'The All-American Rejects',
#  'Dawin',
#  'Ultradiox',
#  'Darude',
#  'Ronya',
#  'Zedd',
#  'BØRNS',
#  'Särre',
#  'Twenty One Pilots',
#  'D-Block & S-te-Fan',
#  'Mabel',
#  'K-Slim',
#  'Firebeatz',
#  'KajO',
#  'LP',
#  'Stig Dogg',
#  'JP Cooper',
#  'Iggy Azalea',
#  'Master Blaster',
#  'Turisti',
#  'Foxes',
#  'The Kid LAROI',
#  'Dominic Fike',
#  'Johanna Kurkela',
#  'Cashmere Cat',
#  'NextYoungin',
#  'Sophia Annello',
#  'william',
#  'La Santa Cecilia',
#  'DMX',
#  'HesaÄijä',
#  'Oh Wonder',
#  'Pehmee Goo',
#  'Konsta Original',
#  "Why Don't We",
#  'Yksi Totuus',
#  "Bomfunk MC's",
#  'Meghan Trainor',
#  'J. Karjalainen & Mustat Lasit',
#  'Pras',
#  'Lily Allen',
#  'Hannah Montana',
#  'Kamatos',
#  'Ryanning',
#  'Live for the weekend',
#  'Pandora',
#  'Chief Keef',
#  'Diddy',
#  'U96',
#  'Ayo & Teo',
#  'Blueface',
#  'Oliver Nelson',
#  'Kah-Lo',
#  'JAY-Z',
#  'Redfoo',
#  'Gunther & the Sunshine Girls',
#  'TOTO',
#  'Normani',
#  'MGMT',
#  'Dirty Disco Youth',
#  'Vesterinen yhtyeineen',
#  'Coolio',
#  'T.O.E.C.',
#  'CMC$',
#  'K-System',
#  'Youngbloodz',
#  'Me & My',
#  '6LACK',
#  'Aikakone',
#  'Dove Cameron',
#  'Tears For Fears',
#  'Bingo Players',
#  'Roy Woods',
#  'Kacey Musgraves',
#  'Calvin Harris',
#  'Smash Mouth',
#  'CamelPhat',
#  'Robin og Bugge',
#  'Beach Bunny',
#  'Malmö',
#  'Pekka Ruuska',
#  'Sak Noel',
#  'WSTRN',
#  'Vaboh',
#  'CeeLo Green',
#  'Shokk',
#  'Timeflies',
#  'Kranium',
#  'Vege',
#  'Wanz',
#  'Eminem',
#  'Kwabs',
#  'twoloud',
#  'Toro y Moi',
#  'Cobra Starship',
#  'Take A Daytrip',
#  'Monica',
#  'Jeremy Zucker',
#  'Robin',
#  'Ege Zulu',
#  'Herba',
#  'Temur',
#  'Da Tweekaz',
#  'Asa',
#  'Uniikki',
#  'The Boy Next Door',
#  'Strange Talk',
#  'Freeman',
#  'Ola',
#  'Teuvo Loman',
#  'Brennan Savage',
#  'Migos',
#  'Movetron',
#  'Freddy Kalas',
#  'Style of Eye',
#  'Juelz Santana',
#  'Vula',
#  'One Direction',
#  'Fatboy L',
#  'Juno',
#  'JP Saxe',
#  'Trippie Redd',
#  'Mike WiLL Made-It',
#  'The Him',
#  'Lewis Capaldi',
#  'Avicii',
#  'Kaija Koo',
#  'E-40',
#  'Sofía Reyes',
#  'YoungBoy Never Broke Again',
#  'MKTO',
#  'Maisie Peters',
#  'Sheck Wes',
#  'Nelly Furtado',
#  'Tommi Läntinen',
#  'Fasion',
#  'Zachary Knowles',
#  'Lil Keed',
#  'A2M',
#  'The Living Tombstone',
#  'Joseph',
#  'Jessie J',
#  'Benjamin',
#  'Captain Cuts',
#  'Chris Linton',
#  'Todiefor',
#  'Don Omar',
#  '21 Savage',
#  'Adelén',
#  'Kacy Hill',
#  '2 Chainz',
#  'Eric Turner',
#  'OMI',
#  'Robin Schulz',
#  'Töölön Ketterä',
#  'Wham!',
#  'Etta',
#  'Joseph Williams',
#  'C & C Music Factory',
#  'Zacari',
#  'Märkä-Simo',
#  'Camila Cabello',
#  'James Newton Howard',
#  'Tez Cadey',
#  'Nightcore',
#  'Dimitri Vangelis & Wyman',
#  'Tauski',
#  'Coldplay',
#  'Breathe Carolina',
#  'Nico & Vinz',
#  'Basic Element',
#  'Dr. Dre',
#  'Vanilla Ice',
#  'Becky G',
#  'Lost Frequencies',
#  'E-Type',
#  'Khia',
#  'Yade Lauren',
#  'Arctic Monkeys',
#  'Slim Mill',
#  'DJ Katch',
#  'Crystal Castles',
#  'Jeremih',
#  'Lupe Fiasco',
#  'Natalie La Rose',
#  'Luis Fonsi',
#  'Martin Garrix',
#  'Auntie Hammy',
#  'Madden',
#  'Nelly',
#  'SANNI',
#  'Roscoe Dash',
#  'The Naked And Famous',
#  'Matt Squire',
#  'Jonas Brothers',
#  'Flipmode Squad',
#  'Sada Baby',
#  'MARINA',
#  'Akon',
#  'SHRTY',
#  'Isac Elliot',
#  'Jonna Tervomaa',
#  'Sara Bareilles',
#  'PistePiste',
#  'AlunaGeorge',
#  '5 Seconds of Summer',
#  'Shotgun Willy',
#  'Dan Caplen',
#  'Protoculture',
#  'phem',
#  'Six',
#  'Carnage',
#  'Sampha',
#  'Olivia Rodrigo',
#  'Ida Paul & Kalle Lindroth',
#  'Lil Nas X',
#  'Jumal X10 Lavis',
#  'Troy',
#  'Tim Bergling',
#  'Ne-Yo',
#  'Jacob Sartorius',
#  'A Great Big World',
#  'Jorja Smith',
#  'Nayer',
#  'FlicFlac',
#  'Annika Eklund',
#  'WALK THE MOON',
#  'Shawn Hook',
#  'Mike Williams',
#  'A$AP Ferg',
#  'THEY.',
#  'Lil Baby',
#  'Marvin Gaye',
#  'Alvaro Soler',
#  'John Legend',
#  'Mouhous',
#  'Tay Money',
#  'Mr Magic',
#  'Savage',
#  'Natalie Imbruglia',
#  'Chance the Rapper',
#  'Shakira',
#  'Timo Pieni Huijaus',
#  'Sofia Zida',
#  'ilyTOMMY',
#  'Isaiah Firebrace',
#  'Snoop Dogg',
#  'Dosdela',
#  'Lakim',
#  'Hurts',
#  'Raappana',
#  'My Chemical Romance',
#  'Ricky Martin',
#  'Simple Plan',
#  'Stanaj',
#  'Sam Smith',
#  'Jonne Aaron',
#  'DJ SpinKing',
#  'Little Big',
#  'Fokin Osk',
#  'Mohombi',
#  'Lil Sage x JustSeAbu x MVD J€¥$ON',
#  'Tim McMorris',
#  'Lana Del Rey',
#  'ZAYN',
#  'Lady Gaga',
#  'Selena Gomez',
#  'Sonique',
#  'Powfu',
#  '50 Cent',
#  'Black Sabbath',
#  'Erin',
#  'Richi M.',
#  'Heikki Kuula',
#  'Nyla',
#  'Pitbull',
#  'Alesso',
#  'kai',
#  'Darko',
#  'Russ',
#  'Kristiina Brask',
#  'Bow Wow',
#  'SEUNGRI',
#  'JESSIA',
#  'Don Huonot',
#  'Foster The People',
#  'Gasellit',
#  'Miranda Cosgrove',
#  'Aqua',
#  'Victorious Cast',
#  'Sultan',
#  'Vance Joy',
#  'Grey',
#  'JACKBOYS',
#  'Thomas Jack',
#  'Lil Mosey',
#  'EXO',
#  'lentra',
#  'Jason Weaver',
#  'Martin Jensen',
#  'Quavo',
#  'Zatox',
#  'YSN Flow',
#  'Cedric Gervais',
#  'Blasterjaxx',
#  'Tove Lo',
#  'Vinttikoira',
#  'Ace of Base',
#  'NF',
#  'The Flexican',
#  'Otto Knows',
#  'Kings of Leon',
#  'Years & Years',
#  'Bassjackers',
#  'John Ryan',
#  'FS Green',
#  'Fousheé',
#  'Sirena',
#  'Bekuh Boom',
#  'DVBBS',
#  'Space Cowboy',
#  'Jason Evigan',
#  'Sam Martin',
#  'Funk Wav',
#  'China Anne McClain',
#  'Jeremy Folderol',
#  'Kansas',
#  'Dua Lipa',
#  'Oasis',
#  'Sandra Lyng',
#  'Kelly Clarkson',
#  'Sir Chloe',
#  'Cory Gunz',
#  'Within Temptation',
#  'Kristal',
#  'Michel Teló',
#  'Ty James',
#  'Ludacris',
#  'Hussa',
#  'Famous Ocean & KungFu',
#  'Maiki',
#  'Young Manager',
#  'W&W',
#  'ABREU',
#  'Mase',
#  'TRAQULA',
#  'Meiju Suvas',
#  'Troye Sivan',
#  'Jared Lee',
#  'The Game',
#  'Pink Guy',
#  'Mally Mall',
#  'Anders Nilsen',
#  'Eternal Flames',
#  'Savage Garden',
#  'Nathan Goshen',
#  'Costi',
#  'Fat Joe',
#  'City Spud',
#  'KYLE',
#  'Surfaces',
#  'Ty Dolla $ign',
#  'Jauz',
#  'Niko Saarinen',
#  'Chase Atlantic',
#  'Ali Gatie',
#  'Prinssi Jusuf',
#  'Zac Efron',
#  'The Throne',
#  'The Boyboy West Coast',
#  'Swell',
#  'LOLO',
#  'Mr. Elämänpeli',
#  'Dermot Kennedy',
#  'PastoriPike',
#  'Toni Braxton',
#  'Valvomo',
#  'Rudimental',
#  'Ruben',
#  'Rex Orange County',
#  'Lil Kapow',
#  'Riton',
#  'Ethan Fields',
#  'Masterboy',
#  'Apocalyptica',
#  'Nicky Jam',
#  'Antti Railio',
#  'MC Hammer',
#  'Dreezy',
#  'Indica',
#  'Mokita',
#  'Sofia Carson',
#  'STIG',
#  'Benji Reyes',
#  'Kielijuhani',
#  'Crystal Fighters',
#  'Emeni',
#  'Giveon',
#  'Devault',
#  'Chimamanda Ngozi Adichie',
#  'Gia Koka',
#  'ODEE',
#  'Sean Kingston',
#  'Alice DJ',
#  'LILHUDDY',
#  'Era Istrefi',
#  'Justin Stone',
#  "Lil' Kim",
#  'Injury Reserve',
#  'Ian Everson',
#  'Lukas Graham',
#  'Burak Yeter',
#  'Cassie',
#  'Naomi Wild',
#  'Ilpo Kaikkonen',
#  'Carlprit',
#  'Topic',
#  'MIKA',
#  'Dean Lewis',
#  'R. City',
#  'Ryan Riback',
#  'Hannah Robinson',
#  'Sam Feldt',
#  'Scooter',
#  'Lorde',
#  'Kid Ink',
#  'Yung Pinch',
#  'IDOLS-Finalistit 2007',
#  'Daniel Okas',
#  'Qulinez',
#  'Mary Lambert',
#  'Y2K',
#  'A Boogie Wit da Hoodie',
#  'Death Cab for Cutie',
#  'M-Fuse',
#  'VIIVI',
#  'Chris Willis',
#  'Spongebob Squarepants',
#  'Trap City',
#  'Tyler, The Creator',
#  'Pixie Lott',
#  'Yö',
#  '7ru7h',
#  'DJ Envy',
#  'Keri Hilson',
#  'J. Karjalainen',
#  'Anne Mattila',
#  'Leo Stannard',
#  'Tee Grizzley',
#  'Eazy-E',
#  'Levi-Äijä',
#  'La Bouche',
#  'Waka Flocka Flame',
#  'Kyla',
#  'BlocBoy JB',
#  'LSD',
#  'Mike Taylor',
#  'Nick Bonin',
#  'The Bangles',
#  'Aleksanteri Hakaniemi',
#  'Steve Aoki',
#  'fun.',
#  'Jess Glynne',
#  '6ix9ine',
#  'Matisyahu',
#  'Sunrise Avenue',
#  'Luke Combs',
#  'The Corrs',
#  'Ben Morfitt (SquidPhysics)',
#  'Vicetone',
#  'GoonRock',
#  'Yung Baby Tate',
#  'DJ Sliink',
#  'Gavin James',
#  'Softengine',
#  'Millie B',
#  'Zendaya',
#  'Pariisin Kevät',
#  'Iamsu!',
#  'JR Serpent',
#  'Axwell',
#  'Gucci Mane',
#  'Bryce Vine',
#  'LLusion',
#  'Survivor',
#  'Hugh Jackman',
#  'Riva Starr',
#  'Lovespeake',
#  'Vepu',
#  'Bizzey',
#  'Little Sis Nora',
#  'blackbear',
#  'Killua the Pilgrim',
#  'Dingo',
#  'Herrat',
#  'Boombox Cartel',
#  'Gromee',
#  'Marshmello',
#  'Party Favor',
#  'Vory',
#  'Calpurnia',
#  'Snow Patrol',
#  'Crazy Frog',
#  'Lykke Li',
#  'Engelwood',
#  'Brent Faiyaz',
#  'Speernorman',
#  'Ernie Sabella',
#  'FKi 1st',
#  'Kelly Rowland',
#  'Nicki Minaj',
#  'Jamelia',
#  'Miley Cyrus',
#  'Spree Wilson',
#  'Far East Movement',
#  'Sir Mix-A-Lot',
#  'AREA21',
#  'Stargate',
#  'Farruko',
#  'The Pussycat Dolls',
#  'Ja Rule',
#  'SLS',
#  'LIOHN',
#  'Lil Jon',
#  'Ryan',
#  'Eevil Stöö',
#  'Toby Fox',
#  'Oz Sparx',
#  'Carly Rae Jepsen',
#  'Nuorihylly',
#  'DEM',
#  'Tierra Whack',
#  'Amba Shepherd',
#  'Black Eyed Peas',
#  'H.E.R.',
#  'Eduardo Luzquiños',
#  'Riff Raff',
#  'Ghostface Killah',
#  'The Carters',
#  'ODB',
#  'Bizi',
#  'NOTD',
#  'Dropgun',
#  'BLACKPINK',
#  'Lyttä',
#  'Of Monsters and Men',
#  'Rodriguez',
#  'DJ DX',
#  'Don Toliver',
#  '3 Doors Down',
#  "Waldo's People",
#  'Marc E. Bassy',
#  'Big Sean',
#  'Väinöväinö',
#  'Rich Brian',
#  'MD$',
#  'Yung Bae',
#  'Gunna',
#  'Karina',
#  "Rag'n'Bone Man",
#  'Sophia Somajo',
#  'Snakehips',
#  'Ashley All Day',
#  'Lil Revive',
#  'Night Lovell',
#  'FLETCHER',
#  'LUCA',
#  'The Oddictions',
#  'Samuli Putro',
#  'Johnny Yukon',
#  'Nick Jonas',
#  'Daze',
#  'Swae Lee',
#  'Rebecca Naomi Jones',
#  'Fareoh',
#  'iamjakehill',
#  'Ellie Goulding',
#  'Lauren Bennett',
#  'Craig Xen',
#  'Diego Miranda',
#  'Jack Garratt',
#  'Childish Gambino',
#  'Jani Wickholm',
#  'Lady A',
#  'Metro Station',
#  'Skepta',
#  'Lakko',
#  'Lou Bega',
#  'Cavallini',
#  'Jussi 69',
#  'Annie Lennox',
#  'Pet Shop Boys',
#  'Erakossa',
#  'Iyaz',
#  'JJani',
#  'Jay Cosmic',
#  'Sanjin',
#  'Tarrus Riley',
#  'Salti',
#  'The Neighbourhood',
#  'Cassadee Pope',
#  'The Companions',
#  'Lea in the Mix',
#  'Madonna',
#  'Alok',
#  'Neea',
#  'Andreea D',
#  'Sueco',
#  'Maisa',
#  'Travis Scott',
#  'Aurora',
#  'Irina',
#  'Anssi Kela',
#  'Meek Mill',
#  'Nate Dogg',
#  "Destiny's Child",
#  'Mamba',
#  'Sasha Lopez',
#  'Megan Nicole',
#  'Tomppabeats',
#  'Mikkel Øwre',
#  'Bronski Beat',
#  'Fleurie',
#  'Ella Mai',
#  'Harry Belafonte',
#  'Lenka',
#  'Mike Candys',
#  't.A.T.u.',
#  'Future',
#  'Kodak Black',
#  'Edu Kettunen',
#  'Chamillionaire',
#  'Rae Sremmurd',
#  'Lil Xan',
#  'Maxx',
#  'Axwell /\\ Ingrosso',
#  'P. Moody',
#  'Portion Boys',
#  'Vaahteramäen Nege',
#  'Black Coffee',
#  'Duncan Laurence',
#  'Kris Kross Amsterdam',
#  'Whitney Houston',
#  'Daya',
#  'Jesse Kaikuranta',
#  'Ziv Zaifman',
#  'Corona',
#  'Sara Kays',
#  'Happoradio',
#  'LEO ISLO',
#  'Bogart Co.',
#  'DJ Martin ElectroSpin',
#  'Faydee',
#  'Vigiland',
#  'The Flint Chozen Choir',
#  'Eric Prydz',
#  'Djuro',
#  'PNAU',
#  'NCO',
#  'Lit',
#  'Supergrass',
#  'Miranda',
#  'Game of Thrones',
#  'ScHoolboy Q',
#  'J. Karjalainen Yhtyeineen',
#  'NLE Choppa',
#  'OneRepublic',
#  'Jesse Markin',
#  'Ritt Momney',
#  'Miriam Bryant',
#  'Yung Hilly',
#  'Kanye West',
#  'Major Lazer',
#  'Yellow Claw',
#  'Halsey',
#  'LIL MAYO',
#  'Loud Luxury',
#  'Anuel AA',
#  'Junge Junge',
#  'Lexi Jayde',
#  'salem ilese',
#  'L.V.',
#  'Diandra',
#  'Morgan Page',
#  'KOI',
#  'Showtek',
#  'Pää-äijät',
#  'Vesta',
#  'Apulanta',
#  'Beats And Styles',
#  'Duki',
#  'Alfons',
#  'R.I.O.',
#  'Silentó',
#  'Frostydasnowmann',
#  'Young Roc',
#  'Smino',
#  'Savage Ga$p',
#  'Zoé',
#  'Antti Ketonen',
#  'VIZE',
#  'Lauri Tähkä & Elonkerjuu',
#  'DJ Scheme',
#  'The Cars',
#  ...]

# %% [markdown]
# ## Artists ID

# %%
def get_artists_from_track(track):
    return[artist["name"] for artist in track["artists"]]

#--------------------------------------------------------------------

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
def get_artists_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_ids_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
len(artists)
len(artists_ids) # We might have more ids due to artists having the same name
# Out:
# 2420

# %% [markdown]
# # Getting the info

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Coldplay',
#  'Greta Bradman',
#  'José Manuel Ferreira Brito',
#  'Rhythms Del Mundo',
#  'Rihanna',
#  'Robin Schulz',
#  'Seeb',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 15256
