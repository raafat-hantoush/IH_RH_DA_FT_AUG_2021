# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results
# Out:
# 200
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '17987341541',
#   'type': 'WatchEvent',
#   'actor': {'id': 7550495,
#    'login': 'KristianFJones',
#    'display_login': 'KristianFJones',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KristianFJones',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7550495?'},
#   'repo': {'id': 199763479,
#    'name': 'bfenetworks/bfe',
#    'url': 'https://api.github.com/repos/bfenetworks/bfe'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z',
#   'org': {'id': 65478032,
#    'login': 'bfenetworks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bfenetworks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65478032?'}},
#  {'id': '17987341525',
#   'type': 'PushEvent',
#   'actor': {'id': 79536742,
#    'login': 'olgaterentyeva',
#    'display_login': 'olgaterentyeva',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/olgaterentyeva',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79536742?'},
#   'repo': {'id': 405041145,
#    'name': 'olgaterentyeva/Landing',
#    'url': 'https://api.github.com/repos/olgaterentyeva/Landing'},
#   'payload': {'push_id': 7935112919,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8b5f7617567642156b970735ad12bb5ff67b35a0',
#    'before': 'e63cc080035b230cc157d291ae9ce7771ee2abb1',
#    'commits': [{'sha': '8b5f7617567642156b970735ad12bb5ff67b35a0',
#      'author': {'email': 'terentyeevaolga@gmail.com',
#       'name': 'terentyevaolga'},
#      'message': 'footer without bg',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/olgaterentyeva/Landing/commits/8b5f7617567642156b970735ad12bb5ff67b35a0'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341510',
#   'type': 'PushEvent',
#   'actor': {'id': 30420089,
#    'login': 'mercadon',
#    'display_login': 'mercadon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mercadon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30420089?'},
#   'repo': {'id': 149518783,
#    'name': 'sourcegraph/about',
#    'url': 'https://api.github.com/repos/sourcegraph/about'},
#   'payload': {'push_id': 7935112909,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5833d8dfb41f58a58792b2c2beb5de21b3c580e3',
#    'before': '17dd052f448b6a567ceede545d889656274a1565',
#    'commits': [{'sha': '5833d8dfb41f58a58792b2c2beb5de21b3c580e3',
#      'author': {'email': '30420089+mercadon@users.noreply.github.com',
#       'name': 'Noemi Mercado'},
#      'message': 'Update resources_for_candidates.md (#4197)\n\nUpdated broken link with updated handbook page on visa policy.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sourcegraph/about/commits/5833d8dfb41f58a58792b2c2beb5de21b3c580e3'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z',
#   'org': {'id': 3979584,
#    'login': 'sourcegraph',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sourcegraph',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3979584?'}},
#  {'id': '17987341513',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1280507,
#    'login': 'aronnem',
#    'display_login': 'aronnem',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aronnem',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1280507?'},
#   'repo': {'id': 375388120,
#    'name': 'tkach940/oco2_modis_vistool',
#    'url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool'},
#   'payload': {'action': 'opened',
#    'number': 5,
#    'pull_request': {'url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5',
#     'id': 734073908,
#     'node_id': 'PR_kwDOFl_32M4rwRQ0',
#     'html_url': 'https://github.com/tkach940/oco2_modis_vistool/pull/5',
#     'diff_url': 'https://github.com/tkach940/oco2_modis_vistool/pull/5.diff',
#     'patch_url': 'https://github.com/tkach940/oco2_modis_vistool/pull/5.patch',
#     'issue_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/5',
#     'number': 5,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update to resolve merge conflicts with hcronk/master',
#     'user': {'login': 'aronnem',
#      'id': 1280507,
#      'node_id': 'MDQ6VXNlcjEyODA1MDc=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1280507?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/aronnem',
#      'html_url': 'https://github.com/aronnem',
#      'followers_url': 'https://api.github.com/users/aronnem/followers',
#      'following_url': 'https://api.github.com/users/aronnem/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/aronnem/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/aronnem/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/aronnem/subscriptions',
#      'organizations_url': 'https://api.github.com/users/aronnem/orgs',
#      'repos_url': 'https://api.github.com/users/aronnem/repos',
#      'events_url': 'https://api.github.com/users/aronnem/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/aronnem/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "This should hopefully make this branch easily merged with Heather's master branch.",
#     'created_at': '2021-09-14T22:14:55Z',
#     'updated_at': '2021-09-14T22:14:55Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5/commits',
#     'review_comments_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5/comments',
#     'review_comment_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/5/comments',
#     'statuses_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/statuses/3d79081ba834e2de1e614e1405ec7ca40d8e4f38',
#     'head': {'label': 'aronnem:himawari_functions',
#      'ref': 'himawari_functions',
#      'sha': '3d79081ba834e2de1e614e1405ec7ca40d8e4f38',
#      'user': {'login': 'aronnem',
#       'id': 1280507,
#       'node_id': 'MDQ6VXNlcjEyODA1MDc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1280507?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aronnem',
#       'html_url': 'https://github.com/aronnem',
#       'followers_url': 'https://api.github.com/users/aronnem/followers',
#       'following_url': 'https://api.github.com/users/aronnem/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aronnem/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aronnem/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aronnem/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aronnem/orgs',
#       'repos_url': 'https://api.github.com/users/aronnem/repos',
#       'events_url': 'https://api.github.com/users/aronnem/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aronnem/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 98949792,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5ODk0OTc5Mg==',
#       'name': 'oco2_modis_vistool',
#       'full_name': 'aronnem/oco2_modis_vistool',
#       'private': False,
#       'owner': {'login': 'aronnem',
#        'id': 1280507,
#        'node_id': 'MDQ6VXNlcjEyODA1MDc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1280507?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aronnem',
#        'html_url': 'https://github.com/aronnem',
#        'followers_url': 'https://api.github.com/users/aronnem/followers',
#        'following_url': 'https://api.github.com/users/aronnem/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aronnem/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aronnem/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aronnem/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aronnem/orgs',
#        'repos_url': 'https://api.github.com/users/aronnem/repos',
#        'events_url': 'https://api.github.com/users/aronnem/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aronnem/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/aronnem/oco2_modis_vistool',
#       'description': 'Plots OCO-2 lite file data on MODIS imagery',
#       'fork': True,
#       'url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool',
#       'forks_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/forks',
#       'keys_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/teams',
#       'hooks_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/events',
#       'assignees_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/tags',
#       'blobs_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/languages',
#       'stargazers_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/subscription',
#       'commits_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/merges',
#       'archive_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/downloads',
#       'issues_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aronnem/oco2_modis_vistool/deployments',
#       'created_at': '2017-08-01T02:21:04Z',
#       'updated_at': '2021-09-14T16:53:14Z',
#       'pushed_at': '2021-09-14T17:30:25Z',
#       'git_url': 'git://github.com/aronnem/oco2_modis_vistool.git',
#       'ssh_url': 'git@github.com:aronnem/oco2_modis_vistool.git',
#       'clone_url': 'https://github.com/aronnem/oco2_modis_vistool.git',
#       'svn_url': 'https://github.com/aronnem/oco2_modis_vistool',
#       'homepage': None,
#       'size': 304265,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'tkach940:himawari_functions',
#      'ref': 'himawari_functions',
#      'sha': '59f8bdce63b15273933cd0a54d0b0cc905ac3a12',
#      'user': {'login': 'tkach940',
#       'id': 56175328,
#       'node_id': 'MDQ6VXNlcjU2MTc1MzI4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/56175328?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tkach940',
#       'html_url': 'https://github.com/tkach940',
#       'followers_url': 'https://api.github.com/users/tkach940/followers',
#       'following_url': 'https://api.github.com/users/tkach940/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tkach940/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tkach940/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tkach940/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tkach940/orgs',
#       'repos_url': 'https://api.github.com/users/tkach940/repos',
#       'events_url': 'https://api.github.com/users/tkach940/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tkach940/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 375388120,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzUzODgxMjA=',
#       'name': 'oco2_modis_vistool',
#       'full_name': 'tkach940/oco2_modis_vistool',
#       'private': False,
#       'owner': {'login': 'tkach940',
#        'id': 56175328,
#        'node_id': 'MDQ6VXNlcjU2MTc1MzI4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/56175328?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tkach940',
#        'html_url': 'https://github.com/tkach940',
#        'followers_url': 'https://api.github.com/users/tkach940/followers',
#        'following_url': 'https://api.github.com/users/tkach940/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tkach940/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tkach940/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tkach940/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tkach940/orgs',
#        'repos_url': 'https://api.github.com/users/tkach940/repos',
#        'events_url': 'https://api.github.com/users/tkach940/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tkach940/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tkach940/oco2_modis_vistool',
#       'description': 'Plots OCO-2 lite file data on MODIS imagery',
#       'fork': True,
#       'url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool',
#       'forks_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/forks',
#       'keys_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/teams',
#       'hooks_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/events',
#       'assignees_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/tags',
#       'blobs_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/languages',
#       'stargazers_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/subscription',
#       'commits_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/merges',
#       'archive_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/downloads',
#       'issues_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/deployments',
#       'created_at': '2021-06-09T14:40:27Z',
#       'updated_at': '2021-06-09T21:21:55Z',
#       'pushed_at': '2021-08-11T19:28:15Z',
#       'git_url': 'git://github.com/tkach940/oco2_modis_vistool.git',
#       'ssh_url': 'git@github.com:tkach940/oco2_modis_vistool.git',
#       'clone_url': 'https://github.com/tkach940/oco2_modis_vistool.git',
#       'svn_url': 'https://github.com/tkach940/oco2_modis_vistool',
#       'homepage': None,
#       'size': 304224,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5'},
#      'html': {'href': 'https://github.com/tkach940/oco2_modis_vistool/pull/5'},
#      'issue': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/5'},
#      'comments': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/issues/5/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/pulls/5/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tkach940/oco2_modis_vistool/statuses/3d79081ba834e2de1e614e1405ec7ca40d8e4f38'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 6,
#     'additions': 67,
#     'deletions': 29,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341514',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 278937978,
#    'name': 'drupol/drupol',
#    'url': 'https://api.github.com/repos/drupol/drupol'},
#   'payload': {'push_id': 7935112912,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e1426de724ed2b57b05ee112e13f76580ed08568',
#    'before': '258d970b7a5f413401311a7e4563f284bf3083c3',
#    'commits': [{'sha': 'e1426de724ed2b57b05ee112e13f76580ed08568',
#      'author': {'email': 'actions@github.com', 'name': 'readme-scribe 🤖'},
#      'message': 'Update generated README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/drupol/drupol/commits/e1426de724ed2b57b05ee112e13f76580ed08568'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341504',
#   'type': 'CreateEvent',
#   'actor': {'id': 76843145,
#    'login': 'abraham-yusuf',
#    'display_login': 'abraham-yusuf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/abraham-yusuf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76843145?'},
#   'repo': {'id': 406536139,
#    'name': 'abraham-yusuf/BSID-NFT721',
#    'url': 'https://api.github.com/repos/abraham-yusuf/BSID-NFT721'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341487',
#   'type': 'PushEvent',
#   'actor': {'id': 254647,
#    'login': 'alsuren',
#    'display_login': 'alsuren',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alsuren',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/254647?'},
#   'repo': {'id': 314224030,
#    'name': 'alsuren/cargo-quickinstall',
#    'url': 'https://api.github.com/repos/alsuren/cargo-quickinstall'},
#   'payload': {'push_id': 7935112907,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/trigger/x86_64-pc-windows-msvc',
#    'head': '6d81b18225630193812084862405abf4d25d445c',
#    'before': '15943bff4c90c360ca7802d80e2be487f318f976',
#    'commits': [{'sha': '6d81b18225630193812084862405abf4d25d445c',
#      'author': {'email': 'alsuren+quickinstall@gmail.com',
#       'name': 'trigger-package-build.sh'},
#      'message': 'build watchexec on x86_64-pc-windows-msvc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alsuren/cargo-quickinstall/commits/6d81b18225630193812084862405abf4d25d445c'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341468',
#   'type': 'WatchEvent',
#   'actor': {'id': 45575072,
#    'login': 'therealpuneeth20',
#    'display_login': 'therealpuneeth20',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/therealpuneeth20',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45575072?'},
#   'repo': {'id': 119456637,
#    'name': 'beckswu/Leetcode',
#    'url': 'https://api.github.com/repos/beckswu/Leetcode'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:56Z'},
#  {'id': '17987341431',
#   'type': 'PushEvent',
#   'actor': {'id': 79336473,
#    'login': 'arciniegasjerson',
#    'display_login': 'arciniegasjerson',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arciniegasjerson',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79336473?'},
#   'repo': {'id': 389781401,
#    'name': 'CesarMorenoM/react-app',
#    'url': 'https://api.github.com/repos/CesarMorenoM/react-app'},
#   'payload': {'push_id': 7935112887,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/jerson',
#    'head': 'a328e06576a5ae3901d3ee43a651def727c1d699',
#    'before': '35e6557b971fe9177465a55845a4a15838cfbb7f',
#    'commits': [{'sha': 'a328e06576a5ae3901d3ee43a651def727c1d699',
#      'author': {'email': 'arciniegasjerson@gmail.com',
#       'name': 'Jerson Arciniegas'},
#      'message': 'Merge',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CesarMorenoM/react-app/commits/a328e06576a5ae3901d3ee43a651def727c1d699'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341435',
#   'type': 'PushEvent',
#   'actor': {'id': 68417258,
#    'login': 'breakingheatmap',
#    'display_login': 'breakingheatmap',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/breakingheatmap',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68417258?'},
#   'repo': {'id': 280356388,
#    'name': 'breakingheatmap/breakingheatmap',
#    'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap'},
#   'payload': {'push_id': 7935112882,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f086211109abe172f2b2f546aaebca6062b99767',
#    'before': 'ef7289aa0ceab9bf7ab77ade5261f1cacb4e2051',
#    'commits': [{'sha': 'f086211109abe172f2b2f546aaebca6062b99767',
#      'author': {'email': 'sudomaze@gmail.com', 'name': 'sudomaze'},
#      'message': '1631657693',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap/commits/f086211109abe172f2b2f546aaebca6062b99767'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341421',
#   'type': 'DeleteEvent',
#   'actor': {'id': 6749661,
#    'login': 'test987987',
#    'display_login': 'test987987',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/test987987',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6749661?'},
#   'repo': {'id': 40834904,
#    'name': 'test987987/test12',
#    'url': 'https://api.github.com/repos/test987987/test12'},
#   'payload': {'ref': '662a361d-84df-46a8-b9ac-8feaca0c55c7',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341388',
#   'type': 'PushEvent',
#   'actor': {'id': 87927395,
#    'login': 'pczh2010',
#    'display_login': 'pczh2010',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pczh2010',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/87927395?'},
#   'repo': {'id': 405701905,
#    'name': 'pczh2010/cf2dns',
#    'url': 'https://api.github.com/repos/pczh2010/cf2dns'},
#   'payload': {'push_id': 7935112855,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a512911aef888c20363730c96e4d16f655d2e2d1',
#    'before': 'ee4e578f8ce54fd5299172e8533c43360fdf29f0',
#    'commits': [{'sha': 'a512911aef888c20363730c96e4d16f655d2e2d1',
#      'author': {'email': 'pczh2010@gmail.com', 'name': 'pczh2010'},
#      'message': 'uploadfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pczh2010/cf2dns/commits/a512911aef888c20363730c96e4d16f655d2e2d1'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341396',
#   'type': 'PushEvent',
#   'actor': {'id': 84594280,
#    'login': 'mafras85',
#    'display_login': 'mafras85',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mafras85',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84594280?'},
#   'repo': {'id': 404487855,
#    'name': 'mafras85/MTA-Project',
#    'url': 'https://api.github.com/repos/mafras85/MTA-Project'},
#   'payload': {'push_id': 7935112866,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '3bfe215abc5dbc950b43867904591738ce36ca8e',
#    'before': '5ea37038e2edb4e39556d75431f472db031a3158',
#    'commits': [{'sha': '3bfe215abc5dbc950b43867904591738ce36ca8e',
#      'author': {'email': '84594280+mafras85@users.noreply.github.com',
#       'name': 'mafras85'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mafras85/MTA-Project/commits/3bfe215abc5dbc950b43867904591738ce36ca8e'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341400',
#   'type': 'PushEvent',
#   'actor': {'id': 10461942,
#    'login': 'christophs78',
#    'display_login': 'christophs78',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/christophs78',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10461942?'},
#   'repo': {'id': 288708949,
#    'name': 'christophs78/primefaces',
#    'url': 'https://api.github.com/repos/christophs78/primefaces'},
#   'payload': {'push_id': 7935112847,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/Java17',
#    'head': 'b7ac1c09d1579ef55972e3ea6ce73802495d75f5',
#    'before': 'a64c48dba491566f699e7c104fb0519099c2f33a',
#    'commits': [{'sha': '356aaf142aafd590fef553594c71c45ad2107543',
#      'author': {'email': 'christoph.strasser78@gmail.com',
#       'name': 'Christoph Straßer'},
#      'message': 'copy WAR to tempdir',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/christophs78/primefaces/commits/356aaf142aafd590fef553594c71c45ad2107543'},
#     {'sha': 'b7ac1c09d1579ef55972e3ea6ce73802495d75f5',
#      'author': {'email': 'christoph.strasser78@gmail.com',
#       'name': 'Christoph Straßer'},
#      'message': 'Hibernate Validator + Rollback copy WAR to tempdir',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/christophs78/primefaces/commits/b7ac1c09d1579ef55972e3ea6ce73802495d75f5'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341402',
#   'type': 'PushEvent',
#   'actor': {'id': 74123271,
#    'login': 'YuliaGV',
#    'display_login': 'YuliaGV',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/YuliaGV',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74123271?'},
#   'repo': {'id': 405784572,
#    'name': 'Zntoff/Reto-1-JuvenTIC',
#    'url': 'https://api.github.com/repos/Zntoff/Reto-1-JuvenTIC'},
#   'payload': {'push_id': 7935112860,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cdf107d83fad156ec3ac6124151f1575a7fae5ef',
#    'before': 'b34ea418b0e7d45ec3c3403eabd31525d32da8c7',
#    'commits': [{'sha': 'cdf107d83fad156ec3ac6124151f1575a7fae5ef',
#      'author': {'email': '74123271+YuliaGV@users.noreply.github.com',
#       'name': 'YuliaGV'},
#      'message': 'correct-headericon',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zntoff/Reto-1-JuvenTIC/commits/cdf107d83fad156ec3ac6124151f1575a7fae5ef'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341398',
#   'type': 'IssuesEvent',
#   'actor': {'id': 782180,
#    'login': 'alexvorobiev',
#    'display_login': 'alexvorobiev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alexvorobiev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/782180?'},
#   'repo': {'id': 4542716,
#    'name': 'NixOS/nixpkgs',
#    'url': 'https://api.github.com/repos/NixOS/nixpkgs'},
#   'payload': {'action': 'reopened',
#    'issue': {'url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/30723',
#     'repository_url': 'https://api.github.com/repos/NixOS/nixpkgs',
#     'labels_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/30723/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/30723/comments',
#     'events_url': 'https://api.github.com/repos/NixOS/nixpkgs/issues/30723/events',
#     'html_url': 'https://github.com/NixOS/nixpkgs/issues/30723',
#     'id': 267675493,
#     'node_id': 'MDU6SXNzdWUyNjc2NzU0OTM=',
#     'number': 30723,
#     'title': 'dockerTools: authentication and private repositories',
#     'user': {'login': 'danbst',
#      'id': 743057,
#      'node_id': 'MDQ6VXNlcjc0MzA1Nw==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/743057?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/danbst',
#      'html_url': 'https://github.com/danbst',
#      'followers_url': 'https://api.github.com/users/danbst/followers',
#      'following_url': 'https://api.github.com/users/danbst/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/danbst/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/danbst/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/danbst/subscriptions',
#      'organizations_url': 'https://api.github.com/users/danbst/orgs',
#      'repos_url': 'https://api.github.com/users/danbst/repos',
#      'events_url': 'https://api.github.com/users/danbst/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/danbst/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2017-10-23T13:49:49Z',
#     'updated_at': '2021-09-14T22:14:55Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '## Issue description\r\nA time ago there was an effort to allow `dockerTools` to work with private repositories:\r\ndockerTools: private registry support https://github.com/NixOS/nixpkgs/pull/12651\r\n\r\nBut after a series of merges/reverts this is lost now. Would be great to restore this. ',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z',
#   'org': {'id': 487568,
#    'login': 'NixOS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NixOS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/487568?'}},
#  {'id': '17987341387',
#   'type': 'CreateEvent',
#   'actor': {'id': 1732935,
#    'login': 'stoyicker',
#    'display_login': 'stoyicker',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stoyicker',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1732935?'},
#   'repo': {'id': 406498841,
#    'name': 'stoyicker/potential-garbanzo',
#    'url': 'https://api.github.com/repos/stoyicker/potential-garbanzo'},
#   'payload': {'ref': 'test',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Jorge Antonio Diaz-Benito Soriano',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341404',
#   'type': 'DeleteEvent',
#   'actor': {'id': 25967473,
#    'login': 'RealityRipple',
#    'display_login': 'RealityRipple',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RealityRipple',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25967473?'},
#   'repo': {'id': 405150368,
#    'name': 'RealityRipple/UXP',
#    'url': 'https://api.github.com/repos/RealityRipple/UXP'},
#   'payload': {'ref': 'sec-gpc-29.4.1',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341379',
#   'type': 'CreateEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 189707297,
#    'name': 'inabagumi/shinju-date',
#    'url': 'https://api.github.com/repos/inabagumi/shinju-date'},
#   'payload': {'ref': 'renovate/react-17.x',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'SHINJU DATE is a web service for searching videos.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z',
#   'org': {'id': 42648621,
#    'login': 'inabagumi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/inabagumi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42648621?'}},
#  {'id': '17987341364',
#   'type': 'PushEvent',
#   'actor': {'id': 85564550,
#    'login': 'wendeel-lima',
#    'display_login': 'wendeel-lima',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wendeel-lima',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85564550?'},
#   'repo': {'id': 404473154,
#    'name': 'wendeel-lima/back-and',
#    'url': 'https://api.github.com/repos/wendeel-lima/back-and'},
#   'payload': {'push_id': 7935112832,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8ac15f0783720232bf33d1e0724d05a54587d6ac',
#    'before': '0dd728d01c60b6daaef10f8793aaa6ecd6ab0a1b',
#    'commits': [{'sha': '8ac15f0783720232bf33d1e0724d05a54587d6ac',
#      'author': {'email': 'wendeel.admpar@gmail.com', 'name': 'Patrick Code'},
#      'message': 'validação de dados',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/wendeel-lima/back-and/commits/8ac15f0783720232bf33d1e0724d05a54587d6ac'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341378',
#   'type': 'PushEvent',
#   'actor': {'id': 12771866,
#    'login': 'suhaibroomy',
#    'display_login': 'suhaibroomy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suhaibroomy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12771866?'},
#   'repo': {'id': 280862990,
#    'name': 'navgurukul/soni-sori',
#    'url': 'https://api.github.com/repos/navgurukul/soni-sori'},
#   'payload': {'push_id': 7935112851,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0391663c321359d7355432f62105642cad3324df',
#    'before': '804948de138498ae4184cab66a13980d14072697',
#    'commits': [{'sha': '0391663c321359d7355432f62105642cad3324df',
#      'author': {'email': 'suhaibroomy91@gmail.com', 'name': 'Suhaib Roomy'},
#      'message': 'Typing Module Refactor (#168)\n\n* refactor of typing module\r\n\r\n* hihglight wrong key when types\r\n\r\n* updated AGP to 7.0.2\r\n\r\n* using key value to compare instead of label\r\n\r\n* added implementation for deeplink\r\n\r\n* compile only dependency for matrix sdk\r\n\r\n* updated timber dependency',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/navgurukul/soni-sori/commits/0391663c321359d7355432f62105642cad3324df'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z',
#   'org': {'id': 25605372,
#    'login': 'navgurukul',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/navgurukul',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25605372?'}},
#  {'id': '17987341375',
#   'type': 'PushEvent',
#   'actor': {'id': 64435955,
#    'login': 'nsc-de',
#    'display_login': 'nsc-de',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nsc-de',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64435955?'},
#   'repo': {'id': 404720807,
#    'name': 'shake-lang/parse-utils',
#    'url': 'https://api.github.com/repos/shake-lang/parse-utils'},
#   'payload': {'push_id': 7935112853,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': 'de78ee126ffc9a24434a1649ca5003cbeae20f67',
#    'before': '222cc8ce90da5364f7e4e43de1c94b5690926201',
#    'commits': [{'sha': 'de78ee126ffc9a24434a1649ca5003cbeae20f67',
#      'author': {'email': '64435955+nsc-de@users.noreply.github.com',
#       'name': 'Minimine'},
#      'message': 'Deploy website - based on dcd12110f1905603cba14fae4ce3787ad6aba37c',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shake-lang/parse-utils/commits/de78ee126ffc9a24434a1649ca5003cbeae20f67'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z',
#   'org': {'id': 84018255,
#    'login': 'shake-lang',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/shake-lang',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84018255?'}},
#  {'id': '17987341367',
#   'type': 'PushEvent',
#   'actor': {'id': 52953973,
#    'login': 'Moxrathore',
#    'display_login': 'Moxrathore',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Moxrathore',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52953973?'},
#   'repo': {'id': 406535851,
#    'name': 'Moxrathore/mainweb',
#    'url': 'https://api.github.com/repos/Moxrathore/mainweb'},
#   'payload': {'push_id': 7935112843,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4a18994e4132fe7434140d0ebe9f5a6dcab1f20c',
#    'before': 'f0f7a30fe17f4d4c797bb256ab194df11b77d5cc',
#    'commits': [{'sha': '4a18994e4132fe7434140d0ebe9f5a6dcab1f20c',
#      'author': {'email': '52953973+Moxrathore@users.noreply.github.com',
#       'name': 'MOX RATHORE'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Moxrathore/mainweb/commits/4a18994e4132fe7434140d0ebe9f5a6dcab1f20c'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341369',
#   'type': 'PushEvent',
#   'actor': {'id': 64525283,
#    'login': 'scraper002',
#    'display_login': 'scraper002',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scraper002',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64525283?'},
#   'repo': {'id': 369171564,
#    'name': 'scraper002/snapshot_data',
#    'url': 'https://api.github.com/repos/scraper002/snapshot_data'},
#   'payload': {'push_id': 7935112838,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '208585c33324f42b292d0e0d15e73b74c87d144e',
#    'before': '5a97acdbd4e20ddd4570648664469176887a3c28',
#    'commits': [{'sha': '208585c33324f42b292d0e0d15e73b74c87d144e',
#      'author': {'email': 'pu776ll@yahoo.co.jp', 'name': 'scraper002'},
#      'message': '1631657401',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/scraper002/snapshot_data/commits/208585c33324f42b292d0e0d15e73b74c87d144e'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341365',
#   'type': 'PushEvent',
#   'actor': {'id': 90420517,
#    'login': 'Nakhmad',
#    'display_login': 'Nakhmad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nakhmad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90420517?'},
#   'repo': {'id': 406529513,
#    'name': 'Nakhmad/Nakhmad.github.io',
#    'url': 'https://api.github.com/repos/Nakhmad/Nakhmad.github.io'},
#   'payload': {'push_id': 7935112852,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cbe031f2bb1ec3957f120cc76919843a676784ec',
#    'before': '7f1284eb96886c2feba85dfcf86a3a3db7306565',
#    'commits': [{'sha': 'cbe031f2bb1ec3957f120cc76919843a676784ec',
#      'author': {'email': 'na24752@educcomp01.ccbb.utexas.edu',
#       'name': 'Nelly Akhmadikina'},
#      'message': 'website',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Nakhmad/Nakhmad.github.io/commits/cbe031f2bb1ec3957f120cc76919843a676784ec'}]},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z'},
#  {'id': '17987341348',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 30420089,
#    'login': 'mercadon',
#    'display_login': 'mercadon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mercadon',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30420089?'},
#   'repo': {'id': 149518783,
#    'name': 'sourcegraph/about',
#    'url': 'https://api.github.com/repos/sourcegraph/about'},
#   'payload': {'action': 'closed',
#    'number': 4197,
#    'pull_request': {'url': 'https://api.github.com/repos/sourcegraph/about/pulls/4197',
#     'id': 713695307,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NzEzNjk1MzA3',
#     'html_url': 'https://github.com/sourcegraph/about/pull/4197',
#     'diff_url': 'https://github.com/sourcegraph/about/pull/4197.diff',
#     'patch_url': 'https://github.com/sourcegraph/about/pull/4197.patch',
#     'issue_url': 'https://api.github.com/repos/sourcegraph/about/issues/4197',
#     'number': 4197,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Update resources_for_candidates.md',
#     'user': {'login': 'mercadon',
#      'id': 30420089,
#      'node_id': 'MDQ6VXNlcjMwNDIwMDg5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/30420089?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mercadon',
#      'html_url': 'https://github.com/mercadon',
#      'followers_url': 'https://api.github.com/users/mercadon/followers',
#      'following_url': 'https://api.github.com/users/mercadon/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mercadon/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mercadon/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mercadon/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mercadon/orgs',
#      'repos_url': 'https://api.github.com/users/mercadon/repos',
#      'events_url': 'https://api.github.com/users/mercadon/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mercadon/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Updated broken link with updated handbook page on visa policy.',
#     'created_at': '2021-08-16T19:38:18Z',
#     'updated_at': '2021-09-14T22:14:54Z',
#     'closed_at': '2021-09-14T22:14:54Z',
#     'merged_at': '2021-09-14T22:14:54Z',
#     'merge_commit_sha': '5833d8dfb41f58a58792b2c2beb5de21b3c580e3',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'carlyj0nes',
#       'id': 81582402,
#       'node_id': 'MDQ6VXNlcjgxNTgyNDAy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/81582402?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/carlyj0nes',
#       'html_url': 'https://github.com/carlyj0nes',
#       'followers_url': 'https://api.github.com/users/carlyj0nes/followers',
#       'following_url': 'https://api.github.com/users/carlyj0nes/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/carlyj0nes/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/carlyj0nes/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/carlyj0nes/subscriptions',
#       'organizations_url': 'https://api.github.com/users/carlyj0nes/orgs',
#       'repos_url': 'https://api.github.com/users/carlyj0nes/repos',
#       'events_url': 'https://api.github.com/users/carlyj0nes/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/carlyj0nes/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/sourcegraph/about/pulls/4197/commits',
#     'review_comments_url': 'https://api.github.com/repos/sourcegraph/about/pulls/4197/comments',
#     'review_comment_url': 'https://api.github.com/repos/sourcegraph/about/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/sourcegraph/about/issues/4197/comments',
#     'statuses_url': 'https://api.github.com/repos/sourcegraph/about/statuses/8d0fc10f96bdf5d39ff5d15d4195a4098fab812f',
#     'head': {'label': 'sourcegraph:mercadon-patch-3',
#      'ref': 'mercadon-patch-3',
# ...
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-09-14T22:14:54Z',
#     'updated_at': '2021-09-14T22:14:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/dotnet/roslyn/pulls/56392/commits',
#     'review_comments_url': 'https://api.github.com/repos/dotnet/roslyn/pulls/56392/comments',
#     'review_comment_url': 'https://api.github.com/repos/dotnet/roslyn/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/dotnet/roslyn/issues/56392/comments',
#     'statuses_url': 'https://api.github.com/repos/dotnet/roslyn/statuses/06ec8e26d8c42fe5ac3f53bc6414e07f28509d7d',
#     'head': {'label': 'dotnet:locfiles/ebc9eed1-23c7-406a-9bec-d749eb9c98d4',
#      'ref': 'locfiles/ebc9eed1-23c7-406a-9bec-d749eb9c98d4',
#      'sha': '06ec8e26d8c42fe5ac3f53bc6414e07f28509d7d',
#      'user': {'login': 'dotnet',
#       'id': 9141961,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dotnet',
#       'html_url': 'https://github.com/dotnet',
#       'followers_url': 'https://api.github.com/users/dotnet/followers',
#       'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#       'repos_url': 'https://api.github.com/users/dotnet/repos',
#       'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 29078997,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA3ODk5Nw==',
#       'name': 'roslyn',
#       'full_name': 'dotnet/roslyn',
#       'private': False,
#       'owner': {'login': 'dotnet',
#        'id': 9141961,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dotnet',
#        'html_url': 'https://github.com/dotnet',
#        'followers_url': 'https://api.github.com/users/dotnet/followers',
#        'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#        'repos_url': 'https://api.github.com/users/dotnet/repos',
#        'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/dotnet/roslyn',
#       'description': 'The Roslyn .NET compiler provides C# and Visual Basic languages with rich code analysis APIs.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/dotnet/roslyn',
#       'forks_url': 'https://api.github.com/repos/dotnet/roslyn/forks',
#       'keys_url': 'https://api.github.com/repos/dotnet/roslyn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dotnet/roslyn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dotnet/roslyn/teams',
#       'hooks_url': 'https://api.github.com/repos/dotnet/roslyn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dotnet/roslyn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dotnet/roslyn/events',
#       'assignees_url': 'https://api.github.com/repos/dotnet/roslyn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dotnet/roslyn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dotnet/roslyn/tags',
#       'blobs_url': 'https://api.github.com/repos/dotnet/roslyn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dotnet/roslyn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dotnet/roslyn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dotnet/roslyn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dotnet/roslyn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dotnet/roslyn/languages',
#       'stargazers_url': 'https://api.github.com/repos/dotnet/roslyn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dotnet/roslyn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dotnet/roslyn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dotnet/roslyn/subscription',
#       'commits_url': 'https://api.github.com/repos/dotnet/roslyn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dotnet/roslyn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dotnet/roslyn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dotnet/roslyn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dotnet/roslyn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dotnet/roslyn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dotnet/roslyn/merges',
#       'archive_url': 'https://api.github.com/repos/dotnet/roslyn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dotnet/roslyn/downloads',
#       'issues_url': 'https://api.github.com/repos/dotnet/roslyn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dotnet/roslyn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dotnet/roslyn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dotnet/roslyn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dotnet/roslyn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dotnet/roslyn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dotnet/roslyn/deployments',
#       'created_at': '2015-01-11T02:39:03Z',
#       'updated_at': '2021-09-14T21:20:17Z',
#       'pushed_at': '2021-09-14T22:14:54Z',
#       'git_url': 'git://github.com/dotnet/roslyn.git',
#       'ssh_url': 'git@github.com:dotnet/roslyn.git',
#       'clone_url': 'https://github.com/dotnet/roslyn.git',
#       'svn_url': 'https://github.com/dotnet/roslyn',
#       'homepage': 'https://docs.microsoft.com/dotnet/csharp/roslyn-sdk/',
#       'size': 1372783,
#       'stargazers_count': 14895,
#       'watchers_count': 14895,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3400,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8913,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 3400,
#       'open_issues': 8913,
#       'watchers': 14895,
#       'default_branch': 'main'}},
#     'base': {'label': 'dotnet:release/dev17.0-vs-deps',
#      'ref': 'release/dev17.0-vs-deps',
#      'sha': '73165d0e9db050da8c46cc375565c9959a5f17e5',
#      'user': {'login': 'dotnet',
#       'id': 9141961,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dotnet',
#       'html_url': 'https://github.com/dotnet',
#       'followers_url': 'https://api.github.com/users/dotnet/followers',
#       'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#       'repos_url': 'https://api.github.com/users/dotnet/repos',
#       'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 29078997,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA3ODk5Nw==',
#       'name': 'roslyn',
#       'full_name': 'dotnet/roslyn',
#       'private': False,
#       'owner': {'login': 'dotnet',
#        'id': 9141961,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjkxNDE5NjE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/dotnet',
#        'html_url': 'https://github.com/dotnet',
#        'followers_url': 'https://api.github.com/users/dotnet/followers',
#        'following_url': 'https://api.github.com/users/dotnet/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/dotnet/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/dotnet/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/dotnet/subscriptions',
#        'organizations_url': 'https://api.github.com/users/dotnet/orgs',
#        'repos_url': 'https://api.github.com/users/dotnet/repos',
#        'events_url': 'https://api.github.com/users/dotnet/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/dotnet/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/dotnet/roslyn',
#       'description': 'The Roslyn .NET compiler provides C# and Visual Basic languages with rich code analysis APIs.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/dotnet/roslyn',
#       'forks_url': 'https://api.github.com/repos/dotnet/roslyn/forks',
#       'keys_url': 'https://api.github.com/repos/dotnet/roslyn/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/dotnet/roslyn/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/dotnet/roslyn/teams',
#       'hooks_url': 'https://api.github.com/repos/dotnet/roslyn/hooks',
#       'issue_events_url': 'https://api.github.com/repos/dotnet/roslyn/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/dotnet/roslyn/events',
#       'assignees_url': 'https://api.github.com/repos/dotnet/roslyn/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/dotnet/roslyn/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/dotnet/roslyn/tags',
#       'blobs_url': 'https://api.github.com/repos/dotnet/roslyn/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/dotnet/roslyn/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/dotnet/roslyn/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/dotnet/roslyn/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/dotnet/roslyn/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/dotnet/roslyn/languages',
#       'stargazers_url': 'https://api.github.com/repos/dotnet/roslyn/stargazers',
#       'contributors_url': 'https://api.github.com/repos/dotnet/roslyn/contributors',
#       'subscribers_url': 'https://api.github.com/repos/dotnet/roslyn/subscribers',
#       'subscription_url': 'https://api.github.com/repos/dotnet/roslyn/subscription',
#       'commits_url': 'https://api.github.com/repos/dotnet/roslyn/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/dotnet/roslyn/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/dotnet/roslyn/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/dotnet/roslyn/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/dotnet/roslyn/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/dotnet/roslyn/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/dotnet/roslyn/merges',
#       'archive_url': 'https://api.github.com/repos/dotnet/roslyn/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/dotnet/roslyn/downloads',
#       'issues_url': 'https://api.github.com/repos/dotnet/roslyn/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/dotnet/roslyn/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/dotnet/roslyn/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/dotnet/roslyn/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/dotnet/roslyn/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/dotnet/roslyn/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/dotnet/roslyn/deployments',
#       'created_at': '2015-01-11T02:39:03Z',
#       'updated_at': '2021-09-14T21:20:17Z',
#       'pushed_at': '2021-09-14T22:14:54Z',
#       'git_url': 'git://github.com/dotnet/roslyn.git',
#       'ssh_url': 'git@github.com:dotnet/roslyn.git',
#       'clone_url': 'https://github.com/dotnet/roslyn.git',
#       'svn_url': 'https://github.com/dotnet/roslyn',
#       'homepage': 'https://docs.microsoft.com/dotnet/csharp/roslyn-sdk/',
#       'size': 1372783,
#       'stargazers_count': 14895,
#       'watchers_count': 14895,
#       'language': 'C#',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 3400,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 8913,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'forks': 3400,
#       'open_issues': 8913,
#       'watchers': 14895,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/dotnet/roslyn/pulls/56392'},
#      'html': {'href': 'https://github.com/dotnet/roslyn/pull/56392'},
#      'issue': {'href': 'https://api.github.com/repos/dotnet/roslyn/issues/56392'},
#      'comments': {'href': 'https://api.github.com/repos/dotnet/roslyn/issues/56392/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/dotnet/roslyn/pulls/56392/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/dotnet/roslyn/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/dotnet/roslyn/pulls/56392/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/dotnet/roslyn/statuses/06ec8e26d8c42fe5ac3f53bc6414e07f28509d7d'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 2948,
#     'deletions': 2947,
#     'changed_files': 151}},
#   'public': True,
#   'created_at': '2021-09-14T22:14:55Z',
#   'org': {'id': 9141961,
#    'login': 'dotnet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dotnet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9141961?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id              type  \
# 0   17987341541        WatchEvent
# 1   17987341525         PushEvent
# 2   17987341510         PushEvent
# 3   17987341513  PullRequestEvent
# 4   17987341514         PushEvent
# 5   17987341504       CreateEvent
# 6   17987341487         PushEvent
# 7   17987341468        WatchEvent
# 8   17987341431         PushEvent
# 9   17987341435         PushEvent
# 10  17987341421       DeleteEvent
# 11  17987341388         PushEvent
# 12  17987341396         PushEvent
# 13  17987341400         PushEvent
# 14  17987341402         PushEvent
# 15  17987341398       IssuesEvent
# 16  17987341387       CreateEvent
# 17  17987341404       DeleteEvent
# 18  17987341379       CreateEvent
# 19  17987341364         PushEvent
# 20  17987341378         PushEvent
# 21  17987341375         PushEvent
# 22  17987341367         PushEvent
# 23  17987341369         PushEvent
# 24  17987341365         PushEvent
# 25  17987341348  PullRequestEvent
# 26  17987341366         PushEvent
# 27  17987341359       CreateEvent
# 28  17987341354  PullRequestEvent
# 29  17987341343  PullRequestEvent
#
#                                                 actor  \
# 0   {'id': 7550495, 'login': 'KristianFJones', 'di...
# 1   {'id': 79536742, 'login': 'olgaterentyeva', 'd...
# 2   {'id': 30420089, 'login': 'mercadon', 'display...
# 3   {'id': 1280507, 'login': 'aronnem', 'display_l...
# 4   {'id': 41898282, 'login': 'github-actions[bot]...
# 5   {'id': 76843145, 'login': 'abraham-yusuf', 'di...
# 6   {'id': 254647, 'login': 'alsuren', 'display_lo...
# 7   {'id': 45575072, 'login': 'therealpuneeth20', ...
# 8   {'id': 79336473, 'login': 'arciniegasjerson', ...
# 9   {'id': 68417258, 'login': 'breakingheatmap', '...
# 10  {'id': 6749661, 'login': 'test987987', 'displa...
# 11  {'id': 87927395, 'login': 'pczh2010', 'display...
# 12  {'id': 84594280, 'login': 'mafras85', 'display...
# 13  {'id': 10461942, 'login': 'christophs78', 'dis...
# 14  {'id': 74123271, 'login': 'YuliaGV', 'display_...
# 15  {'id': 782180, 'login': 'alexvorobiev', 'displ...
# 16  {'id': 1732935, 'login': 'stoyicker', 'display...
# 17  {'id': 25967473, 'login': 'RealityRipple', 'di...
# 18  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 19  {'id': 85564550, 'login': 'wendeel-lima', 'dis...
# 20  {'id': 12771866, 'login': 'suhaibroomy', 'disp...
# 21  {'id': 64435955, 'login': 'nsc-de', 'display_l...
# 22  {'id': 52953973, 'login': 'Moxrathore', 'displ...
# 23  {'id': 64525283, 'login': 'scraper002', 'displ...
# 24  {'id': 90420517, 'login': 'Nakhmad', 'display_...
# 25  {'id': 30420089, 'login': 'mercadon', 'display...
# 26  {'id': 8517910, 'login': 'LombiqBot', 'display...
# 27  {'id': 45902873, 'login': 'aochoae', 'display_...
# 28  {'id': 28765322, 'login': 'mono57', 'display_l...
# 29  {'id': 9011267, 'login': 'dotnet-bot', 'displa...
#
#                                                  repo  \
# 0   {'id': 199763479, 'name': 'bfenetworks/bfe', '...
# 1   {'id': 405041145, 'name': 'olgaterentyeva/Land...
# 2   {'id': 149518783, 'name': 'sourcegraph/about',...
# 3   {'id': 375388120, 'name': 'tkach940/oco2_modis...
# 4   {'id': 278937978, 'name': 'drupol/drupol', 'ur...
# 5   {'id': 406536139, 'name': 'abraham-yusuf/BSID-...
# 6   {'id': 314224030, 'name': 'alsuren/cargo-quick...
# 7   {'id': 119456637, 'name': 'beckswu/Leetcode', ...
# 8   {'id': 389781401, 'name': 'CesarMorenoM/react-...
# 9   {'id': 280356388, 'name': 'breakingheatmap/bre...
# 10  {'id': 40834904, 'name': 'test987987/test12', ...
# 11  {'id': 405701905, 'name': 'pczh2010/cf2dns', '...
# 12  {'id': 404487855, 'name': 'mafras85/MTA-Projec...
# 13  {'id': 288708949, 'name': 'christophs78/primef...
# 14  {'id': 405784572, 'name': 'Zntoff/Reto-1-Juven...
# 15  {'id': 4542716, 'name': 'NixOS/nixpkgs', 'url'...
# 16  {'id': 406498841, 'name': 'stoyicker/potential...
# 17  {'id': 405150368, 'name': 'RealityRipple/UXP',...
# 18  {'id': 189707297, 'name': 'inabagumi/shinju-da...
# 19  {'id': 404473154, 'name': 'wendeel-lima/back-a...
# 20  {'id': 280862990, 'name': 'navgurukul/soni-sor...
# 21  {'id': 404720807, 'name': 'shake-lang/parse-ut...
# 22  {'id': 406535851, 'name': 'Moxrathore/mainweb'...
# 23  {'id': 369171564, 'name': 'scraper002/snapshot...
# 24  {'id': 406529513, 'name': 'Nakhmad/Nakhmad.git...
# 25  {'id': 149518783, 'name': 'sourcegraph/about',...
# 26  {'id': 265094381, 'name': 'Lombiq/Testing-Tool...
# 27  {'id': 299784439, 'name': 'aochoae/checkdigit-...
# 28  {'id': 294813047, 'name': 'mono57/genoskul-app...
# 29  {'id': 29078997, 'name': 'dotnet/roslyn', 'url...
#
#                                               payload  public  \
# 0                               {'action': 'started'}    True
# 1   {'push_id': 7935112919, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 7935112909, 'size': 1, 'distinct_s...    True
# 3   {'action': 'opened', 'number': 5, 'pull_reques...    True
# 4   {'push_id': 7935112912, 'size': 1, 'distinct_s...    True
# 5   {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 6   {'push_id': 7935112907, 'size': 1, 'distinct_s...    True
# 7                               {'action': 'started'}    True
# 8   {'push_id': 7935112887, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 7935112882, 'size': 1, 'distinct_s...    True
# 10  {'ref': '662a361d-84df-46a8-b9ac-8feaca0c55c7'...    True
# 11  {'push_id': 7935112855, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 7935112866, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 7935112847, 'size': 2, 'distinct_s...    True
# 14  {'push_id': 7935112860, 'size': 1, 'distinct_s...    True
# 15  {'action': 'reopened', 'issue': {'url': 'https...    True
# 16  {'ref': 'test', 'ref_type': 'branch', 'master_...    True
# 17  {'ref': 'sec-gpc-29.4.1', 'ref_type': 'branch'...    True
# 18  {'ref': 'renovate/react-17.x', 'ref_type': 'br...    True
# 19  {'push_id': 7935112832, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 7935112851, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 7935112853, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 7935112843, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 7935112838, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 7935112852, 'size': 1, 'distinct_s...    True
# 25  {'action': 'closed', 'number': 4197, 'pull_req...    True
# 26  {'push_id': 7935112848, 'size': 0, 'distinct_s...    True
# 27  {'ref': 'develop', 'ref_type': 'branch', 'mast...    True
# 28  {'action': 'opened', 'number': 14, 'pull_reque...    True
# 29  {'action': 'opened', 'number': 56392, 'pull_re...    True
#
#               created_at                                                org
# 0   2021-09-14T22:14:56Z  {'id': 65478032, 'login': 'bfenetworks', 'grav...
# 1   2021-09-14T22:14:56Z                                                NaN
# 2   2021-09-14T22:14:56Z  {'id': 3979584, 'login': 'sourcegraph', 'grava...
# 3   2021-09-14T22:14:56Z                                                NaN
# 4   2021-09-14T22:14:56Z                                                NaN
# 5   2021-09-14T22:14:56Z                                                NaN
# 6   2021-09-14T22:14:56Z                                                NaN
# 7   2021-09-14T22:14:56Z                                                NaN
# 8   2021-09-14T22:14:55Z                                                NaN
# 9   2021-09-14T22:14:55Z                                                NaN
# 10  2021-09-14T22:14:55Z                                                NaN
# 11  2021-09-14T22:14:55Z                                                NaN
# 12  2021-09-14T22:14:55Z                                                NaN
# 13  2021-09-14T22:14:55Z                                                NaN
# 14  2021-09-14T22:14:55Z                                                NaN
# 15  2021-09-14T22:14:55Z  {'id': 487568, 'login': 'NixOS', 'gravatar_id'...
# 16  2021-09-14T22:14:55Z                                                NaN
# 17  2021-09-14T22:14:55Z                                                NaN
# 18  2021-09-14T22:14:55Z  {'id': 42648621, 'login': 'inabagumi', 'gravat...
# 19  2021-09-14T22:14:55Z                                                NaN
# 20  2021-09-14T22:14:55Z  {'id': 25605372, 'login': 'navgurukul', 'grava...
# 21  2021-09-14T22:14:55Z  {'id': 84018255, 'login': 'shake-lang', 'grava...
# 22  2021-09-14T22:14:55Z                                                NaN
# 23  2021-09-14T22:14:55Z                                                NaN
# 24  2021-09-14T22:14:55Z                                                NaN
# 25  2021-09-14T22:14:55Z  {'id': 3979584, 'login': 'sourcegraph', 'grava...
# 26  2021-09-14T22:14:55Z  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 27  2021-09-14T22:14:55Z                                                NaN
# 28  2021-09-14T22:14:55Z                                                NaN
# 29  2021-09-14T22:14:55Z  {'id': 9141961, 'login': 'dotnet', 'gravatar_i...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id  ... payload.pull_request.merged_by.site_admin
# 0   16781608999  ...                                       NaN
# 1   16781608961  ...                                       NaN
# 2   16781609009  ...                                       NaN
# 3   16781608975  ...                                       NaN
# 4   16781608976  ...                                       NaN
# 5   16781608965  ...                                       NaN
# 6   16781608969  ...                                       NaN
# 7   16781608967  ...                                       NaN
# 8   16781608991  ...                                       NaN
# 9   16781608912  ...                                       NaN
# 10  16781608926  ...                                       NaN
# 11  16781608899  ...                                       NaN
# 12  16781608947  ...                                       NaN
# 13  16781608922  ...                                       NaN
# 14  16781608934  ...                                       NaN
# 15  16781608935  ...                                       NaN
# 16  16781608884  ...                                       NaN
# 17  16781608885  ...                                       NaN
# 18  16781608908  ...                                       NaN
# 19  16781608902  ...                                       NaN
# 20  16781608910  ...                                       NaN
# 21  16781608873  ...                                       NaN
# 22  16781608863  ...                                       NaN
# 23  16781608875  ...                                       NaN
# 24  16781608852  ...                                       NaN
# 25  16781608842  ...                                       NaN
# 26  16781608864  ...                                       NaN
# 27  16781608833  ...                                       NaN
# 28  16781608871  ...                                     False
# 29  16781608837  ...                                       NaN
#
# [30 rows x 523 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '24.8482', 'longitude': '88.2612'},
#  'message': 'success',
#  'timestamp': 1631658021}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1631658033,
#   'latitude': 41.39773,
#   'longitude': 2.19029,
#   'passes': 5},
#  'response': [{'duration': 576, 'risetime': 1631662447},
#   {'duration': 628, 'risetime': 1631668284},
#   {'duration': 651, 'risetime': 1631674093},
#   {'duration': 421, 'risetime': 1631679977},
#   {'duration': 385, 'risetime': 1631728669}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 23, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s")
# Out:
# Timestamp('2020-11-03 22:32:26')

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1,'/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"rh":44,"pod":"d","lon":-4.2,"pres":945.1,"timezone":"Europe\/Madrid","ob_time":"2021-06-15 08:00","country_code":"ES","clouds":75,"ts":1623744000,"solar_rad":378.2,"state_code":"29","city_name":"Zarzalejo","wind_spd":1,"wind_cdir_full":"northeast","wind_cdir":"NE","slp":1018.9,"vis":5,"h_angle":-45,"sunset":"19:48","dni":808.24,"dewpt":12.4,"snow":0,"uv":5.89272,"precip":0,"wind_dir":44,"sunrise":"04:44","ghi":540.97,"dhi":92.52,"aqi":68,"lat":40.55,"weather":{"icon":"c02d","code":802,"description":"Scattered clouds"},"datetime":"2021-06-15:08","temp":25.6,"station":"F7959","elev_angle":34.18,"app_temp":25.4}],"count":1}

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'data': [{'rh': 44, 'pod': 'd', 'lon': -4.2, 'pres': 945.1, 'timezone': 'Europe/Madrid', 'ob_time': '2021-06-15 08:00', 'country_code': 'ES', 'clouds': 75, 'ts': 1623744000, 'solar_rad': 378.2, 'state_code': '29', 'city_name': 'Zarzalejo', 'wind_spd': 1, 'wind_cdir_full': 'northeast', 'wind_cdir': 'NE', 'slp': 1018.9, 'vis': 5, 'h_angle': -45, 'sunset': '19:48', 'dni': 808.24, 'dewpt': 12.4, 'snow': 0, 'uv': 5.89272, 'precip': 0, 'wind_dir': 44, 'sunrise': '04:44', 'ghi': 540.97, 'dhi': 92.52, 'aqi': 68, 'lat': 40.55, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'datetime': '2021-06-15:08', 'temp': 25.6, 'station': 'F7959', 'elev_angle': 34.18, 'app_temp': 25.4}], 'count': 1}
# dict

# %%
results.keys()
# Out:
# dict_keys(['data', 'count'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...

# %%
results['data']
# Out:
# [{'app_temp': 22.4,
#   'clouds': 69,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 69,
#   'datetime': '2021-06-15:09',
#   'dewpt': 7.9,
#   'dhi': 103.41,
#   'dni': 868.79,
#   'ghi': 717.09,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.001953125,
#   'pres': 884.145,
#   'rh': 39,
#   'slp': 1018.79,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 564.782,
#   'temp': 23,
#   'timestamp_local': '2021-06-15T11:00:00',
#   'timestamp_utc': '2021-06-15T09:00:00',
#   'ts': 1623747600,
#   'uv': 2.81755,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 78,
#   'wind_gust_spd': 11.5571,
#   'wind_spd': 4.07371},
#  {'app_temp': 26.2,
#   'clouds': 38,
#   'clouds_hi': 2,
#   'clouds_low': 0,
#   'clouds_mid': 39,
#   'datetime': '2021-06-15:12',
#   'dewpt': 6,
#   'dhi': 117.62,
#   'dni': 937.94,
#   'ghi': 1002.88,
#   'ozone': 328,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.112,
#   'rh': 27,
#   'slp': 1016.89,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 974.853,
#   'temp': 26.8,
#   'timestamp_local': '2021-06-15T14:00:00',
#   'timestamp_utc': '2021-06-15T12:00:00',
#   'ts': 1623758400,
#   'uv': 7.58151,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 111,
#   'wind_gust_spd': 11.7118,
#   'wind_spd': 5.50618},
#  {'app_temp': 26.9,
#   'clouds': 76,
#   'clouds_hi': 43,
#   'clouds_low': 0,
#   'clouds_mid': 56,
#   'datetime': '2021-06-15:15',
#   'dewpt': 5.4,
#   'dhi': 107.98,
#   'dni': 892.15,
#   'ghi': 801.62,
#   'ozone': 323,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.048828125,
#   'pres': 881.339,
#   'rh': 24,
#   'slp': 1014.46,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 565.139,
#   'temp': 28.1,
#   'timestamp_local': '2021-06-15T17:00:00',
#   'timestamp_utc': '2021-06-15T15:00:00',
#   'ts': 1623769200,
#   'uv': 3.15302,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 164,
#   'wind_gust_spd': 12.2921,
#   'wind_spd': 4.28592},
#  {'app_temp': 25.8,
#   'clouds': 80,
#   'clouds_hi': 12,
#   'clouds_low': 0,
#   'clouds_mid': 78,
#   'datetime': '2021-06-15:18',
#   'dewpt': 6,
#   'dhi': 68.69,
#   'dni': 647.18,
#   'ghi': 262.69,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.021484375,
#   'pres': 880.719,
#   'rh': 28,
#   'slp': 1013.91,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 170.431,
#   'temp': 26.4,
#   'timestamp_local': '2021-06-15T20:00:00',
#   'timestamp_utc': '2021-06-15T18:00:00',
#   'ts': 1623780000,
#   'uv': 0.813903,
#   'vis': 19.2,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 169,
#   'wind_gust_spd': 10.1157,
#   'wind_spd': 4.75035},
#  {'app_temp': 20.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 8,
#   'clouds_mid': 81,
#   'datetime': '2021-06-15:21',
#   'dewpt': 9.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 319,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.095703125,
#   'pres': 881.045,
#   'rh': 48,
#   'slp': 1015.38,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-06-15T23:00:00',
#   'timestamp_utc': '2021-06-15T21:00:00',
#   'ts': 1623790800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 7.37562,
#   'wind_spd': 2.08412},
#  {'app_temp': 18.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 4,
#   'clouds_mid': 70,
#   'datetime': '2021-06-16:00',
#   'dewpt': 11.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 324.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.33984375,
#   'pres': 881.915,
#   'rh': 67,
#   'slp': 1017.05,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2021-06-16T02:00:00',
#   'timestamp_utc': '2021-06-16T00:00:00',
#   'ts': 1623801600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 90,
#   'wind_gust_spd': 9.4193,
#   'wind_spd': 1.0167},
#  {'app_temp': 17.4,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 24,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:03',
#   'dewpt': 11,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 323,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.068359375,
#   'pres': 879.474,
#   'rh': 67,
#   'slp': 1014.45,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.4,
#   'timestamp_local': '2021-06-16T05:00:00',
#   'timestamp_utc': '2021-06-16T03:00:00',
#   'ts': 1623812400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 11.6762,
#   'wind_spd': 3.34812},
#  {'app_temp': 17,
#   'clouds': 62,
#   'clouds_hi': 0,
#   'clouds_low': 21,
#   'clouds_mid': 54,
#   'datetime': '2021-06-16:06',
#   'dewpt': 10.8,
#   'dhi': 55.42,
#   'dni': 536.17,
#   'ghi': 159.75,
#   'ozone': 321.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.611,
#   'rh': 69,
#   'slp': 1014.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.165,
#   'temp': 17,
#   'timestamp_local': '2021-06-16T08:00:00',
#   'timestamp_utc': '2021-06-16T06:00:00',
#   'ts': 1623823200,
#   'uv': 0.894861,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 11.2242,
#   'wind_spd': 2.06524},
#  {'app_temp': 19.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 30,
#   'clouds_mid': 51,
#   'datetime': '2021-06-16:09',
#   'dewpt': 11.3,
#   'dhi': 103.38,
#   'dni': 868.55,
#   'ghi': 716.68,
#   'ozone': 318.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.427,
#   'rh': 60,
#   'slp': 1014.29,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 179.17,
#   'temp': 19.7,
#   'timestamp_local': '2021-06-16T11:00:00',
#   'timestamp_utc': '2021-06-16T09:00:00',
#   'ts': 1623834000,
#   'uv': 1.67897,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 97,
#   'wind_gust_spd': 11.2175,
#   'wind_spd': 2.20589},
#  {'app_temp': 22.9,
#   'clouds': 56,
#   'clouds_hi': 8,
#   'clouds_low': 30,
#   'clouds_mid': 38,
#   'datetime': '2021-06-16:12',
#   'dewpt': 11.1,
#   'dhi': 117.6,
#   'dni': 937.81,
#   'ghi': 1002.87,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.146484375,
#   'pres': 878.984,
#   'rh': 48,
#   'slp': 1013.18,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 898.122,
#   'temp': 23.2,
#   'timestamp_local': '2021-06-16T14:00:00',
#   'timestamp_utc': '2021-06-16T12:00:00',
#   'ts': 1623844800,
#   'uv': 6.33404,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 13.1602,
#   'wind_spd': 4.33191},
#  {'app_temp': 23.8,
#   'clouds': 82,
#   'clouds_hi': 8,
#   'clouds_low': 64,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:15',
#   'dewpt': 8.7,
#   'dhi': 108,
#   'dni': 892.19,
#   'ghi': 802.25,
#   'ozone': 328.25,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.01171875,
#   'pres': 876.801,
#   'rh': 38,
#   'slp': 1010.28,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 495.815,
#   'temp': 24.3,
#   'timestamp_local': '2021-06-16T17:00:00',
#   'timestamp_utc': '2021-06-16T15:00:00',
#   'ts': 1623855600,
#   'uv': 2.88811,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 194,
#   'wind_gust_spd': 13.1986,
#   'wind_spd': 6.2823},
#  {'app_temp': 22.4,
#   'clouds': 82,
#   'clouds_hi': 19,
#   'clouds_low': 56,
#   'clouds_mid': 69,
#   'datetime': '2021-06-16:18',
#   'dewpt': 9.1,
#   'dhi': 68.79,
#   'dni': 647.94,
#   'ghi': 263.66,
#   'ozone': 326.75,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.06640625,
#   'pres': 876.411,
#   'rh': 42,
#   'slp': 1010.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 162.95,
#   'temp': 22.9,
#   'timestamp_local': '2021-06-16T20:00:00',
#   'timestamp_utc': '2021-06-16T18:00:00',
#   'ts': 1623866400,
#   'uv': 0.793887,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 220,
#   'wind_gust_spd': 11.1933,
#   'wind_spd': 3.96155},
#  {'app_temp': 18.1,
#   'clouds': 94,
#   'clouds_hi': 62,
#   'clouds_low': 56,
#   'clouds_mid': 84,
#   'datetime': '2021-06-16:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.193359375,
#   'pres': 878.112,
#   'rh': 59,
#   'slp': 1012.83,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.6,
#   'timestamp_local': '2021-06-16T23:00:00',
#   'timestamp_utc': '2021-06-16T21:00:00',
#   'ts': 1623877200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 7.01437,
#   'wind_spd': 1.32861},
#  {'app_temp': 15.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2021-06-17:00',
#   'dewpt': 10.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.269,
#   'rh': 72,
#   'slp': 1012.48,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 15.8,
#   'timestamp_local': '2021-06-17T02:00:00',
#   'timestamp_utc': '2021-06-17T00:00:00',
#   'ts': 1623888000,
#   'uv': 0,
#   'vis': 10.008,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 327,
#   'wind_gust_spd': 6.08424,
#   'wind_spd': 1.71289},
#  {'app_temp': 14.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 27,
#   'clouds_mid': 2,
#   'datetime': '2021-06-17:03',
#   'dewpt': 10.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 330.75,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.7,
#   'rh': 78,
#   'slp': 1011.99,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.8,
#   'timestamp_local': '2021-06-17T05:00:00',
#   'timestamp_utc': '2021-06-17T03:00:00',
#   'ts': 1623898800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 2,
#   'wind_gust_spd': 5.55667,
#   'wind_spd': 1.72096},
#  {'app_temp': 15.5,
#   'clouds': 88,
#   'clouds_hi': 67,
#   'clouds_low': 37,
#   'clouds_mid': 45,
#   'datetime': '2021-06-17:06',
#   'dewpt': 11.7,
#   'dhi': 55.36,
#   'dni': 535.63,
#   'ghi': 159.4,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.228,
#   'rh': 80,
#   'slp': 1011.42,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 81.9911,
#   'temp': 15.5,
#   'timestamp_local': '2021-06-17T08:00:00',
#   'timestamp_utc': '2021-06-17T06:00:00',
#   'ts': 1623909600,
#   'uv': 0.608304,
#   'vis': 10.728,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 4.37833,
#   'wind_spd': 1.08316},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 72,
#   'clouds_mid': 30,
#   'datetime': '2021-06-17:09',
#   'dewpt': 13.5,
#   'dhi': 103.34,
#   'dni': 868.31,
#   'ghi': 716.21,
#   'ozone': 339.25,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.75,
#   'pres': 876.576,
#   'rh': 80,
#   'slp': 1011.65,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.08,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T11:00:00',
#   'timestamp_utc': '2021-06-17T09:00:00',
#   'ts': 1623920400,
#   'uv': 1.66392,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 137,
#   'wind_gust_spd': 6.34957,
#   'wind_spd': 1.5818},
#  {'app_temp': 17.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 71,
#   'clouds_mid': 33,
#   'datetime': '2021-06-17:12',
#   'dewpt': 14.6,
#   'dhi': 117.59,
#   'dni': 937.68,
#   'ghi': 1002.82,
#   'ozone': 334.75,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.89453125,
#   'pres': 876.039,
#   'rh': 87,
#   'slp': 1011.09,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 190.536,
#   'temp': 17.1,
#   'timestamp_local': '2021-06-17T14:00:00',
#   'timestamp_utc': '2021-06-17T12:00:00',
#   'ts': 1623931200,
#   'uv': 3.18526,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 116,
#   'wind_gust_spd': 5.97595,
#   'wind_spd': 1.59535},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 73,
#   'clouds_mid': 18,
#   'datetime': '2021-06-17:15',
#   'dewpt': 14.8,
#   'dhi': 108.02,
#   'dni': 892.23,
#   'ghi': 802.82,
#   'ozone': 333,
#   'pod': 'd',
#   'pop': 30,
#   'precip': 0.4140625,
#   'pres': 874.932,
#   'rh': 87,
#   'slp': 1009.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 152.536,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T17:00:00',
#   'timestamp_utc': '2021-06-17T15:00:00',
#   'ts': 1623942000,
#   'uv': 2.05182,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 9.99384,
#   'wind_spd': 1.89453},
#  {'app_temp': 16,
#   'clouds': 79,
#   'clouds_hi': 14,
#   'clouds_low': 73,
#   'clouds_mid': 16,
#   'datetime': '2021-06-17:18',
#   'dewpt': 13.9,
#   'dhi': 68.88,
#   'dni': 648.64,
#   'ghi': 264.57,
#   'ozone': 338.75,
#   'pod': 'd',
#   'pop': 65,
#   'precip': 1.90234375,
#   'pres': 875.149,
#   'rh': 89,
#   'slp': 1010.34,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 168.418,
#   'temp': 16,
#   'timestamp_local': '2021-06-17T20:00:00',
#   'timestamp_utc': '2021-06-17T18:00:00',
#   'ts': 1623952800,
#   'uv': 0.821966,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 55,
#   'wind_gust_spd': 11.0891,
#   'wind_spd': 0.200486},
#  {'app_temp': 14.9,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 49,
#   'clouds_mid': 55,
#   'datetime': '2021-06-17:21',
#   'dewpt': 13.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 344.5,
#   'pod': 'n',
#   'pop': 55,
#   'precip': 1.25390625,
#   'pres': 876.497,
#   'rh': 91,
#   'slp': 1012.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.9,
#   'timestamp_local': '2021-06-17T23:00:00',
#   'timestamp_utc': '2021-06-17T21:00:00',
#   'ts': 1623963600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 33,
#   'wind_gust_spd': 6.10028,
#   'wind_spd': 0.601711},
#  {'app_temp': 13.1,
#   'clouds': 12,
#   'clouds_hi': 2,
#   'clouds_low': 4,
#   'clouds_mid': 5,
#   'datetime': '2021-06-18:00',
#   'dewpt': 11.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.513,
#   'rh': 89,
#   'slp': 1012.39,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.1,
#   'timestamp_local': '2021-06-18T02:00:00',
#   'timestamp_utc': '2021-06-18T00:00:00',
#   'ts': 1623974400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 352,
#   'wind_gust_spd': 4.04717,
#   'wind_spd': 0.758533},
#  {'app_temp': 12,
#   'clouds': 50,
#   'clouds_hi': 1,
#   'clouds_low': 50,
#   'clouds_mid': 2,
#   'datetime': '2021-06-18:03',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.03125,
#   'pres': 876.44,
#   'rh': 92,
#   'slp': 1012.57,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T05:00:00',
#   'timestamp_utc': '2021-06-18T03:00:00',
#   'ts': 1623985200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 345,
#   'wind_gust_spd': 6.70735,
#   'wind_spd': 0.87161},
#  {'app_temp': 12,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 78,
#   'clouds_mid': 30,
#   'datetime': '2021-06-18:06',
#   'dewpt': 10.7,
#   'dhi': 55.29,
#   'dni': 535,
#   'ghi': 158.97,
#   'ozone': 343.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.36,
#   'rh': 93,
#   'slp': 1013.68,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 66.33,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T08:00:00',
#   'timestamp_utc': '2021-06-18T06:00:00',
#   'ts': 1623996000,
#   'uv': 0.593585,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 7.49278,
#   'wind_spd': 0.468219},
#  {'app_temp': 19.7,
#   'clouds': 90,
#   'clouds_hi': 90,
#   'clouds_low': 46,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:09',
#   'dewpt': 8.1,
#   'dhi': 103.3,
#   'dni': 868.06,
#   'ghi': 715.69,
#   'ozone': 345,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 45,
#   'slp': 1012.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 344.066,
#   'temp': 20.5,
#   'timestamp_local': '2021-06-18T11:00:00',
#   'timestamp_utc': '2021-06-18T09:00:00',
#   'ts': 1624006800,
#   'uv': 2.0374,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 138,
#   'wind_gust_spd': 5.41016,
#   'wind_spd': 3.7763},
#  {'app_temp': 22.4,
#   'clouds': 24,
#   'clouds_hi': 2,
#   'clouds_low': 24,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:12',
#   'dewpt': 8.8,
#   'dhi': 117.58,
#   'dni': 937.55,
#   'ghi': 1002.73,
#   'ozone': 344.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 40,
#   'slp': 1012,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 997.187,
#   'temp': 23,
#   'timestamp_local': '2021-06-18T14:00:00',
#   'timestamp_utc': '2021-06-18T12:00:00',
#   'ts': 1624017600,
#   'uv': 8.58676,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 147,
#   'wind_gust_spd': 6.69922,
#   'wind_spd': 4.54761},
#  {'app_temp': 23.5,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 63,
#   'clouds_mid': 32,
#   'datetime': '2021-06-18:15',
#   'dewpt': 7.5,
#   'dhi': 108.04,
#   'dni': 892.26,
#   'ghi': 803.36,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905,
#   'rh': 34,
#   'slp': 1009.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 200.84,
#   'temp': 24.2,
#   'timestamp_local': '2021-06-18T17:00:00',
#   'timestamp_utc': '2021-06-18T15:00:00',
#   'ts': 1624028400,
#   'uv': 2.04829,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 5.91797,
#   'wind_spd': 2.26834},
#  {'app_temp': 22.7,
#   'clouds': 64,
#   'clouds_hi': 57,
#   'clouds_low': 18,
#   'clouds_mid': 19,
#   'datetime': '2021-06-18:18',
#   'dewpt': 8.5,
#   'dhi': 68.97,
#   'dni': 649.29,
#   'ghi': 265.41,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 904.5,
#   'rh': 38,
#   'slp': 1008.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 220.884,
#   'temp': 23.3,
#   'timestamp_local': '2021-06-18T20:00:00',
#   'timestamp_utc': '2021-06-18T18:00:00',
#   'ts': 1624039200,
#   'uv': 0.994731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'WSW',
#   'wind_cdir_full': 'west-southwest',
#   'wind_dir': 239,
#   'wind_gust_spd': 4.63281,
#   'wind_spd': 2.69643},
#  {'app_temp': 18.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 6,
#   'clouds_mid': 79,
#   'datetime': '2021-06-18:21',
#   'dewpt': 7.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 340.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905.5,
#   'rh': 50,
#   'slp': 1010.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2021-06-18T23:00:00',
#   'timestamp_utc': '2021-06-18T21:00:00',
#   'ts': 1624050000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 351,
#   'wind_gust_spd': 2.12695,
#   'wind_spd': 2.41283},
#  {'app_temp': 16.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 99,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:00',
#   'dewpt': 10.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 337.75,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 905.5,
#   'rh': 68,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.1,
#   'timestamp_local': '2021-06-19T02:00:00',
#   'timestamp_utc': '2021-06-19T00:00:00',
#   'ts': 1624060800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 338,
#   'wind_gust_spd': 0.812988,
#   'wind_spd': 0.61213},
#  {'app_temp': 13.4,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:03',
#   'dewpt': 12.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 333.25,
#   'pod': 'n',
#   'pop': 90,
#   'precip': 7.4375,
#   'pres': 905,
#   'rh': 97,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.4,
#   'timestamp_local': '2021-06-19T05:00:00',
#   'timestamp_utc': '2021-06-19T03:00:00',
#   'ts': 1624071600,
#   'uv': 0,
#   'vis': 1.0125,
#   'weather': {'code': 502, 'description': 'Heavy rain', 'icon': 'r03n'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 7.69922,
#   'wind_spd': 4.79758},
#  {'app_temp': 11.7,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:06',
#   'dewpt': 9.4,
#   'dhi': 55.21,
#   'dni': 534.26,
#   'ghi': 158.47,
#   'ozone': 342.75,
#   'pod': 'd',
#   'pop': 40,
#   'precip': 0.6875,
#   'pres': 908,
#   'rh': 86,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 30.1093,
#   'temp': 11.7,
#   'timestamp_local': '2021-06-19T08:00:00',
#   'timestamp_utc': '2021-06-19T06:00:00',
#   'ts': 1624082400,
#   'uv': 0.472565,
#   'vis': 5.4,
#   'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 199,
#   'wind_gust_spd': 5.59766,
#   'wind_spd': 2.69708},
#  {'app_temp': 11.4,
#   'clouds': 100,
#   'clouds_hi': 14,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:09',
#   'dewpt': 10.3,
#   'dhi': 103.26,
#   'dni': 867.79,
#   'ghi': 715.12,
#   'ozone': 350.75,
#   'pod': 'd',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 907.5,
#   'rh': 93,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 71.512,
#   'temp': 11.4,
#   'timestamp_local': '2021-06-19T11:00:00',
#   'timestamp_utc': '2021-06-19T09:00:00',
#   'ts': 1624093200,
#   'uv': 1.65327,
#   'vis': 0.869,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 139,
#   'wind_gust_spd': 4.59766,
#   'wind_spd': 2.73987},
#  {'app_temp': 15.1,
#   'clouds': 92,
#   'clouds_hi': 8,
#   'clouds_low': 92,
#   'clouds_mid': 32,
#   'datetime': '2021-06-19:12',
#   'dewpt': 10,
#   'dhi': 117.56,
#   'dni': 937.42,
#   'ghi': 1002.62,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.0625,
#   'pres': 907.5,
#   'rh': 72,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 434.972,
#   'temp': 15.1,
#   'timestamp_local': '2021-06-19T14:00:00',
#   'timestamp_utc': '2021-06-19T12:00:00',
#   'ts': 1624104000,
#   'uv': 3.7363,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 162,
#   'wind_gust_spd': 3.10547,
#   'wind_spd': 2.37379},
#  {'app_temp': 18,
#   'clouds': 69,
#   'clouds_hi': 55,
#   'clouds_low': 40,
#   'clouds_mid': 56,
#   'datetime': '2021-06-19:15',
#   'dewpt': 9.3,
#   'dhi': 108.05,
#   'dni': 892.29,
#   'ghi': 803.85,
#   'ozone': 352.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 56,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 633.115,
#   'temp': 18,
#   'timestamp_local': '2021-06-19T17:00:00',
#   'timestamp_utc': '2021-06-19T15:00:00',
#   'ts': 1624114800,
#   'uv': 3.45731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 3.32227,
#   'wind_spd': 2.62303},
#  {'app_temp': 18.1,
#   'clouds': 10,
#   'clouds_hi': 10,
#   'clouds_low': 1,
#   'clouds_mid': 6,
#   'datetime': '2021-06-19:18',
#   'dewpt': 8.7,
#   'dhi': 69.05,
#   'dni': 649.88,
#   'ghi': 266.18,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 54,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 266.103,
#   'temp': 18.1,
#   'timestamp_local': '2021-06-19T20:00:00',
#   'timestamp_utc': '2021-06-19T18:00:00',
#   'ts': 1624125600,
#   'uv': 1.657,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 3.30078,
#   'wind_spd': 2.27588},
#  {'app_temp': 14,
#   'clouds': 100,
#   'clouds_hi': 21,
#   'clouds_low': 3,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:21',
#   'dewpt': 9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 347.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 72,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14,
#   'timestamp_local': '2021-06-19T23:00:00',
#   'timestamp_utc': '2021-06-19T21:00:00',
#   'ts': 1624136400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 1.125,
#   'wind_spd': 0.953986},
#  {'app_temp': 12.7,
#   'clouds': 64,
#   'clouds_hi': 64,
#   'clouds_low': 2,
#   'clouds_mid': 5,
#   'datetime': '2021-06-20:00',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 348.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 79,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12.7,
#   'timestamp_local': '2021-06-20T02:00:00',
#   'timestamp_utc': '2021-06-20T00:00:00',
#   'ts': 1624147200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 343,
#   'wind_gust_spd': 0.899902,
#   'wind_spd': 0.956497},
#  {'app_temp': 11.6,
#   'clouds': 72,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 72,
#   'datetime': '2021-06-20:03',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 350.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.3125,
#   'pres': 908.5,
#   'rh': 85,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 11.6,
#   'timestamp_local': '2021-06-20T05:00:00',
#   'timestamp_utc': '2021-06-20T03:00:00',
#   'ts': 1624158000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 6,
#   'wind_gust_spd': 1.10254,
#   'wind_spd': 1.19666},
#  {'app_temp': 13,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 22,
#   'clouds_mid': 88,
#   'datetime': '2021-06-20:06',
#   'dewpt': 10.2,
#   'dhi': 55.12,
#   'dni': 533.43,
#   'ghi': 157.9,
#   'ozone': 352,
#   'pod': 'd',
#   'pop': 50,
#   'precip': 1.0625,
#   'pres': 908,
#   'rh': 83,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 73.4744,
#   'temp': 13,
#   'timestamp_local': '2021-06-20T08:00:00',
#   'timestamp_utc': '2021-06-20T06:00:00',
#   'ts': 1624168800,
#   'uv': 0.586461,
#   'vis': 12.568,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 348,
#   'wind_gust_spd': 0.911621,
#   'wind_spd': 0.800612}]

# %%
len(results['data'])
# Out:
# 40
