# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results
# Out:
# 200
# [{'completed': False, 'id': 1, 'title': 'delectus aut autem', 'userId': 1},
#  {'completed': False,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'userId': 1},
#  {'completed': False, 'id': 3, 'title': 'fugiat veniam minus', 'userId': 1},
#  {'completed': True, 'id': 4, 'title': 'et porro tempora', 'userId': 1},
#  {'completed': False,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'userId': 1},
#  {'completed': False,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'userId': 1},
#  {'completed': False,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'userId': 1},
#  {'completed': True,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'userId': 1},
#  {'completed': False,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'userId': 1},
#  {'completed': True,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'userId': 1},
#  {'completed': True,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'userId': 1},
#  {'completed': True,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'userId': 1},
#  {'completed': False, 'id': 13, 'title': 'et doloremque nulla', 'userId': 1},
#  {'completed': True,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'userId': 1},
#  {'completed': True,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'userId': 1},
#  {'completed': True,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'userId': 1},
#  {'completed': True,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'userId': 1},
#  {'completed': False,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'userId': 1},
#  {'completed': True,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'userId': 1},
#  {'completed': True,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'userId': 1},
#  {'completed': False,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'userId': 2},
#  {'completed': True,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'userId': 2},
#  {'completed': False,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'userId': 2},
#  {'completed': False,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'userId': 2},
#  {'completed': True,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'userId': 2},
#  {'completed': True, 'id': 26, 'title': 'aliquam aut quasi', 'userId': 2},
#  {'completed': True,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'userId': 2},
#  {'completed': False,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'userId': 2},
#  {'completed': False, 'id': 29, 'title': 'laborum aut in quam', 'userId': 2},
#  {'completed': True,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'userId': 2},
#  {'completed': False,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'userId': 2},
#  {'completed': False,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'userId': 2},
#  {'completed': False, 'id': 33, 'title': 'sint sit aut vero', 'userId': 2},
#  {'completed': False,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'userId': 2},
#  {'completed': True,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'userId': 2},
#  {'completed': True,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'userId': 2},
#  {'completed': False, 'id': 37, 'title': 'sunt cum tempora', 'userId': 2},
#  {'completed': False, 'id': 38, 'title': 'totam quia non', 'userId': 2},
#  {'completed': False,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'userId': 2},
#  {'completed': True,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'userId': 2},
#  {'completed': False,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'userId': 3},
#  {'completed': False,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'userId': 3},
#  {'completed': True,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'userId': 3},
#  {'completed': True,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'userId': 3},
#  {'completed': False,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'userId': 3},
#  {'completed': False,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'userId': 3},
#  {'completed': False,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'userId': 3},
#  {'completed': False,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'userId': 3},
#  {'completed': False,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'userId': 3},
#  {'completed': True,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'userId': 3},
#  {'completed': False,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'userId': 3},
#  {'completed': False,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'userId': 3},
#  {'completed': False,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'userId': 3},
#  {'completed': True,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'userId': 3},
#  {'completed': True,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'userId': 3},
#  {'completed': True,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'userId': 3},
#  {'completed': False,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'userId': 3},
#  {'completed': False,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'userId': 3},
#  {'completed': False,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'userId': 3},
#  {'completed': True,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'userId': 3},
#  {'completed': True,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'userId': 4},
#  {'completed': False,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'userId': 4},
#  {'completed': True,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'userId': 4},
#  {'completed': False,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'userId': 4},
#  {'completed': False,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'userId': 4},
#  {'completed': False,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'userId': 4},
#  {'completed': False,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'userId': 4},
#  {'completed': False,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'userId': 4},
#  {'completed': False,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'userId': 4},
#  {'completed': False,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'userId': 4},
#  {'completed': False, 'id': 71, 'title': 'aut velit saepe ullam', 'userId': 4},
#  {'completed': False,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'userId': 4},
#  {'completed': True,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'userId': 4},
#  {'completed': False,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'userId': 4},
#  {'completed': False,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'userId': 4},
#  {'completed': True, 'id': 76, 'title': 'sequi dolorem sed', 'userId': 4},
#  {'completed': False,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'userId': 4},
#  {'completed': False,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'userId': 4},
#  {'completed': True, 'id': 79, 'title': 'eum ipsa maxime ut', 'userId': 4},
#  {'completed': True,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'userId': 4},
#  {'completed': True, 'id': 81, 'title': 'suscipit qui totam', 'userId': 5},
#  {'completed': False,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'userId': 5},
#  {'completed': True,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'userId': 5},
#  {'completed': False,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'userId': 5},
#  {'completed': True, 'id': 85, 'title': 'et quia ad iste a', 'userId': 5},
#  {'completed': True,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'userId': 5},
#  {'completed': True,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'userId': 5},
#  {'completed': False,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'userId': 5},
#  {'completed': True, 'id': 89, 'title': 'sequi ut omnis et', 'userId': 5},
#  {'completed': True,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'userId': 5},
#  {'completed': True,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'userId': 5},
#  {'completed': True, 'id': 92, 'title': 'in omnis laboriosam', 'userId': 5},
#  {'completed': True,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'userId': 5},
#  {'completed': False,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'userId': 5},
#  {'completed': True,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'userId': 5},
#  {'completed': False,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'userId': 5},
#  {'completed': False,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'userId': 5},
#  {'completed': True,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'userId': 5},
#  {'completed': False,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'userId': 5},
#  {'completed': False,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'userId': 5},
#  {'completed': False,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'userId': 6},
#  {'completed': False, 'id': 102, 'title': 'sed ab consequatur', 'userId': 6},
#  {'completed': False,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'userId': 6},
#  {'completed': False,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'userId': 6},
#  {'completed': True,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'userId': 6},
#  {'completed': True,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'userId': 6},
#  {'completed': False,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'userId': 6},
#  {'completed': True,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'userId': 6},
#  {'completed': True,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'userId': 6},
#  {'completed': True, 'id': 110, 'title': 'aut aut ea corporis', 'userId': 6},
#  {'completed': False,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'userId': 6},
#  {'completed': False,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'userId': 6},
#  {'completed': False,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'userId': 6},
#  {'completed': False,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'userId': 6},
#  {'completed': False, 'id': 115, 'title': 'sed et ea eum', 'userId': 6},
#  {'completed': True,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'userId': 6},
#  {'completed': False,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'userId': 6},
#  {'completed': False,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'userId': 6},
#  {'completed': False,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'userId': 6},
#  {'completed': False,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'userId': 6},
#  {'completed': True,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'userId': 7},
#  {'completed': True,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'userId': 7},
#  {'completed': False,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'userId': 7},
#  {'completed': False, 'id': 124, 'title': 'qui consectetur id', 'userId': 7},
#  {'completed': False,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'userId': 7},
#  {'completed': True,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'userId': 7},
#  {'completed': True,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'userId': 7},
#  {'completed': False,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'userId': 7},
#  {'completed': False,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'userId': 7},
#  {'completed': True,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'userId': 7},
#  {'completed': False, 'id': 131, 'title': 'qui ea incidunt quis', 'userId': 7},
#  {'completed': True,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'userId': 7},
#  {'completed': True,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'userId': 7},
#  {'completed': False,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'userId': 7},
#  {'completed': False,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'userId': 7},
#  {'completed': False,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'userId': 7},
#  {'completed': False, 'id': 137, 'title': 'qui sit non', 'userId': 7},
#  {'completed': True,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'userId': 7},
#  {'completed': False,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'userId': 7},
#  {'completed': True,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'userId': 7},
#  {'completed': True,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'userId': 8},
#  {'completed': True,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'userId': 8},
#  {'completed': False,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'userId': 8},
#  {'completed': False,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'userId': 8},
#  {'completed': False,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'userId': 8},
#  {'completed': True,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'userId': 8},
#  {'completed': True,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'userId': 8},
#  {'completed': False,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'userId': 8},
#  {'completed': False,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'userId': 8},
#  {'completed': False,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'userId': 8},
#  {'completed': True,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'userId': 8},
#  {'completed': False,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'userId': 8},
#  {'completed': False,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'userId': 8},
#  {'completed': True, 'id': 154, 'title': 'rerum non ex sapiente', 'userId': 8},
#  {'completed': True,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'userId': 8},
#  {'completed': True,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'userId': 8},
#  {'completed': True,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'userId': 8},
#  {'completed': True,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'userId': 8},
#  {'completed': True,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'userId': 8},
#  {'completed': False,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'userId': 8},
#  {'completed': True,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'userId': 9},
#  {'completed': True,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'userId': 9},
#  {'completed': False,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'userId': 9},
#  {'completed': False,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'userId': 9},
#  {'completed': False,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'userId': 9},
#  {'completed': False,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'userId': 9},
#  {'completed': False,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'userId': 9},
#  {'completed': False,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'userId': 9},
#  {'completed': True,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'userId': 9},
#  {'completed': False,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'userId': 9},
#  {'completed': True,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'userId': 9},
#  {'completed': False,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'userId': 9},
#  {'completed': False,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'userId': 9},
#  {'completed': False, 'id': 174, 'title': 'similique aut quo', 'userId': 9},
#  {'completed': True,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'userId': 9},
#  {'completed': False,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'userId': 9},
#  {'completed': False,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'userId': 9},
#  {'completed': True,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'userId': 9},
#  {'completed': True,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'userId': 9},
#  {'completed': True,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'userId': 9},
#  {'completed': False,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'userId': 10},
#  {'completed': True,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'userId': 10},
#  {'completed': True,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'userId': 10},
#  {'completed': False,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'userId': 10},
#  {'completed': False,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'userId': 10},
#  {'completed': False,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'userId': 10},
#  {'completed': False,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'userId': 10},
#  {'completed': True, 'id': 188, 'title': 'vel non beatae est', 'userId': 10},
#  {'completed': True,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'userId': 10},
#  {'completed': True,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'userId': 10},
#  {'completed': True,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'userId': 10},
#  {'completed': False,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'userId': 10},
#  {'completed': True,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'userId': 10},
#  {'completed': False,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'userId': 10},
#  {'completed': True,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'userId': 10},
#  {'completed': True,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'userId': 10},
#  {'completed': True,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'userId': 10},
#  {'completed': True,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'userId': 10},
#  {'completed': True,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'userId': 10},
#  {'completed': False,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'userId': 10}]

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/56565392?',
#    'display_login': 'ArielLahiany',
#    'gravatar_id': '',
#    'id': 56565392,
#    'login': 'ArielLahiany',
#    'url': 'https://api.github.com/users/ArielLahiany'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608999',
#   'payload': {'before': '617047862b0fb71f1579bc77781132974785b6f1',
#    'commits': [{'author': {'email': 'ariel.lahiany@gmail.com',
#       'name': 'ariel.lahiany'},
#      'distinct': True,
#      'message': 'Adding Celery and Beat to the project.',
#      'sha': '0726725380a45fc746705d91166592655925609a',
#      'url': 'https://api.github.com/repos/ArielLahiany/saleor/commits/0726725380a45fc746705d91166592655925609a'}],
#    'distinct_size': 1,
#    'head': '0726725380a45fc746705d91166592655925609a',
#    'push_id': 7328944741,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 376832599,
#    'name': 'ArielLahiany/saleor',
#    'url': 'https://api.github.com/repos/ArielLahiany/saleor'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/74113347?',
#    'display_login': 'commit-b0t',
#    'gravatar_id': '',
#    'id': 74113347,
#    'login': 'commit-b0t',
#    'url': 'https://api.github.com/users/commit-b0t'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608961',
#   'payload': {'before': '57b34866aea542ac0cba0c475614bca6e12d76f9',
#    'commits': [{'author': {'email': '74113347+commit-b0t@users.noreply.github.com',
#       'name': 'Commit'},
#      'distinct': True,
#      'message': 'chore: updated README.md',
#      'sha': 'a5d205b0a4c9a3974ee1a805afe36e101fcc2424',
#      'url': 'https://api.github.com/repos/commit-b0t/commit-b0t/commits/a5d205b0a4c9a3974ee1a805afe36e101fcc2424'}],
#    'distinct_size': 1,
#    'head': 'a5d205b0a4c9a3974ee1a805afe36e101fcc2424',
#    'push_id': 7328944712,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 310908821,
#    'name': 'commit-b0t/commit-b0t',
#    'url': 'https://api.github.com/repos/commit-b0t/commit-b0t'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/16033201?',
#    'display_login': 'fbs2112',
#    'gravatar_id': '',
#    'id': 16033201,
#    'login': 'fbs2112',
#    'url': 'https://api.github.com/users/fbs2112'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781609009',
#   'payload': {'before': 'b113a0aba56300468244a9e4f59138680a7c3f6f',
#    'commits': [{'author': {'email': 'fbs@pol.ufrj.br', 'name': 'fbs2112'},
#      'distinct': True,
#      'message': 'New script to analyse the mitigation results using NMF',
#      'sha': '864001e303887bd2156f4a437f9c3cdff94f12b7',
#      'url': 'https://api.github.com/repos/fbs2112/PhD_codes/commits/864001e303887bd2156f4a437f9c3cdff94f12b7'}],
#    'distinct_size': 1,
#    'head': '864001e303887bd2156f4a437f9c3cdff94f12b7',
#    'push_id': 7328944736,
#    'ref': 'refs/heads/master',
#    'size': 1},
#   'public': True,
#   'repo': {'id': 165776789,
#    'name': 'fbs2112/PhD_codes',
#    'url': 'https://api.github.com/repos/fbs2112/PhD_codes'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'id': 10810283,
#    'login': 'direwolf-github',
#    'url': 'https://api.github.com/users/direwolf-github'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608975',
#   'payload': {'action': 'closed',
#    'number': 1,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/1/comments'},
#      'commits': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1/commits'},
#      'html': {'href': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/1'},
#      'review_comment': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1/comments'},
#      'self': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1'},
#      'statuses': {'href': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/statuses/f73210ceb934fedf48f4f1ab48591efe2501ccc5'}},
#     'active_lock_reason': None,
#     'additions': 1,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'base': {'label': 'direwolf-github:master',
#      'ref': 'master',
#      'repo': {'archive_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/branches{/branch}',
#       'clone_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028.git',
#       'collaborators_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/contributors',
#       'created_at': '2021-06-15T08:09:28Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/downloads',
#       'events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/forks',
#       'full_name': 'direwolf-github/ephemeral-ci-4aa56028',
#       'git_commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/tags{/sha}',
#       'git_url': 'git://github.com/direwolf-github/ephemeral-ci-4aa56028.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/hooks',
#       'html_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028',
#       'id': 377085640,
#       'issue_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/labels{/name}',
#       'language': None,
#       'languages_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/merges',
#       'milestones_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/milestones{/number}',
#       'mirror_url': None,
#       'name': 'ephemeral-ci-4aa56028',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzcwODU2NDA=',
#       'notifications_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?v=4',
#        'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#        'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/direwolf-github',
#        'id': 10810283,
#        'login': 'direwolf-github',
#        'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#        'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#        'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#        'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/direwolf-github'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:47Z',
#       'releases_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/releases{/id}',
#       'size': 0,
#       'ssh_url': 'git@github.com:direwolf-github/ephemeral-ci-4aa56028.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/stargazers',
#       'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/subscribers',
#       'subscription_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/subscription',
#       'svn_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028',
#       'tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/tags',
#       'teams_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/teams',
#       'trees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/trees{/sha}',
#       'updated_at': '2021-06-15T08:09:33Z',
#       'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': '848c163e0b202f0dc413540f08b0fcbbe28dddb4',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?v=4',
#       'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#       'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/direwolf-github',
#       'id': 10810283,
#       'login': 'direwolf-github',
#       'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#       'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#       'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#       'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/direwolf-github'}},
#     'body': 'Direwolf review apps test branch-e3221841',
#     'changed_files': 1,
#     'closed_at': '2021-06-15T08:09:48Z',
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/1/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1/commits',
#     'created_at': '2021-06-15T08:09:35Z',
#     'deletions': 0,
#     'diff_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028/pull/1.diff',
#     'draft': False,
#     'head': {'label': 'direwolf-github:branch-e3221841',
#      'ref': 'branch-e3221841',
#      'repo': {'archive_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/branches{/branch}',
#       'clone_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028.git',
#       'collaborators_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/contributors',
#       'created_at': '2021-06-15T08:09:28Z',
#       'default_branch': 'master',
#       'deployments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/deployments',
#       'description': None,
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/downloads',
#       'events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/forks',
#       'full_name': 'direwolf-github/ephemeral-ci-4aa56028',
#       'git_commits_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/tags{/sha}',
#       'git_url': 'git://github.com/direwolf-github/ephemeral-ci-4aa56028.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/hooks',
#       'html_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028',
#       'id': 377085640,
#       'issue_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/labels{/name}',
#       'language': None,
#       'languages_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/merges',
#       'milestones_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/milestones{/number}',
#       'mirror_url': None,
#       'name': 'ephemeral-ci-4aa56028',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzcwODU2NDA=',
#       'notifications_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?v=4',
#        'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#        'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/direwolf-github',
#        'id': 10810283,
#        'login': 'direwolf-github',
#        'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#        'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#        'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#        'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/direwolf-github'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:47Z',
#       'releases_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/releases{/id}',
#       'size': 0,
#       'ssh_url': 'git@github.com:direwolf-github/ephemeral-ci-4aa56028.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/stargazers',
#       'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/subscribers',
#       'subscription_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/subscription',
#       'svn_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028',
#       'tags_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/tags',
#       'teams_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/teams',
#       'trees_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/git/trees{/sha}',
#       'updated_at': '2021-06-15T08:09:33Z',
#       'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': 'f73210ceb934fedf48f4f1ab48591efe2501ccc5',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?v=4',
#       'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#       'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/direwolf-github',
#       'id': 10810283,
#       'login': 'direwolf-github',
#       'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#       'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#       'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#       'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/direwolf-github'}},
#     'html_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028/pull/1',
#     'id': 670174675,
#     'issue_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/issues/1',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': '0aa7c6db4658b757c186f113ad8781af8d742eae',
#     'mergeable': True,
#     'mergeable_state': 'clean',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjcwMTc0Njc1',
#     'number': 1,
#     'patch_url': 'https://github.com/direwolf-github/ephemeral-ci-4aa56028/pull/1.patch',
#     'rebaseable': True,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/statuses/f73210ceb934fedf48f4f1ab48591efe2501ccc5',
#     'title': 'Direwolf review apps test branch-e3221841',
#     'updated_at': '2021-06-15T08:09:48Z',
#     'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028/pulls/1',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?v=4',
#      'events_url': 'https://api.github.com/users/direwolf-github/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/direwolf-github/followers',
#      'following_url': 'https://api.github.com/users/direwolf-github/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/direwolf-github/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/direwolf-github',
#      'id': 10810283,
#      'login': 'direwolf-github',
#      'node_id': 'MDQ6VXNlcjEwODEwMjgz',
#      'organizations_url': 'https://api.github.com/users/direwolf-github/orgs',
#      'received_events_url': 'https://api.github.com/users/direwolf-github/received_events',
#      'repos_url': 'https://api.github.com/users/direwolf-github/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/direwolf-github/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/direwolf-github/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/direwolf-github'}}},
#   'public': True,
#   'repo': {'id': 377085640,
#    'name': 'direwolf-github/ephemeral-ci-4aa56028',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-4aa56028'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'id': 49699333,
#    'login': 'dependabot[bot]',
#    'url': 'https://api.github.com/users/dependabot[bot]'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608976',
#   'payload': {'action': 'opened',
#    'number': 77,
#    'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/77/comments'},
#      'commits': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77/commits'},
#      'html': {'href': 'https://github.com/jorginhodev/boilerplate-nuxt/pull/77'},
#      'issue': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/77'},
#      'review_comment': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/comments{/number}'},
#      'review_comments': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77/comments'},
#      'self': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77'},
#      'statuses': {'href': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/statuses/5d8e888ab4fc8d8ce96693e63adce9a9d435076d'}},
#     'active_lock_reason': None,
#     'additions': 75,
#     'assignee': None,
#     'assignees': [],
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'base': {'label': 'jorginhodev:main',
#      'ref': 'main',
#      'repo': {'archive_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/branches{/branch}',
#       'clone_url': 'https://github.com/jorginhodev/boilerplate-nuxt.git',
#       'collaborators_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/contributors',
#       'created_at': '2021-01-03T19:06:54Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/deployments',
#       'description': 'Boilerplate to streamline application development with NuxtJS.',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/downloads',
#       'events_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/forks',
#       'full_name': 'jorginhodev/boilerplate-nuxt',
#       'git_commits_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/tags{/sha}',
#       'git_url': 'git://github.com/jorginhodev/boilerplate-nuxt.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/hooks',
#       'html_url': 'https://github.com/jorginhodev/boilerplate-nuxt',
#       'id': 326481175,
#       'issue_comment_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/merges',
#       'milestones_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/milestones{/number}',
#       'mirror_url': None,
#       'name': 'boilerplate-nuxt',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjY0ODExNzU=',
#       'notifications_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/11377244?v=4',
#        'events_url': 'https://api.github.com/users/jorginhodev/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/jorginhodev/followers',
#        'following_url': 'https://api.github.com/users/jorginhodev/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jorginhodev/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/jorginhodev',
#        'id': 11377244,
#        'login': 'jorginhodev',
#        'node_id': 'MDQ6VXNlcjExMzc3MjQ0',
#        'organizations_url': 'https://api.github.com/users/jorginhodev/orgs',
#        'received_events_url': 'https://api.github.com/users/jorginhodev/received_events',
#        'repos_url': 'https://api.github.com/users/jorginhodev/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/jorginhodev/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jorginhodev/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/jorginhodev'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:48Z',
#       'releases_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/releases{/id}',
#       'size': 9941,
#       'ssh_url': 'git@github.com:jorginhodev/boilerplate-nuxt.git',
#       'stargazers_count': 1,
#       'stargazers_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/stargazers',
#       'statuses_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/subscription',
#       'svn_url': 'https://github.com/jorginhodev/boilerplate-nuxt',
#       'tags_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/tags',
#       'teams_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/teams',
#       'trees_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/trees{/sha}',
#       'updated_at': '2021-06-11T14:54:02Z',
#       'url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt',
#       'watchers': 1,
#       'watchers_count': 1},
#      'sha': '45e34c77c10153f0ea6d0b6ff589596846f2177d',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/11377244?v=4',
#       'events_url': 'https://api.github.com/users/jorginhodev/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/jorginhodev/followers',
#       'following_url': 'https://api.github.com/users/jorginhodev/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jorginhodev/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/jorginhodev',
#       'id': 11377244,
#       'login': 'jorginhodev',
#       'node_id': 'MDQ6VXNlcjExMzc3MjQ0',
#       'organizations_url': 'https://api.github.com/users/jorginhodev/orgs',
#       'received_events_url': 'https://api.github.com/users/jorginhodev/received_events',
#       'repos_url': 'https://api.github.com/users/jorginhodev/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/jorginhodev/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jorginhodev/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/jorginhodev'}},
#     'body': 'Bumps [nuxt](https://github.com/nuxt/nuxt.js) from 2.15.6 to 2.15.7.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/nuxt/nuxt.js/releases">nuxt\'s releases</a>.</em></p>\n<blockquote>\n<h2>v2.15.7</h2>\n<h3>🔰 Security advisory</h3>\n<p>Please upgrade to <code>nuxt@^2.15.7</code> if using <code>nuxt@2.15.5</code> or <code>nuxt@2.15.6</code></p>\n<h3>🐛 Bug Fixes</h3>\n<ul>\n<li><code>vue-app</code>\n<ul>\n<li><a href="https://github-redirect.dependabot.com/nuxt/nuxt.js/issues/9431">#9431</a> Check whether a route exists within the nuxt app before replacing</li>\n</ul>\n</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/nuxt/nuxt.js/commit/4f370e2043b7731db0e8ef65a4f88431cd8795f3"><code>4f370e2</code></a> v2.15.7</li>\n<li><a href="https://github.com/nuxt/nuxt.js/commit/85615a5dc56a343c8be17d9dbfb6d71551c90e36"><code>85615a5</code></a> fix(vue-app): check whether route exists within nuxt app before replacing (<a href="https://github-redirect.dependabot.com/nuxt/nuxt.js/issues/9">#9</a>...</li>\n<li>See full diff in <a href="https://github.com/nuxt/nuxt.js/compare/v2.15.6...v2.15.7">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=nuxt&package-manager=npm_and_yarn&previous-version=2.15.6&new-version=2.15.7)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>',
#     'changed_files': 2,
#     'closed_at': None,
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/77/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77/commits',
#     'created_at': '2021-06-15T08:09:48Z',
#     'deletions': 75,
#     'diff_url': 'https://github.com/jorginhodev/boilerplate-nuxt/pull/77.diff',
#     'draft': False,
#     'head': {'label': 'jorginhodev:dependabot/npm_and_yarn/nuxt-2.15.7',
#      'ref': 'dependabot/npm_and_yarn/nuxt-2.15.7',
#      'repo': {'archive_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/branches{/branch}',
#       'clone_url': 'https://github.com/jorginhodev/boilerplate-nuxt.git',
#       'collaborators_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/contributors',
#       'created_at': '2021-01-03T19:06:54Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/deployments',
#       'description': 'Boilerplate to streamline application development with NuxtJS.',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/downloads',
#       'events_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/forks',
#       'full_name': 'jorginhodev/boilerplate-nuxt',
#       'git_commits_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/tags{/sha}',
#       'git_url': 'git://github.com/jorginhodev/boilerplate-nuxt.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/hooks',
#       'html_url': 'https://github.com/jorginhodev/boilerplate-nuxt',
#       'id': 326481175,
#       'issue_comment_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/labels{/name}',
#       'language': 'JavaScript',
#       'languages_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/languages',
#       'license': None,
#       'merges_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/merges',
#       'milestones_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/milestones{/number}',
#       'mirror_url': None,
#       'name': 'boilerplate-nuxt',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjY0ODExNzU=',
#       'notifications_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/notifications{?since,all,participating}',
#       'open_issues': 1,
#       'open_issues_count': 1,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/11377244?v=4',
#        'events_url': 'https://api.github.com/users/jorginhodev/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/jorginhodev/followers',
#        'following_url': 'https://api.github.com/users/jorginhodev/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jorginhodev/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/jorginhodev',
#        'id': 11377244,
#        'login': 'jorginhodev',
#        'node_id': 'MDQ6VXNlcjExMzc3MjQ0',
#        'organizations_url': 'https://api.github.com/users/jorginhodev/orgs',
#        'received_events_url': 'https://api.github.com/users/jorginhodev/received_events',
#        'repos_url': 'https://api.github.com/users/jorginhodev/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/jorginhodev/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jorginhodev/subscriptions',
#        'type': 'User',
#        'url': 'https://api.github.com/users/jorginhodev'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:48Z',
#       'releases_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/releases{/id}',
#       'size': 9941,
#       'ssh_url': 'git@github.com:jorginhodev/boilerplate-nuxt.git',
#       'stargazers_count': 1,
#       'stargazers_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/stargazers',
#       'statuses_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/subscription',
#       'svn_url': 'https://github.com/jorginhodev/boilerplate-nuxt',
#       'tags_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/tags',
#       'teams_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/teams',
#       'trees_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/git/trees{/sha}',
#       'updated_at': '2021-06-11T14:54:02Z',
#       'url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt',
#       'watchers': 1,
#       'watchers_count': 1},
#      'sha': '5d8e888ab4fc8d8ce96693e63adce9a9d435076d',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/11377244?v=4',
#       'events_url': 'https://api.github.com/users/jorginhodev/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/jorginhodev/followers',
#       'following_url': 'https://api.github.com/users/jorginhodev/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jorginhodev/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/jorginhodev',
#       'id': 11377244,
#       'login': 'jorginhodev',
#       'node_id': 'MDQ6VXNlcjExMzc3MjQ0',
#       'organizations_url': 'https://api.github.com/users/jorginhodev/orgs',
#       'received_events_url': 'https://api.github.com/users/jorginhodev/received_events',
#       'repos_url': 'https://api.github.com/users/jorginhodev/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/jorginhodev/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jorginhodev/subscriptions',
#       'type': 'User',
#       'url': 'https://api.github.com/users/jorginhodev'}},
#     'html_url': 'https://github.com/jorginhodev/boilerplate-nuxt/pull/77',
#     'id': 670174829,
#     'issue_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/issues/77',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': None,
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': False,
#     'merged_at': None,
#     'merged_by': None,
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjcwMTc0ODI5',
#     'number': 77,
#     'patch_url': 'https://github.com/jorginhodev/boilerplate-nuxt/pull/77.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77/comments',
#     'state': 'open',
#     'statuses_url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/statuses/5d8e888ab4fc8d8ce96693e63adce9a9d435076d',
#     'title': 'Bump nuxt from 2.15.6 to 2.15.7',
#     'updated_at': '2021-06-15T08:09:48Z',
#     'url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt/pulls/77',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/apps/dependabot',
#      'id': 49699333,
#      'login': 'dependabot[bot]',
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'type': 'Bot',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D'}}},
#   'public': True,
#   'repo': {'id': 326481175,
#    'name': 'jorginhodev/boilerplate-nuxt',
#    'url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'id': 49699333,
#    'login': 'dependabot[bot]',
#    'url': 'https://api.github.com/users/dependabot[bot]'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608965',
#   'payload': {'description': 'Boilerplate to streamline application development with NuxtJS.',
#    'master_branch': 'main',
#    'pusher_type': 'user',
#    'ref': 'dependabot/npm_and_yarn/nuxt-2.15.7',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 326481175,
#    'name': 'jorginhodev/boilerplate-nuxt',
#    'url': 'https://api.github.com/repos/jorginhodev/boilerplate-nuxt'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/85929002?',
#    'display_login': 'Nerds737',
#    'gravatar_id': '',
#    'id': 85929002,
#    'login': 'Nerds737',
#    'url': 'https://api.github.com/users/Nerds737'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608969',
#   'payload': {'description': None,
#    'master_branch': 'main',
#    'pusher_type': 'user',
#    'ref': None,
#    'ref_type': 'repository'},
#   'public': True,
#   'repo': {'id': 377085715,
#    'name': 'Nerds737/Nerds',
#    'url': 'https://api.github.com/repos/Nerds737/Nerds'},
#   'type': 'CreateEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'id': 49699333,
#    'login': 'dependabot[bot]',
#    'url': 'https://api.github.com/users/dependabot[bot]'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608967',
#   'payload': {'pusher_type': 'user',
#    'ref': 'dependabot/npm_and_yarn/typescript-eslint/eslint-plugin-4.26.1',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 363534108,
#    'name': 'EnosDomingues/solana-program-hello-world',
#    'url': 'https://api.github.com/repos/EnosDomingues/solana-program-hello-world'},
#   'type': 'DeleteEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/58170926?',
#    'display_login': 'mikehalmamoj',
#    'gravatar_id': '',
#    'id': 58170926,
#    'login': 'mikehalmamoj',
#    'url': 'https://api.github.com/users/mikehalmamoj'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608991',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/2203574?',
#    'gravatar_id': '',
#    'id': 2203574,
#    'login': 'ministryofjustice',
#    'url': 'https://api.github.com/orgs/ministryofjustice'},
#   'payload': {'pusher_type': 'user',
#    'ref': 'mh-DT-1581-telemetry',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 370951976,
#    'name': 'ministryofjustice/hmpps-spring-boot-sqs',
#    'url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs'},
# ...
#        'repos_url': 'https://api.github.com/users/ministryofjustice/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ministryofjustice/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ministryofjustice/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/ministryofjustice'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:47Z',
#       'releases_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/releases{/id}',
#       'size': 180,
#       'ssh_url': 'git@github.com:ministryofjustice/hmpps-spring-boot-sqs.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/stargazers',
#       'statuses_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/subscription',
#       'svn_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs',
#       'tags_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/tags',
#       'teams_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/teams',
#       'trees_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/trees{/sha}',
#       'updated_at': '2021-06-15T08:00:00Z',
#       'url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': 'dcf9db8ab6fbdf909347fd475b05450da5ddff6f',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/2203574?v=4',
#       'events_url': 'https://api.github.com/users/ministryofjustice/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/ministryofjustice/followers',
#       'following_url': 'https://api.github.com/users/ministryofjustice/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ministryofjustice/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/ministryofjustice',
#       'id': 2203574,
#       'login': 'ministryofjustice',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMDM1NzQ=',
#       'organizations_url': 'https://api.github.com/users/ministryofjustice/orgs',
#       'received_events_url': 'https://api.github.com/users/ministryofjustice/received_events',
#       'repos_url': 'https://api.github.com/users/ministryofjustice/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/ministryofjustice/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ministryofjustice/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/ministryofjustice'}},
#     'body': '',
#     'changed_files': 4,
#     'closed_at': '2021-06-15T08:09:47Z',
#     'comments': 0,
#     'comments_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/issues/16/comments',
#     'commits': 1,
#     'commits_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls/16/commits',
#     'created_at': '2021-06-15T08:02:25Z',
#     'deletions': 29,
#     'diff_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs/pull/16.diff',
#     'draft': False,
#     'head': {'label': 'ministryofjustice:mh-DT-1581-telemetry',
#      'ref': 'mh-DT-1581-telemetry',
#      'repo': {'archive_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/{archive_format}{/ref}',
#       'archived': False,
#       'assignees_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/assignees{/user}',
#       'blobs_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/blobs{/sha}',
#       'branches_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/branches{/branch}',
#       'clone_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs.git',
#       'collaborators_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/collaborators{/collaborator}',
#       'comments_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/comments{/number}',
#       'commits_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/commits{/sha}',
#       'compare_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/compare/{base}...{head}',
#       'contents_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/contents/{+path}',
#       'contributors_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/contributors',
#       'created_at': '2021-05-26T07:54:13Z',
#       'default_branch': 'main',
#       'deployments_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/deployments',
#       'description': 'A helper library for ',
#       'disabled': False,
#       'downloads_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/downloads',
#       'events_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/events',
#       'fork': False,
#       'forks': 0,
#       'forks_count': 0,
#       'forks_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/forks',
#       'full_name': 'ministryofjustice/hmpps-spring-boot-sqs',
#       'git_commits_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/commits{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/refs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/tags{/sha}',
#       'git_url': 'git://github.com/ministryofjustice/hmpps-spring-boot-sqs.git',
#       'has_downloads': True,
#       'has_issues': True,
#       'has_pages': False,
#       'has_projects': True,
#       'has_wiki': True,
#       'homepage': None,
#       'hooks_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/hooks',
#       'html_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs',
#       'id': 370951976,
#       'issue_comment_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/issues/comments{/number}',
#       'issue_events_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/issues/events{/number}',
#       'issues_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/issues{/number}',
#       'keys_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/keys{/key_id}',
#       'labels_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/labels{/name}',
#       'language': 'Kotlin',
#       'languages_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/languages',
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'node_id': 'MDc6TGljZW5zZTEz',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit'},
#       'merges_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/merges',
#       'milestones_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/milestones{/number}',
#       'mirror_url': None,
#       'name': 'hmpps-spring-boot-sqs',
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzA5NTE5NzY=',
#       'notifications_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/notifications{?since,all,participating}',
#       'open_issues': 0,
#       'open_issues_count': 0,
#       'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/2203574?v=4',
#        'events_url': 'https://api.github.com/users/ministryofjustice/events{/privacy}',
#        'followers_url': 'https://api.github.com/users/ministryofjustice/followers',
#        'following_url': 'https://api.github.com/users/ministryofjustice/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ministryofjustice/gists{/gist_id}',
#        'gravatar_id': '',
#        'html_url': 'https://github.com/ministryofjustice',
#        'id': 2203574,
#        'login': 'ministryofjustice',
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMDM1NzQ=',
#        'organizations_url': 'https://api.github.com/users/ministryofjustice/orgs',
#        'received_events_url': 'https://api.github.com/users/ministryofjustice/received_events',
#        'repos_url': 'https://api.github.com/users/ministryofjustice/repos',
#        'site_admin': False,
#        'starred_url': 'https://api.github.com/users/ministryofjustice/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ministryofjustice/subscriptions',
#        'type': 'Organization',
#        'url': 'https://api.github.com/users/ministryofjustice'},
#       'private': False,
#       'pulls_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls{/number}',
#       'pushed_at': '2021-06-15T08:09:47Z',
#       'releases_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/releases{/id}',
#       'size': 180,
#       'ssh_url': 'git@github.com:ministryofjustice/hmpps-spring-boot-sqs.git',
#       'stargazers_count': 0,
#       'stargazers_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/stargazers',
#       'statuses_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/statuses/{sha}',
#       'subscribers_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/subscription',
#       'svn_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs',
#       'tags_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/tags',
#       'teams_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/teams',
#       'trees_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/git/trees{/sha}',
#       'updated_at': '2021-06-15T08:00:00Z',
#       'url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs',
#       'watchers': 0,
#       'watchers_count': 0},
#      'sha': 'bd9e41569c2af885cfca38c8938720b457332d94',
#      'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/2203574?v=4',
#       'events_url': 'https://api.github.com/users/ministryofjustice/events{/privacy}',
#       'followers_url': 'https://api.github.com/users/ministryofjustice/followers',
#       'following_url': 'https://api.github.com/users/ministryofjustice/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ministryofjustice/gists{/gist_id}',
#       'gravatar_id': '',
#       'html_url': 'https://github.com/ministryofjustice',
#       'id': 2203574,
#       'login': 'ministryofjustice',
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMDM1NzQ=',
#       'organizations_url': 'https://api.github.com/users/ministryofjustice/orgs',
#       'received_events_url': 'https://api.github.com/users/ministryofjustice/received_events',
#       'repos_url': 'https://api.github.com/users/ministryofjustice/repos',
#       'site_admin': False,
#       'starred_url': 'https://api.github.com/users/ministryofjustice/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ministryofjustice/subscriptions',
#       'type': 'Organization',
#       'url': 'https://api.github.com/users/ministryofjustice'}},
#     'html_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs/pull/16',
#     'id': 670169205,
#     'issue_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/issues/16',
#     'labels': [],
#     'locked': False,
#     'maintainer_can_modify': False,
#     'merge_commit_sha': '435282fafc177c7127b83300c066f754ef67cd13',
#     'mergeable': None,
#     'mergeable_state': 'unknown',
#     'merged': True,
#     'merged_at': '2021-06-15T08:09:47Z',
#     'merged_by': {'avatar_url': 'https://avatars.githubusercontent.com/u/58170926?v=4',
#      'events_url': 'https://api.github.com/users/mikehalmamoj/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/mikehalmamoj/followers',
#      'following_url': 'https://api.github.com/users/mikehalmamoj/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mikehalmamoj/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/mikehalmamoj',
#      'id': 58170926,
#      'login': 'mikehalmamoj',
#      'node_id': 'MDQ6VXNlcjU4MTcwOTI2',
#      'organizations_url': 'https://api.github.com/users/mikehalmamoj/orgs',
#      'received_events_url': 'https://api.github.com/users/mikehalmamoj/received_events',
#      'repos_url': 'https://api.github.com/users/mikehalmamoj/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/mikehalmamoj/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mikehalmamoj/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/mikehalmamoj'},
#     'milestone': None,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NjcwMTY5MjA1',
#     'number': 16,
#     'patch_url': 'https://github.com/ministryofjustice/hmpps-spring-boot-sqs/pull/16.patch',
#     'rebaseable': None,
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'review_comment_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls/comments{/number}',
#     'review_comments': 0,
#     'review_comments_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls/16/comments',
#     'state': 'closed',
#     'statuses_url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/statuses/bd9e41569c2af885cfca38c8938720b457332d94',
#     'title': 'DT-1581 Add telemetry to retry-dlq and purge-queue',
#     'updated_at': '2021-06-15T08:09:47Z',
#     'url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs/pulls/16',
#     'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/58170926?v=4',
#      'events_url': 'https://api.github.com/users/mikehalmamoj/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/mikehalmamoj/followers',
#      'following_url': 'https://api.github.com/users/mikehalmamoj/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mikehalmamoj/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/mikehalmamoj',
#      'id': 58170926,
#      'login': 'mikehalmamoj',
#      'node_id': 'MDQ6VXNlcjU4MTcwOTI2',
#      'organizations_url': 'https://api.github.com/users/mikehalmamoj/orgs',
#      'received_events_url': 'https://api.github.com/users/mikehalmamoj/received_events',
#      'repos_url': 'https://api.github.com/users/mikehalmamoj/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/mikehalmamoj/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mikehalmamoj/subscriptions',
#      'type': 'User',
#      'url': 'https://api.github.com/users/mikehalmamoj'}}},
#   'public': True,
#   'repo': {'id': 370951976,
#    'name': 'ministryofjustice/hmpps-spring-boot-sqs',
#    'url': 'https://api.github.com/repos/ministryofjustice/hmpps-spring-boot-sqs'},
#   'type': 'PullRequestEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'id': 10810283,
#    'login': 'direwolf-github',
#    'url': 'https://api.github.com/users/direwolf-github'},
#   'created_at': '2021-06-15T08:09:48Z',
#   'id': '16781608837',
#   'payload': {'pusher_type': 'user',
#    'ref': 'branch-77779734',
#    'ref_type': 'branch'},
#   'public': True,
#   'repo': {'id': 377085638,
#    'name': 'direwolf-github/ephemeral-ci-23d9ed6b',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-23d9ed6b'},
#   'type': 'DeleteEvent'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id  ...                                                org
# 0   15826270092  ...                                                NaN
# 1   15826270089  ...  {'id': 11848947, 'login': 'navikt', 'gravatar_...
# 2   15826270079  ...                                                NaN
# 3   15826270080  ...  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 4   15826270086  ...                                                NaN
# 5   15826270074  ...                                                NaN
# 6   15826270073  ...                                                NaN
# 7   15826270056  ...                                                NaN
# 8   15826270068  ...                                                NaN
# 9   15826270064  ...                                                NaN
# 10  15826270051  ...                                                NaN
# 11  15826270044  ...  {'id': 11848947, 'login': 'navikt', 'gravatar_...
# 12  15826270034  ...                                                NaN
# 13  15826270035  ...                                                NaN
# 14  15826270011  ...                                                NaN
# 15  15826270015  ...                                                NaN
# 16  15826270021  ...                                                NaN
# 17  15826270016  ...                                                NaN
# 18  15826269997  ...                                                NaN
# 19  15826270001  ...                                                NaN
# 20  15826270002  ...                                                NaN
# 21  15826269999  ...  {'id': 63743711, 'login': 'home-assistant-libs...
# 22  15826270007  ...                                                NaN
# 23  15826269981  ...                                                NaN
# 24  15826269989  ...                                                NaN
# 25  15826269990  ...                                                NaN
# 26  15826269985  ...                                                NaN
# 27  15826269971  ...  {'id': 72631062, 'login': 'BetterDiscord', 'gr...
# 28  15826269956  ...                                                NaN
# 29  15826269935  ...                                                NaN
#
# [30 rows x 8 columns]

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id  ... payload.pull_request.merged_by.site_admin
# 0   16781608999  ...                                       NaN
# 1   16781608961  ...                                       NaN
# 2   16781609009  ...                                       NaN
# 3   16781608975  ...                                       NaN
# 4   16781608976  ...                                       NaN
# 5   16781608965  ...                                       NaN
# 6   16781608969  ...                                       NaN
# 7   16781608967  ...                                       NaN
# 8   16781608991  ...                                       NaN
# 9   16781608912  ...                                       NaN
# 10  16781608926  ...                                       NaN
# 11  16781608899  ...                                       NaN
# 12  16781608947  ...                                       NaN
# 13  16781608922  ...                                       NaN
# 14  16781608934  ...                                       NaN
# 15  16781608935  ...                                       NaN
# 16  16781608884  ...                                       NaN
# 17  16781608885  ...                                       NaN
# 18  16781608908  ...                                       NaN
# 19  16781608902  ...                                       NaN
# 20  16781608910  ...                                       NaN
# 21  16781608873  ...                                       NaN
# 22  16781608863  ...                                       NaN
# 23  16781608875  ...                                       NaN
# 24  16781608852  ...                                       NaN
# 25  16781608842  ...                                       NaN
# 26  16781608864  ...                                       NaN
# 27  16781608833  ...                                       NaN
# 28  16781608871  ...                                     False
# 29  16781608837  ...                                       NaN
#
# [30 rows x 523 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1623745143,
#   'latitude': 41.39773,
#   'longitude': 2.19029,
#   'passes': 5},
#  'response': [{'duration': 652, 'risetime': 1623745425},
#   {'duration': 614, 'risetime': 1623751270},
#   {'duration': 572, 'risetime': 1623757154},
#   {'duration': 620, 'risetime': 1623762991},
#   {'duration': 649, 'risetime': 1623768798}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 22, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s")
# Out:
# Timestamp('2020-11-03 22:32:26')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1,'/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"data":[{"rh":44,"pod":"d","lon":-4.2,"pres":945.1,"timezone":"Europe\/Madrid","ob_time":"2021-06-15 08:00","country_code":"ES","clouds":75,"ts":1623744000,"solar_rad":378.2,"state_code":"29","city_name":"Zarzalejo","wind_spd":1,"wind_cdir_full":"northeast","wind_cdir":"NE","slp":1018.9,"vis":5,"h_angle":-45,"sunset":"19:48","dni":808.24,"dewpt":12.4,"snow":0,"uv":5.89272,"precip":0,"wind_dir":44,"sunrise":"04:44","ghi":540.97,"dhi":92.52,"aqi":68,"lat":40.55,"weather":{"icon":"c02d","code":802,"description":"Scattered clouds"},"datetime":"2021-06-15:08","temp":25.6,"station":"F7959","elev_angle":34.18,"app_temp":25.4}],"count":1}

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'data': [{'rh': 44, 'pod': 'd', 'lon': -4.2, 'pres': 945.1, 'timezone': 'Europe/Madrid', 'ob_time': '2021-06-15 08:00', 'country_code': 'ES', 'clouds': 75, 'ts': 1623744000, 'solar_rad': 378.2, 'state_code': '29', 'city_name': 'Zarzalejo', 'wind_spd': 1, 'wind_cdir_full': 'northeast', 'wind_cdir': 'NE', 'slp': 1018.9, 'vis': 5, 'h_angle': -45, 'sunset': '19:48', 'dni': 808.24, 'dewpt': 12.4, 'snow': 0, 'uv': 5.89272, 'precip': 0, 'wind_dir': 44, 'sunrise': '04:44', 'ghi': 540.97, 'dhi': 92.52, 'aqi': 68, 'lat': 40.55, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'datetime': '2021-06-15:08', 'temp': 25.6, 'station': 'F7959', 'elev_angle': 34.18, 'app_temp': 25.4}], 'count': 1}
# dict

# %%
results.keys()
# Out:
# dict_keys(['data', 'count'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...

# %%
results['data']
# Out:
# [{'app_temp': 22.4,
#   'clouds': 69,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 69,
#   'datetime': '2021-06-15:09',
#   'dewpt': 7.9,
#   'dhi': 103.41,
#   'dni': 868.79,
#   'ghi': 717.09,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.001953125,
#   'pres': 884.145,
#   'rh': 39,
#   'slp': 1018.79,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 564.782,
#   'temp': 23,
#   'timestamp_local': '2021-06-15T11:00:00',
#   'timestamp_utc': '2021-06-15T09:00:00',
#   'ts': 1623747600,
#   'uv': 2.81755,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 78,
#   'wind_gust_spd': 11.5571,
#   'wind_spd': 4.07371},
#  {'app_temp': 26.2,
#   'clouds': 38,
#   'clouds_hi': 2,
#   'clouds_low': 0,
#   'clouds_mid': 39,
#   'datetime': '2021-06-15:12',
#   'dewpt': 6,
#   'dhi': 117.62,
#   'dni': 937.94,
#   'ghi': 1002.88,
#   'ozone': 328,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.112,
#   'rh': 27,
#   'slp': 1016.89,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 974.853,
#   'temp': 26.8,
#   'timestamp_local': '2021-06-15T14:00:00',
#   'timestamp_utc': '2021-06-15T12:00:00',
#   'ts': 1623758400,
#   'uv': 7.58151,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 111,
#   'wind_gust_spd': 11.7118,
#   'wind_spd': 5.50618},
#  {'app_temp': 26.9,
#   'clouds': 76,
#   'clouds_hi': 43,
#   'clouds_low': 0,
#   'clouds_mid': 56,
#   'datetime': '2021-06-15:15',
#   'dewpt': 5.4,
#   'dhi': 107.98,
#   'dni': 892.15,
#   'ghi': 801.62,
#   'ozone': 323,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.048828125,
#   'pres': 881.339,
#   'rh': 24,
#   'slp': 1014.46,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 565.139,
#   'temp': 28.1,
#   'timestamp_local': '2021-06-15T17:00:00',
#   'timestamp_utc': '2021-06-15T15:00:00',
#   'ts': 1623769200,
#   'uv': 3.15302,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 164,
#   'wind_gust_spd': 12.2921,
#   'wind_spd': 4.28592},
#  {'app_temp': 25.8,
#   'clouds': 80,
#   'clouds_hi': 12,
#   'clouds_low': 0,
#   'clouds_mid': 78,
#   'datetime': '2021-06-15:18',
#   'dewpt': 6,
#   'dhi': 68.69,
#   'dni': 647.18,
#   'ghi': 262.69,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.021484375,
#   'pres': 880.719,
#   'rh': 28,
#   'slp': 1013.91,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 170.431,
#   'temp': 26.4,
#   'timestamp_local': '2021-06-15T20:00:00',
#   'timestamp_utc': '2021-06-15T18:00:00',
#   'ts': 1623780000,
#   'uv': 0.813903,
#   'vis': 19.2,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 169,
#   'wind_gust_spd': 10.1157,
#   'wind_spd': 4.75035},
#  {'app_temp': 20.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 8,
#   'clouds_mid': 81,
#   'datetime': '2021-06-15:21',
#   'dewpt': 9.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 319,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.095703125,
#   'pres': 881.045,
#   'rh': 48,
#   'slp': 1015.38,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-06-15T23:00:00',
#   'timestamp_utc': '2021-06-15T21:00:00',
#   'ts': 1623790800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 7.37562,
#   'wind_spd': 2.08412},
#  {'app_temp': 18.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 4,
#   'clouds_mid': 70,
#   'datetime': '2021-06-16:00',
#   'dewpt': 11.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 324.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.33984375,
#   'pres': 881.915,
#   'rh': 67,
#   'slp': 1017.05,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2021-06-16T02:00:00',
#   'timestamp_utc': '2021-06-16T00:00:00',
#   'ts': 1623801600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 90,
#   'wind_gust_spd': 9.4193,
#   'wind_spd': 1.0167},
#  {'app_temp': 17.4,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 24,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:03',
#   'dewpt': 11,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 323,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.068359375,
#   'pres': 879.474,
#   'rh': 67,
#   'slp': 1014.45,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.4,
#   'timestamp_local': '2021-06-16T05:00:00',
#   'timestamp_utc': '2021-06-16T03:00:00',
#   'ts': 1623812400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 11.6762,
#   'wind_spd': 3.34812},
#  {'app_temp': 17,
#   'clouds': 62,
#   'clouds_hi': 0,
#   'clouds_low': 21,
#   'clouds_mid': 54,
#   'datetime': '2021-06-16:06',
#   'dewpt': 10.8,
#   'dhi': 55.42,
#   'dni': 536.17,
#   'ghi': 159.75,
#   'ozone': 321.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.611,
#   'rh': 69,
#   'slp': 1014.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.165,
#   'temp': 17,
#   'timestamp_local': '2021-06-16T08:00:00',
#   'timestamp_utc': '2021-06-16T06:00:00',
#   'ts': 1623823200,
#   'uv': 0.894861,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 11.2242,
#   'wind_spd': 2.06524},
#  {'app_temp': 19.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 30,
#   'clouds_mid': 51,
#   'datetime': '2021-06-16:09',
#   'dewpt': 11.3,
#   'dhi': 103.38,
#   'dni': 868.55,
#   'ghi': 716.68,
#   'ozone': 318.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.427,
#   'rh': 60,
#   'slp': 1014.29,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 179.17,
#   'temp': 19.7,
#   'timestamp_local': '2021-06-16T11:00:00',
#   'timestamp_utc': '2021-06-16T09:00:00',
#   'ts': 1623834000,
#   'uv': 1.67897,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 97,
#   'wind_gust_spd': 11.2175,
#   'wind_spd': 2.20589},
#  {'app_temp': 22.9,
#   'clouds': 56,
#   'clouds_hi': 8,
#   'clouds_low': 30,
#   'clouds_mid': 38,
#   'datetime': '2021-06-16:12',
#   'dewpt': 11.1,
#   'dhi': 117.6,
#   'dni': 937.81,
#   'ghi': 1002.87,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.146484375,
#   'pres': 878.984,
#   'rh': 48,
#   'slp': 1013.18,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 898.122,
#   'temp': 23.2,
#   'timestamp_local': '2021-06-16T14:00:00',
#   'timestamp_utc': '2021-06-16T12:00:00',
#   'ts': 1623844800,
#   'uv': 6.33404,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 13.1602,
#   'wind_spd': 4.33191},
#  {'app_temp': 23.8,
#   'clouds': 82,
#   'clouds_hi': 8,
#   'clouds_low': 64,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:15',
#   'dewpt': 8.7,
#   'dhi': 108,
#   'dni': 892.19,
#   'ghi': 802.25,
#   'ozone': 328.25,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.01171875,
#   'pres': 876.801,
#   'rh': 38,
#   'slp': 1010.28,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 495.815,
#   'temp': 24.3,
#   'timestamp_local': '2021-06-16T17:00:00',
#   'timestamp_utc': '2021-06-16T15:00:00',
#   'ts': 1623855600,
#   'uv': 2.88811,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 194,
#   'wind_gust_spd': 13.1986,
#   'wind_spd': 6.2823},
#  {'app_temp': 22.4,
#   'clouds': 82,
#   'clouds_hi': 19,
#   'clouds_low': 56,
#   'clouds_mid': 69,
#   'datetime': '2021-06-16:18',
#   'dewpt': 9.1,
#   'dhi': 68.79,
#   'dni': 647.94,
#   'ghi': 263.66,
#   'ozone': 326.75,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.06640625,
#   'pres': 876.411,
#   'rh': 42,
#   'slp': 1010.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 162.95,
#   'temp': 22.9,
#   'timestamp_local': '2021-06-16T20:00:00',
#   'timestamp_utc': '2021-06-16T18:00:00',
#   'ts': 1623866400,
#   'uv': 0.793887,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 220,
#   'wind_gust_spd': 11.1933,
#   'wind_spd': 3.96155},
#  {'app_temp': 18.1,
#   'clouds': 94,
#   'clouds_hi': 62,
#   'clouds_low': 56,
#   'clouds_mid': 84,
#   'datetime': '2021-06-16:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.193359375,
#   'pres': 878.112,
#   'rh': 59,
#   'slp': 1012.83,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.6,
#   'timestamp_local': '2021-06-16T23:00:00',
#   'timestamp_utc': '2021-06-16T21:00:00',
#   'ts': 1623877200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 7.01437,
#   'wind_spd': 1.32861},
#  {'app_temp': 15.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2021-06-17:00',
#   'dewpt': 10.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.269,
#   'rh': 72,
#   'slp': 1012.48,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 15.8,
#   'timestamp_local': '2021-06-17T02:00:00',
#   'timestamp_utc': '2021-06-17T00:00:00',
#   'ts': 1623888000,
#   'uv': 0,
#   'vis': 10.008,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 327,
#   'wind_gust_spd': 6.08424,
#   'wind_spd': 1.71289},
#  {'app_temp': 14.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 27,
#   'clouds_mid': 2,
#   'datetime': '2021-06-17:03',
#   'dewpt': 10.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 330.75,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.7,
#   'rh': 78,
#   'slp': 1011.99,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.8,
#   'timestamp_local': '2021-06-17T05:00:00',
#   'timestamp_utc': '2021-06-17T03:00:00',
#   'ts': 1623898800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 2,
#   'wind_gust_spd': 5.55667,
#   'wind_spd': 1.72096},
#  {'app_temp': 15.5,
#   'clouds': 88,
#   'clouds_hi': 67,
#   'clouds_low': 37,
#   'clouds_mid': 45,
#   'datetime': '2021-06-17:06',
#   'dewpt': 11.7,
#   'dhi': 55.36,
#   'dni': 535.63,
#   'ghi': 159.4,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.228,
#   'rh': 80,
#   'slp': 1011.42,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 81.9911,
#   'temp': 15.5,
#   'timestamp_local': '2021-06-17T08:00:00',
#   'timestamp_utc': '2021-06-17T06:00:00',
#   'ts': 1623909600,
#   'uv': 0.608304,
#   'vis': 10.728,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 4.37833,
#   'wind_spd': 1.08316},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 72,
#   'clouds_mid': 30,
#   'datetime': '2021-06-17:09',
#   'dewpt': 13.5,
#   'dhi': 103.34,
#   'dni': 868.31,
#   'ghi': 716.21,
#   'ozone': 339.25,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.75,
#   'pres': 876.576,
#   'rh': 80,
#   'slp': 1011.65,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.08,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T11:00:00',
#   'timestamp_utc': '2021-06-17T09:00:00',
#   'ts': 1623920400,
#   'uv': 1.66392,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 137,
#   'wind_gust_spd': 6.34957,
#   'wind_spd': 1.5818},
#  {'app_temp': 17.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 71,
#   'clouds_mid': 33,
#   'datetime': '2021-06-17:12',
#   'dewpt': 14.6,
#   'dhi': 117.59,
#   'dni': 937.68,
#   'ghi': 1002.82,
#   'ozone': 334.75,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.89453125,
#   'pres': 876.039,
#   'rh': 87,
#   'slp': 1011.09,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 190.536,
#   'temp': 17.1,
#   'timestamp_local': '2021-06-17T14:00:00',
#   'timestamp_utc': '2021-06-17T12:00:00',
#   'ts': 1623931200,
#   'uv': 3.18526,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 116,
#   'wind_gust_spd': 5.97595,
#   'wind_spd': 1.59535},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 73,
#   'clouds_mid': 18,
#   'datetime': '2021-06-17:15',
#   'dewpt': 14.8,
#   'dhi': 108.02,
#   'dni': 892.23,
#   'ghi': 802.82,
#   'ozone': 333,
#   'pod': 'd',
#   'pop': 30,
#   'precip': 0.4140625,
#   'pres': 874.932,
#   'rh': 87,
#   'slp': 1009.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 152.536,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T17:00:00',
#   'timestamp_utc': '2021-06-17T15:00:00',
#   'ts': 1623942000,
#   'uv': 2.05182,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 9.99384,
#   'wind_spd': 1.89453},
#  {'app_temp': 16,
#   'clouds': 79,
#   'clouds_hi': 14,
#   'clouds_low': 73,
#   'clouds_mid': 16,
#   'datetime': '2021-06-17:18',
#   'dewpt': 13.9,
#   'dhi': 68.88,
#   'dni': 648.64,
#   'ghi': 264.57,
#   'ozone': 338.75,
#   'pod': 'd',
#   'pop': 65,
#   'precip': 1.90234375,
#   'pres': 875.149,
#   'rh': 89,
#   'slp': 1010.34,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 168.418,
#   'temp': 16,
#   'timestamp_local': '2021-06-17T20:00:00',
#   'timestamp_utc': '2021-06-17T18:00:00',
#   'ts': 1623952800,
#   'uv': 0.821966,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 55,
#   'wind_gust_spd': 11.0891,
#   'wind_spd': 0.200486},
#  {'app_temp': 14.9,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 49,
#   'clouds_mid': 55,
#   'datetime': '2021-06-17:21',
#   'dewpt': 13.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 344.5,
#   'pod': 'n',
#   'pop': 55,
#   'precip': 1.25390625,
#   'pres': 876.497,
#   'rh': 91,
#   'slp': 1012.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.9,
#   'timestamp_local': '2021-06-17T23:00:00',
#   'timestamp_utc': '2021-06-17T21:00:00',
#   'ts': 1623963600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 33,
#   'wind_gust_spd': 6.10028,
#   'wind_spd': 0.601711},
#  {'app_temp': 13.1,
#   'clouds': 12,
#   'clouds_hi': 2,
#   'clouds_low': 4,
#   'clouds_mid': 5,
#   'datetime': '2021-06-18:00',
#   'dewpt': 11.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.513,
#   'rh': 89,
#   'slp': 1012.39,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.1,
#   'timestamp_local': '2021-06-18T02:00:00',
#   'timestamp_utc': '2021-06-18T00:00:00',
#   'ts': 1623974400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 352,
#   'wind_gust_spd': 4.04717,
#   'wind_spd': 0.758533},
#  {'app_temp': 12,
#   'clouds': 50,
#   'clouds_hi': 1,
#   'clouds_low': 50,
#   'clouds_mid': 2,
#   'datetime': '2021-06-18:03',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.03125,
#   'pres': 876.44,
#   'rh': 92,
#   'slp': 1012.57,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T05:00:00',
#   'timestamp_utc': '2021-06-18T03:00:00',
#   'ts': 1623985200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 345,
#   'wind_gust_spd': 6.70735,
#   'wind_spd': 0.87161},
#  {'app_temp': 12,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 78,
#   'clouds_mid': 30,
#   'datetime': '2021-06-18:06',
#   'dewpt': 10.7,
#   'dhi': 55.29,
#   'dni': 535,
#   'ghi': 158.97,
#   'ozone': 343.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.36,
#   'rh': 93,
#   'slp': 1013.68,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 66.33,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T08:00:00',
#   'timestamp_utc': '2021-06-18T06:00:00',
#   'ts': 1623996000,
#   'uv': 0.593585,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 7.49278,
#   'wind_spd': 0.468219},
#  {'app_temp': 19.7,
#   'clouds': 90,
#   'clouds_hi': 90,
#   'clouds_low': 46,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:09',
#   'dewpt': 8.1,
#   'dhi': 103.3,
#   'dni': 868.06,
#   'ghi': 715.69,
#   'ozone': 345,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 45,
#   'slp': 1012.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 344.066,
#   'temp': 20.5,
#   'timestamp_local': '2021-06-18T11:00:00',
#   'timestamp_utc': '2021-06-18T09:00:00',
#   'ts': 1624006800,
#   'uv': 2.0374,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 138,
#   'wind_gust_spd': 5.41016,
#   'wind_spd': 3.7763},
#  {'app_temp': 22.4,
#   'clouds': 24,
#   'clouds_hi': 2,
#   'clouds_low': 24,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:12',
#   'dewpt': 8.8,
#   'dhi': 117.58,
#   'dni': 937.55,
#   'ghi': 1002.73,
#   'ozone': 344.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 40,
#   'slp': 1012,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 997.187,
#   'temp': 23,
#   'timestamp_local': '2021-06-18T14:00:00',
#   'timestamp_utc': '2021-06-18T12:00:00',
#   'ts': 1624017600,
#   'uv': 8.58676,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 147,
#   'wind_gust_spd': 6.69922,
#   'wind_spd': 4.54761},
#  {'app_temp': 23.5,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 63,
#   'clouds_mid': 32,
#   'datetime': '2021-06-18:15',
#   'dewpt': 7.5,
#   'dhi': 108.04,
#   'dni': 892.26,
#   'ghi': 803.36,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905,
#   'rh': 34,
#   'slp': 1009.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 200.84,
#   'temp': 24.2,
#   'timestamp_local': '2021-06-18T17:00:00',
#   'timestamp_utc': '2021-06-18T15:00:00',
#   'ts': 1624028400,
#   'uv': 2.04829,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 5.91797,
#   'wind_spd': 2.26834},
#  {'app_temp': 22.7,
#   'clouds': 64,
#   'clouds_hi': 57,
#   'clouds_low': 18,
#   'clouds_mid': 19,
#   'datetime': '2021-06-18:18',
#   'dewpt': 8.5,
#   'dhi': 68.97,
#   'dni': 649.29,
#   'ghi': 265.41,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 904.5,
#   'rh': 38,
#   'slp': 1008.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 220.884,
#   'temp': 23.3,
#   'timestamp_local': '2021-06-18T20:00:00',
#   'timestamp_utc': '2021-06-18T18:00:00',
#   'ts': 1624039200,
#   'uv': 0.994731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'WSW',
#   'wind_cdir_full': 'west-southwest',
#   'wind_dir': 239,
#   'wind_gust_spd': 4.63281,
#   'wind_spd': 2.69643},
#  {'app_temp': 18.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 6,
#   'clouds_mid': 79,
#   'datetime': '2021-06-18:21',
#   'dewpt': 7.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 340.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905.5,
#   'rh': 50,
#   'slp': 1010.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2021-06-18T23:00:00',
#   'timestamp_utc': '2021-06-18T21:00:00',
#   'ts': 1624050000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 351,
#   'wind_gust_spd': 2.12695,
#   'wind_spd': 2.41283},
#  {'app_temp': 16.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 99,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:00',
#   'dewpt': 10.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 337.75,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 905.5,
#   'rh': 68,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.1,
#   'timestamp_local': '2021-06-19T02:00:00',
#   'timestamp_utc': '2021-06-19T00:00:00',
#   'ts': 1624060800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 338,
#   'wind_gust_spd': 0.812988,
#   'wind_spd': 0.61213},
#  {'app_temp': 13.4,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:03',
#   'dewpt': 12.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 333.25,
#   'pod': 'n',
#   'pop': 90,
#   'precip': 7.4375,
#   'pres': 905,
#   'rh': 97,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.4,
#   'timestamp_local': '2021-06-19T05:00:00',
#   'timestamp_utc': '2021-06-19T03:00:00',
#   'ts': 1624071600,
#   'uv': 0,
#   'vis': 1.0125,
#   'weather': {'code': 502, 'description': 'Heavy rain', 'icon': 'r03n'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 7.69922,
#   'wind_spd': 4.79758},
#  {'app_temp': 11.7,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:06',
#   'dewpt': 9.4,
#   'dhi': 55.21,
#   'dni': 534.26,
#   'ghi': 158.47,
#   'ozone': 342.75,
#   'pod': 'd',
#   'pop': 40,
#   'precip': 0.6875,
#   'pres': 908,
#   'rh': 86,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 30.1093,
#   'temp': 11.7,
#   'timestamp_local': '2021-06-19T08:00:00',
#   'timestamp_utc': '2021-06-19T06:00:00',
#   'ts': 1624082400,
#   'uv': 0.472565,
#   'vis': 5.4,
#   'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 199,
#   'wind_gust_spd': 5.59766,
#   'wind_spd': 2.69708},
#  {'app_temp': 11.4,
#   'clouds': 100,
#   'clouds_hi': 14,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:09',
#   'dewpt': 10.3,
#   'dhi': 103.26,
#   'dni': 867.79,
#   'ghi': 715.12,
#   'ozone': 350.75,
#   'pod': 'd',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 907.5,
#   'rh': 93,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 71.512,
#   'temp': 11.4,
#   'timestamp_local': '2021-06-19T11:00:00',
#   'timestamp_utc': '2021-06-19T09:00:00',
#   'ts': 1624093200,
#   'uv': 1.65327,
#   'vis': 0.869,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 139,
#   'wind_gust_spd': 4.59766,
#   'wind_spd': 2.73987},
#  {'app_temp': 15.1,
#   'clouds': 92,
#   'clouds_hi': 8,
#   'clouds_low': 92,
#   'clouds_mid': 32,
#   'datetime': '2021-06-19:12',
#   'dewpt': 10,
#   'dhi': 117.56,
#   'dni': 937.42,
#   'ghi': 1002.62,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.0625,
#   'pres': 907.5,
#   'rh': 72,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 434.972,
#   'temp': 15.1,
#   'timestamp_local': '2021-06-19T14:00:00',
#   'timestamp_utc': '2021-06-19T12:00:00',
#   'ts': 1624104000,
#   'uv': 3.7363,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 162,
#   'wind_gust_spd': 3.10547,
#   'wind_spd': 2.37379},
#  {'app_temp': 18,
#   'clouds': 69,
#   'clouds_hi': 55,
#   'clouds_low': 40,
#   'clouds_mid': 56,
#   'datetime': '2021-06-19:15',
#   'dewpt': 9.3,
#   'dhi': 108.05,
#   'dni': 892.29,
#   'ghi': 803.85,
#   'ozone': 352.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 56,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 633.115,
#   'temp': 18,
#   'timestamp_local': '2021-06-19T17:00:00',
#   'timestamp_utc': '2021-06-19T15:00:00',
#   'ts': 1624114800,
#   'uv': 3.45731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 3.32227,
#   'wind_spd': 2.62303},
#  {'app_temp': 18.1,
#   'clouds': 10,
#   'clouds_hi': 10,
#   'clouds_low': 1,
#   'clouds_mid': 6,
#   'datetime': '2021-06-19:18',
#   'dewpt': 8.7,
#   'dhi': 69.05,
#   'dni': 649.88,
#   'ghi': 266.18,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 54,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 266.103,
#   'temp': 18.1,
#   'timestamp_local': '2021-06-19T20:00:00',
#   'timestamp_utc': '2021-06-19T18:00:00',
#   'ts': 1624125600,
#   'uv': 1.657,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 3.30078,
#   'wind_spd': 2.27588},
#  {'app_temp': 14,
#   'clouds': 100,
#   'clouds_hi': 21,
#   'clouds_low': 3,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:21',
#   'dewpt': 9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 347.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 72,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14,
#   'timestamp_local': '2021-06-19T23:00:00',
#   'timestamp_utc': '2021-06-19T21:00:00',
#   'ts': 1624136400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 1.125,
#   'wind_spd': 0.953986},
#  {'app_temp': 12.7,
#   'clouds': 64,
#   'clouds_hi': 64,
#   'clouds_low': 2,
#   'clouds_mid': 5,
#   'datetime': '2021-06-20:00',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 348.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 79,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12.7,
#   'timestamp_local': '2021-06-20T02:00:00',
#   'timestamp_utc': '2021-06-20T00:00:00',
#   'ts': 1624147200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 343,
#   'wind_gust_spd': 0.899902,
#   'wind_spd': 0.956497},
#  {'app_temp': 11.6,
#   'clouds': 72,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 72,
#   'datetime': '2021-06-20:03',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 350.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.3125,
#   'pres': 908.5,
#   'rh': 85,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 11.6,
#   'timestamp_local': '2021-06-20T05:00:00',
#   'timestamp_utc': '2021-06-20T03:00:00',
#   'ts': 1624158000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 6,
#   'wind_gust_spd': 1.10254,
#   'wind_spd': 1.19666},
#  {'app_temp': 13,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 22,
#   'clouds_mid': 88,
#   'datetime': '2021-06-20:06',
#   'dewpt': 10.2,
#   'dhi': 55.12,
#   'dni': 533.43,
#   'ghi': 157.9,
#   'ozone': 352,
#   'pod': 'd',
#   'pop': 50,
#   'precip': 1.0625,
#   'pres': 908,
#   'rh': 83,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 73.4744,
#   'temp': 13,
#   'timestamp_local': '2021-06-20T08:00:00',
#   'timestamp_utc': '2021-06-20T06:00:00',
#   'ts': 1624168800,
#   'uv': 0.586461,
#   'vis': 12.568,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 348,
#   'wind_gust_spd': 0.911621,
#   'wind_spd': 0.800612}]

# %%
len(results['data'])
# Out:
# 40
