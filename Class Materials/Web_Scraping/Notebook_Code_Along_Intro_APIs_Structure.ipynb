# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results
# Out:
# 200
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '17991044540',
#   'type': 'PushEvent',
#   'actor': {'id': 15673138,
#    'login': 'feghalya',
#    'display_login': 'feghalya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/feghalya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15673138?'},
#   'repo': {'id': 24479570,
#    'name': 'tariqdaouda/pyGeno',
#    'url': 'https://api.github.com/repos/tariqdaouda/pyGeno'},
#   'payload': {'push_id': 7937021749,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': 'bfa47b41527c3c02a2b7e302980cc81b1de87942',
#    'before': '5cfb12fa8050cdef5fc83826c3d5c8fd197a1b57',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044506',
#   'type': 'CreateEvent',
#   'actor': {'id': 26779779,
#    'login': 'WalterGnr',
#    'display_login': 'WalterGnr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/WalterGnr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26779779?'},
#   'repo': {'id': 406634191,
#    'name': 'WalterGnr/CIS-106',
#    'url': 'https://api.github.com/repos/WalterGnr/CIS-106'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'This is my repo for my linux course semester spring 2021',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044513',
#   'type': 'IssuesEvent',
#   'actor': {'id': 58094558,
#    'login': 'pddemo',
#    'display_login': 'pddemo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pddemo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58094558?'},
#   'repo': {'id': 277422872,
#    'name': 'pddemo/demo',
#    'url': 'https://api.github.com/repos/pddemo/demo'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/pddemo/demo/issues/620956',
#     'repository_url': 'https://api.github.com/repos/pddemo/demo',
#     'labels_url': 'https://api.github.com/repos/pddemo/demo/issues/620956/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/pddemo/demo/issues/620956/comments',
#     'events_url': 'https://api.github.com/repos/pddemo/demo/issues/620956/events',
#     'html_url': 'https://github.com/pddemo/demo/issues/620956',
#     'id': 996694967,
#     'node_id': 'I_kwDOEIkjGM47aFu3',
#     'number': 620956,
#     'title': 'Unbranded Cotton Soap',
#     'user': {'login': 'pddemo',
#      'id': 58094558,
#      'node_id': 'MDQ6VXNlcjU4MDk0NTU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/58094558?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pddemo',
#      'html_url': 'https://github.com/pddemo',
#      'followers_url': 'https://api.github.com/users/pddemo/followers',
#      'following_url': 'https://api.github.com/users/pddemo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pddemo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pddemo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pddemo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pddemo/orgs',
#      'repos_url': 'https://api.github.com/users/pddemo/repos',
#      'events_url': 'https://api.github.com/users/pddemo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pddemo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-09-15T06:07:45Z',
#     'updated_at': '2021-09-15T06:07:45Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': None,
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044510',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 279757975,
#    'name': 'TooYoungTooSimp/flutter',
#    'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter'},
#   'payload': {'ref': 'dependabot/bundler/dev/ci/docker_linux/json-2.5.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044460',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 16663997,
#    'login': 'swaschkut',
#    'display_login': 'swaschkut',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swaschkut',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16663997?'},
#   'repo': {'id': 362708721,
#    'name': 'PaloAltoNetworks/pan-os-php',
#    'url': 'https://api.github.com/repos/PaloAltoNetworks/pan-os-php'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/PaloAltoNetworks/pan-os-php/releases/49575679',
#     'assets_url': 'https://api.github.com/repos/PaloAltoNetworks/pan-os-php/releases/49575679/assets',
#     'upload_url': 'https://uploads.github.com/repos/PaloAltoNetworks/pan-os-php/releases/49575679/assets{?name,label}',
#     'html_url': 'https://github.com/PaloAltoNetworks/pan-os-php/releases/tag/v2.0.11',
#     'id': 49575679,
#     'author': {'login': 'swaschkut',
#      'id': 16663997,
#      'node_id': 'MDQ6VXNlcjE2NjYzOTk3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/16663997?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/swaschkut',
#      'html_url': 'https://github.com/swaschkut',
#      'followers_url': 'https://api.github.com/users/swaschkut/followers',
#      'following_url': 'https://api.github.com/users/swaschkut/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/swaschkut/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/swaschkut/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/swaschkut/subscriptions',
#      'organizations_url': 'https://api.github.com/users/swaschkut/orgs',
#      'repos_url': 'https://api.github.com/users/swaschkut/repos',
#      'events_url': 'https://api.github.com/users/swaschkut/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/swaschkut/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'node_id': 'RE_kwDOFZ5-8c4C9Hb_',
#     'tag_name': 'v2.0.11',
#     'target_commitish': 'main',
#     'name': 'bugfix - PAN-OS XML API key generation | SecurityRule default behaviour for Service XMLnode',
#     'draft': False,
#     'prerelease': False,
#     'created_at': '2021-09-15T06:04:14Z',
#     'published_at': '2021-09-15T06:07:45Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/PaloAltoNetworks/pan-os-php/tarball/v2.0.11',
#     'zipball_url': 'https://api.github.com/repos/PaloAltoNetworks/pan-os-php/zipball/v2.0.11',
#     'body': "- PAN-OS XML API key generation:\r\n    - for Windows package it is not possible again to generate PaN-OS API key with hiddenPW\r\n    \r\n- SecurityRule with a non existing XMLnode 'service' are now create correct with <service><member>any</member></service>",
#     'short_description_html': "<ul>\n<li>\n<p>PAN-OS XML API key generation:</p>\n<ul>\n<li>for Windows package it is not possible again to generate PaN-OS API key with hiddenPW</li>\n</ul>\n</li>\n<li>\n<p>SecurityRule with a non existing XMLnode 'service' are now create correct …</p>\n</li>\n</ul>",
#     'is_short_description_html_truncated': True}},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z',
#   'org': {'id': 4855743,
#    'login': 'PaloAltoNetworks',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PaloAltoNetworks',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4855743?'}},
#  {'id': '17991044491',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 6648049,
#    'login': 'TooYoungTooSimp',
#    'display_login': 'TooYoungTooSimp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TooYoungTooSimp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?'},
#   'repo': {'id': 279757975,
#    'name': 'TooYoungTooSimp/flutter',
#    'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter'},
#   'payload': {'action': 'opened',
#    'number': 9,
#    'pull_request': {'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9',
#     'id': 734248725,
#     'node_id': 'PR_kwDOEKzEl84rw78V',
#     'html_url': 'https://github.com/TooYoungTooSimp/flutter/pull/9',
#     'diff_url': 'https://github.com/TooYoungTooSimp/flutter/pull/9.diff',
#     'patch_url': 'https://github.com/TooYoungTooSimp/flutter/pull/9.patch',
#     'issue_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/9',
#     'number': 9,
#     'state': 'open',
#     'locked': False,
#     'title': 'Revert "Bump addressable from 2.7.0 to 2.8.0 in /dev/ci/mac"',
#     'user': {'login': 'TooYoungTooSimp',
#      'id': 6648049,
#      'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TooYoungTooSimp',
#      'html_url': 'https://github.com/TooYoungTooSimp',
#      'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#      'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#      'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#      'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Reverts TooYoungTooSimp/flutter#2',
#     'created_at': '2021-09-15T06:07:45Z',
#     'updated_at': '2021-09-15T06:07:45Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9/commits',
#     'review_comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9/comments',
#     'review_comment_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/9/comments',
#     'statuses_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/f13b90cc79e92c8a4b600b358646238de352f629',
#     'head': {'label': 'TooYoungTooSimp:revert-2-dependabot/bundler/dev/ci/mac/addressable-2.8.0',
#      'ref': 'revert-2-dependabot/bundler/dev/ci/mac/addressable-2.8.0',
#      'sha': 'f13b90cc79e92c8a4b600b358646238de352f629',
#      'user': {'login': 'TooYoungTooSimp',
#       'id': 6648049,
#       'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TooYoungTooSimp',
#       'html_url': 'https://github.com/TooYoungTooSimp',
#       'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#       'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#       'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#       'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 279757975,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzk3NTc5NzU=',
#       'name': 'flutter',
#       'full_name': 'TooYoungTooSimp/flutter',
#       'private': False,
#       'owner': {'login': 'TooYoungTooSimp',
#        'id': 6648049,
#        'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TooYoungTooSimp',
#        'html_url': 'https://github.com/TooYoungTooSimp',
#        'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#        'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#        'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#        'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'description': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter',
#       'forks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/forks',
#       'keys_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/teams',
#       'hooks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/events',
#       'assignees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/tags',
#       'blobs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/languages',
#       'stargazers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscription',
#       'commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/merges',
#       'archive_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/downloads',
#       'issues_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/deployments',
#       'created_at': '2020-07-15T03:55:51Z',
#       'updated_at': '2021-09-15T06:06:47Z',
#       'pushed_at': '2021-09-15T06:07:44Z',
#       'git_url': 'git://github.com/TooYoungTooSimp/flutter.git',
#       'ssh_url': 'git@github.com:TooYoungTooSimp/flutter.git',
#       'clone_url': 'https://github.com/TooYoungTooSimp/flutter.git',
#       'svn_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'homepage': 'https://flutter.dev',
#       'size': 107291,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Dart',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'TooYoungTooSimp:master',
#      'ref': 'master',
#      'sha': '8e531f503faec54149345bf856d72cd1e0357438',
#      'user': {'login': 'TooYoungTooSimp',
#       'id': 6648049,
#       'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TooYoungTooSimp',
#       'html_url': 'https://github.com/TooYoungTooSimp',
#       'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#       'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#       'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#       'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 279757975,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzk3NTc5NzU=',
#       'name': 'flutter',
#       'full_name': 'TooYoungTooSimp/flutter',
#       'private': False,
#       'owner': {'login': 'TooYoungTooSimp',
#        'id': 6648049,
#        'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TooYoungTooSimp',
#        'html_url': 'https://github.com/TooYoungTooSimp',
#        'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#        'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#        'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#        'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'description': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter',
#       'forks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/forks',
#       'keys_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/teams',
#       'hooks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/events',
#       'assignees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/tags',
#       'blobs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/languages',
#       'stargazers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscription',
#       'commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/merges',
#       'archive_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/downloads',
#       'issues_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/deployments',
#       'created_at': '2020-07-15T03:55:51Z',
#       'updated_at': '2021-09-15T06:06:47Z',
#       'pushed_at': '2021-09-15T06:07:44Z',
#       'git_url': 'git://github.com/TooYoungTooSimp/flutter.git',
#       'ssh_url': 'git@github.com:TooYoungTooSimp/flutter.git',
#       'clone_url': 'https://github.com/TooYoungTooSimp/flutter.git',
#       'svn_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'homepage': 'https://flutter.dev',
#       'size': 107291,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Dart',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9'},
#      'html': {'href': 'https://github.com/TooYoungTooSimp/flutter/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/f13b90cc79e92c8a4b600b358646238de352f629'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044485',
#   'type': 'PushEvent',
#   'actor': {'id': 524596,
#    'login': 'Varriount',
#    'display_login': 'Varriount',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Varriount',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/524596?'},
#   'repo': {'id': 378265592,
#    'name': 'Varriount/Yoyo',
#    'url': 'https://api.github.com/repos/Varriount/Yoyo'},
#   'payload': {'push_id': 7937021727,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/@',
#    'head': '4530c575af6e749875ca12aeaba574d1c8ac21e4',
#    'before': '4530c575af6e749875ca12aeaba574d1c8ac21e4',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044484',
#   'type': 'PushEvent',
#   'actor': {'id': 83797931,
#    'login': 'dawang1110',
#    'display_login': 'dawang1110',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dawang1110',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83797931?'},
#   'repo': {'id': 405557599,
#    'name': 'dawang1110/QX',
#    'url': 'https://api.github.com/repos/dawang1110/QX'},
#   'payload': {'push_id': 7937021726,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e74b8757b5833f07ec0f5c2c7f8f6db6c7bc4162',
#    'before': '21dbad26bbfca15568f7a1955ce7fe94831d1137',
#    'commits': [{'sha': 'e74b8757b5833f07ec0f5c2c7f8f6db6c7bc4162',
#      'author': {'email': '83797931+dawang1110@users.noreply.github.com',
#       'name': 'dawang1110'},
#      'message': 'Update read1.js',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dawang1110/QX/commits/e74b8757b5833f07ec0f5c2c7f8f6db6c7bc4162'}]},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044464',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 400562702,
#    'name': 'aleee133/vscode',
#    'url': 'https://api.github.com/repos/aleee133/vscode'},
#   'payload': {'push_id': 7937021695,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '129e62c989f1c0583a1115080f4a668c236f8b91',
#    'before': '0c83ca1ced83259971d80890d93abbe19cbfc992',
#    'commits': [{'sha': '129e62c989f1c0583a1115080f4a668c236f8b91',
#      'author': {'email': 'benjpas@microsoft.com', 'name': 'Benjamin Pasero'},
#      'message': 'storage - do not fail state access for extensions (#132777) (#133071)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aleee133/vscode/commits/129e62c989f1c0583a1115080f4a668c236f8b91'}]},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044487',
#   'type': 'PushEvent',
#   'actor': {'id': 26252963,
#    'login': 'binmishr',
#    'display_login': 'binmishr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/binmishr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26252963?'},
#   'repo': {'id': 406631593,
#    'name': 'binmishr/-tidycovid19-New-data-and-documentation',
#    'url': 'https://api.github.com/repos/binmishr/-tidycovid19-New-data-and-documentation'},
#   'payload': {'push_id': 7937021731,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ebf84f7ac14840f753d7d75ebeab0cb494129276',
#    'before': 'd1706f9f95db9e9bf9df733f19cb5ceaa6c0b8e3',
#    'commits': [{'sha': 'ebf84f7ac14840f753d7d75ebeab0cb494129276',
#      'author': {'email': 'mishra.binayaka.18005@gmail.com',
#       'name': 'BINAYAKA MISHRA'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/binmishr/-tidycovid19-New-data-and-documentation/commits/ebf84f7ac14840f753d7d75ebeab0cb494129276'}]},
#   'public': True,
#   'created_at': '2021-09-15T06:07:45Z'},
#  {'id': '17991044490',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 21101779,
#    'login': 'dhananjaymayane',
#    'display_login': 'dhananjaymayane',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dhananjaymayane',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21101779?'},
#   'repo': {'id': 385818786,
#    'name': 'wpeka/surveyfunnel-lite',
#    'url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite'},
#   'payload': {'action': 'closed',
#    'number': 126,
#    'pull_request': {'url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls/126',
#     'id': 734248645,
#     'node_id': 'PR_kwDOFv8gos4rw77F',
#     'html_url': 'https://github.com/wpeka/surveyfunnel-lite/pull/126',
#     'diff_url': 'https://github.com/wpeka/surveyfunnel-lite/pull/126.diff',
#     'patch_url': 'https://github.com/wpeka/surveyfunnel-lite/pull/126.patch',
#     'issue_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/126',
#     'number': 126,
#     'state': 'closed',
#     'locked': False,
#     'title': 'updated readme',
#     'user': {'login': 'dhananjaymayane',
#      'id': 21101779,
#      'node_id': 'MDQ6VXNlcjIxMTAxNzc5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/21101779?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dhananjaymayane',
#      'html_url': 'https://github.com/dhananjaymayane',
#      'followers_url': 'https://api.github.com/users/dhananjaymayane/followers',
#      'following_url': 'https://api.github.com/users/dhananjaymayane/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dhananjaymayane/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dhananjaymayane/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dhananjaymayane/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dhananjaymayane/orgs',
#      'repos_url': 'https://api.github.com/users/dhananjaymayane/repos',
#      'events_url': 'https://api.github.com/users/dhananjaymayane/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dhananjaymayane/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2021-09-15T06:07:37Z',
#     'updated_at': '2021-09-15T06:07:45Z',
#     'closed_at': '2021-09-15T06:07:45Z',
#     'merged_at': '2021-09-15T06:07:45Z',
#     'merge_commit_sha': '7b8eeca1d82806d3e977906f106344798311e765',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls/126/commits',
#     'review_comments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls/126/comments',
#     'review_comment_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/126/comments',
#     'statuses_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/statuses/08fb4277ba5b87be9f0694d92086280785020e0f',
#     'head': {'label': 'wpeka:master',
#      'ref': 'master',
#      'sha': '08fb4277ba5b87be9f0694d92086280785020e0f',
#      'user': {'login': 'wpeka',
#       'id': 79441688,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5NDQxNjg4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/79441688?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wpeka',
#       'html_url': 'https://github.com/wpeka',
#       'followers_url': 'https://api.github.com/users/wpeka/followers',
#       'following_url': 'https://api.github.com/users/wpeka/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wpeka/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wpeka/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wpeka/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wpeka/orgs',
#       'repos_url': 'https://api.github.com/users/wpeka/repos',
#       'events_url': 'https://api.github.com/users/wpeka/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wpeka/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 385818786,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzODU4MTg3ODY=',
#       'name': 'surveyfunnel-lite',
#       'full_name': 'wpeka/surveyfunnel-lite',
#       'private': False,
#       'owner': {'login': 'wpeka',
#        'id': 79441688,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5NDQxNjg4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/79441688?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wpeka',
#        'html_url': 'https://github.com/wpeka',
#        'followers_url': 'https://api.github.com/users/wpeka/followers',
#        'following_url': 'https://api.github.com/users/wpeka/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wpeka/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wpeka/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wpeka/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wpeka/orgs',
#        'repos_url': 'https://api.github.com/users/wpeka/repos',
#        'events_url': 'https://api.github.com/users/wpeka/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wpeka/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wpeka/surveyfunnel-lite',
#       'description': 'WP Survey Funnel',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite',
#       'forks_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/forks',
#       'keys_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/teams',
#       'hooks_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/events',
#       'assignees_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/tags',
#       'blobs_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/languages',
#       'stargazers_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/subscription',
#       'commits_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/merges',
#       'archive_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/downloads',
#       'issues_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/deployments',
#       'created_at': '2021-07-14T05:00:34Z',
#       'updated_at': '2021-09-15T06:05:50Z',
#       'pushed_at': '2021-09-15T06:07:45Z',
#       'git_url': 'git://github.com/wpeka/surveyfunnel-lite.git',
#       'ssh_url': 'git@github.com:wpeka/surveyfunnel-lite.git',
#       'clone_url': 'https://github.com/wpeka/surveyfunnel-lite.git',
#       'svn_url': 'https://github.com/wpeka/surveyfunnel-lite',
#       'homepage': None,
#       'size': 1881,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-2.0',
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'allow_forking': True,
#       'forks': 4,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'wpeka:surveytypes-scoring',
#      'ref': 'surveytypes-scoring',
#      'sha': '28b436a00060864f946451a566824b4d06a64d8d',
#      'user': {'login': 'wpeka',
#       'id': 79441688,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5NDQxNjg4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/79441688?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wpeka',
#       'html_url': 'https://github.com/wpeka',
#       'followers_url': 'https://api.github.com/users/wpeka/followers',
#       'following_url': 'https://api.github.com/users/wpeka/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wpeka/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wpeka/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wpeka/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wpeka/orgs',
#       'repos_url': 'https://api.github.com/users/wpeka/repos',
#       'events_url': 'https://api.github.com/users/wpeka/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wpeka/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 385818786,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzODU4MTg3ODY=',
#       'name': 'surveyfunnel-lite',
#       'full_name': 'wpeka/surveyfunnel-lite',
#       'private': False,
#       'owner': {'login': 'wpeka',
#        'id': 79441688,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjc5NDQxNjg4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/79441688?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wpeka',
#        'html_url': 'https://github.com/wpeka',
#        'followers_url': 'https://api.github.com/users/wpeka/followers',
#        'following_url': 'https://api.github.com/users/wpeka/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wpeka/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wpeka/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wpeka/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wpeka/orgs',
#        'repos_url': 'https://api.github.com/users/wpeka/repos',
#        'events_url': 'https://api.github.com/users/wpeka/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wpeka/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wpeka/surveyfunnel-lite',
#       'description': 'WP Survey Funnel',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite',
#       'forks_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/forks',
#       'keys_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/teams',
#       'hooks_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/events',
#       'assignees_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/tags',
#       'blobs_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/languages',
#       'stargazers_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/subscription',
#       'commits_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/merges',
#       'archive_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/downloads',
#       'issues_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wpeka/surveyfunnel-lite/deployments',
#       'created_at': '2021-07-14T05:00:34Z',
#       'updated_at': '2021-09-15T06:05:50Z',
#       'pushed_at': '2021-09-15T06:07:45Z',
#       'git_url': 'git://github.com/wpeka/surveyfunnel-lite.git',
#       'ssh_url': 'git@github.com:wpeka/surveyfunnel-lite.git',
#       'clone_url': 'https://github.com/wpeka/surveyfunnel-lite.git',
#       'svn_url': 'https://github.com/wpeka/surveyfunnel-lite',
#       'homepage': None,
#       'size': 1881,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'gpl-2.0',
# ...
#      'sha': '6e509ed15958d557f328efb9d31e9263cd334845',
#      'user': {'login': 'TooYoungTooSimp',
#       'id': 6648049,
#       'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TooYoungTooSimp',
#       'html_url': 'https://github.com/TooYoungTooSimp',
#       'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#       'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#       'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#       'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 279757975,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzk3NTc5NzU=',
#       'name': 'flutter',
#       'full_name': 'TooYoungTooSimp/flutter',
#       'private': False,
#       'owner': {'login': 'TooYoungTooSimp',
#        'id': 6648049,
#        'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TooYoungTooSimp',
#        'html_url': 'https://github.com/TooYoungTooSimp',
#        'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#        'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#        'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#        'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'description': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter',
#       'forks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/forks',
#       'keys_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/teams',
#       'hooks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/events',
#       'assignees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/tags',
#       'blobs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/languages',
#       'stargazers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscription',
#       'commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/merges',
#       'archive_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/downloads',
#       'issues_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/deployments',
#       'created_at': '2020-07-15T03:55:51Z',
#       'updated_at': '2021-09-15T06:06:47Z',
#       'pushed_at': '2021-09-15T06:07:44Z',
#       'git_url': 'git://github.com/TooYoungTooSimp/flutter.git',
#       'ssh_url': 'git@github.com:TooYoungTooSimp/flutter.git',
#       'clone_url': 'https://github.com/TooYoungTooSimp/flutter.git',
#       'svn_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'homepage': 'https://flutter.dev',
#       'size': 107291,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Dart',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'TooYoungTooSimp:master',
#      'ref': 'master',
#      'sha': '8e531f503faec54149345bf856d72cd1e0357438',
#      'user': {'login': 'TooYoungTooSimp',
#       'id': 6648049,
#       'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/TooYoungTooSimp',
#       'html_url': 'https://github.com/TooYoungTooSimp',
#       'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#       'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#       'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#       'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#       'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 279757975,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzk3NTc5NzU=',
#       'name': 'flutter',
#       'full_name': 'TooYoungTooSimp/flutter',
#       'private': False,
#       'owner': {'login': 'TooYoungTooSimp',
#        'id': 6648049,
#        'node_id': 'MDQ6VXNlcjY2NDgwNDk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6648049?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/TooYoungTooSimp',
#        'html_url': 'https://github.com/TooYoungTooSimp',
#        'followers_url': 'https://api.github.com/users/TooYoungTooSimp/followers',
#        'following_url': 'https://api.github.com/users/TooYoungTooSimp/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/TooYoungTooSimp/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/TooYoungTooSimp/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/TooYoungTooSimp/subscriptions',
#        'organizations_url': 'https://api.github.com/users/TooYoungTooSimp/orgs',
#        'repos_url': 'https://api.github.com/users/TooYoungTooSimp/repos',
#        'events_url': 'https://api.github.com/users/TooYoungTooSimp/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/TooYoungTooSimp/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'description': 'Flutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/TooYoungTooSimp/flutter',
#       'forks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/forks',
#       'keys_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/teams',
#       'hooks_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/hooks',
#       'issue_events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/events',
#       'assignees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/tags',
#       'blobs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/languages',
#       'stargazers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/stargazers',
#       'contributors_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contributors',
#       'subscribers_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscribers',
#       'subscription_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/subscription',
#       'commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/merges',
#       'archive_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/downloads',
#       'issues_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/TooYoungTooSimp/flutter/deployments',
#       'created_at': '2020-07-15T03:55:51Z',
#       'updated_at': '2021-09-15T06:06:47Z',
#       'pushed_at': '2021-09-15T06:07:44Z',
#       'git_url': 'git://github.com/TooYoungTooSimp/flutter.git',
#       'ssh_url': 'git@github.com:TooYoungTooSimp/flutter.git',
#       'clone_url': 'https://github.com/TooYoungTooSimp/flutter.git',
#       'svn_url': 'https://github.com/TooYoungTooSimp/flutter',
#       'homepage': 'https://flutter.dev',
#       'size': 107291,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Dart',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'bsd-3-clause',
#        'name': 'BSD 3-Clause "New" or "Revised" License',
#        'spdx_id': 'BSD-3-Clause',
#        'url': 'https://api.github.com/licenses/bsd-3-clause',
#        'node_id': 'MDc6TGljZW5zZTU='},
#       'allow_forking': True,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/8'},
#      'html': {'href': 'https://github.com/TooYoungTooSimp/flutter/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/TooYoungTooSimp/flutter/statuses/6e509ed15958d557f328efb9d31e9263cd334845'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2021-09-15T06:07:44Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                    type  \
# 0   17991044540               PushEvent
# 1   17991044506             CreateEvent
# 2   17991044513             IssuesEvent
# 3   17991044510             CreateEvent
# 4   17991044460            ReleaseEvent
# 5   17991044491        PullRequestEvent
# 6   17991044485               PushEvent
# 7   17991044484               PushEvent
# 8   17991044464               PushEvent
# 9   17991044487               PushEvent
# 10  17991044490        PullRequestEvent
# 11  17991044454             CreateEvent
# 12  17991044447  PullRequestReviewEvent
# 13  17991044468               PushEvent
# 14  17991044422               PushEvent
# 15  17991044440               PushEvent
# 16  17991044428               PushEvent
# 17  17991044425             CreateEvent
# 18  17991044438               PushEvent
# 19  17991044416             IssuesEvent
# 20  17991044414              WatchEvent
# 21  17991044387               PushEvent
# 22  17991044402               PushEvent
# 23  17991044401      CommitCommentEvent
# 24  17991044381               PushEvent
# 25  17991044376               PushEvent
# 26  17991044373       IssueCommentEvent
# 27  17991044317               PushEvent
# 28  17991044322             CreateEvent
# 29  17991044311        PullRequestEvent
#
#                                                 actor  \
# 0   {'id': 15673138, 'login': 'feghalya', 'display...
# 1   {'id': 26779779, 'login': 'WalterGnr', 'displa...
# 2   {'id': 58094558, 'login': 'pddemo', 'display_l...
# 3   {'id': 49699333, 'login': 'dependabot[bot]', '...
# 4   {'id': 16663997, 'login': 'swaschkut', 'displa...
# 5   {'id': 6648049, 'login': 'TooYoungTooSimp', 'd...
# 6   {'id': 524596, 'login': 'Varriount', 'display_...
# 7   {'id': 83797931, 'login': 'dawang1110', 'displ...
# 8   {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 9   {'id': 26252963, 'login': 'binmishr', 'display...
# 10  {'id': 21101779, 'login': 'dhananjaymayane', '...
# 11  {'id': 49275095, 'login': 'ursabot', 'display_...
# 12  {'id': 1191838, 'login': 'gra-moore', 'display...
# 13  {'id': 41898282, 'login': 'github-actions[bot]...
# 14  {'id': 87577305, 'login': 'dmda-nft', 'display...
# 15  {'id': 325476, 'login': 'xuhdev', 'display_log...
# 16  {'id': 39692281, 'login': 'AliClouddocs', 'dis...
# 17  {'id': 24642875, 'login': 'LZYongcn', 'display...
# 18  {'id': 56963907, 'login': 'Fxizenta', 'display...
# 19  {'id': 9100555, 'login': 'stylefeng', 'display...
# 20  {'id': 1321938, 'login': 'supermarcos', 'displ...
# 21  {'id': 41898282, 'login': 'github-actions[bot]...
# 22  {'id': 90581163, 'login': 'teamfocusme', 'disp...
# 23  {'id': 35613825, 'login': 'vercel[bot]', 'disp...
# 24  {'id': 66055060, 'login': 'HakkaTjakka', 'disp...
# 25  {'id': 31362988, 'login': '007tom', 'display_l...
# 26  {'id': 13981538, 'login': 'adam-urbanczyk', 'd...
# 27  {'id': 2158838, 'login': 'danieljurek', 'displ...
# 28  {'id': 90213129, 'login': 'Asma-O', 'display_l...
# 29  {'id': 49699333, 'login': 'dependabot[bot]', '...
#
#                                                  repo  \
# 0   {'id': 24479570, 'name': 'tariqdaouda/pyGeno',...
# 1   {'id': 406634191, 'name': 'WalterGnr/CIS-106',...
# 2   {'id': 277422872, 'name': 'pddemo/demo', 'url'...
# 3   {'id': 279757975, 'name': 'TooYoungTooSimp/flu...
# 4   {'id': 362708721, 'name': 'PaloAltoNetworks/pa...
# 5   {'id': 279757975, 'name': 'TooYoungTooSimp/flu...
# 6   {'id': 378265592, 'name': 'Varriount/Yoyo', 'u...
# 7   {'id': 405557599, 'name': 'dawang1110/QX', 'ur...
# 8   {'id': 400562702, 'name': 'aleee133/vscode', '...
# 9   {'id': 406631593, 'name': 'binmishr/-tidycovid...
# 10  {'id': 385818786, 'name': 'wpeka/surveyfunnel-...
# 11  {'id': 328697653, 'name': 'ursacomputing/cross...
# 12  {'id': 350433371, 'name': 'mimiro-io/datahub',...
# 13  {'id': 302103151, 'name': 'cfpb/crawl-cfgov', ...
# 14  {'id': 406590178, 'name': 'dmda-nft/solanauts-...
# 15  {'id': 149419235, 'name': 'xuhdev/pytorch', 'u...
# 16  {'id': 202657488, 'name': 'AlibabaCloudDocs/vo...
# 17  {'id': 406633756, 'name': 'LZYongcn/toyOS', 'u...
# 18  {'id': 406380284, 'name': 'scnu-sloth/hsctf-20...
# 19  {'id': 96391112, 'name': 'stylefeng/Guns', 'ur...
# 20  {'id': 247787309, 'name': 'InfectoOne/vue-gant...
# 21  {'id': 384678961, 'name': 'xiao-cold/AutoApiSe...
# 22  {'id': 405817290, 'name': 'teamfocusme/wwwteam...
# 23  {'id': 403837349, 'name': 'hideckies/australop...
# 24  {'id': 404364529, 'name': 'HakkaTjakka/sample-...
# 25  {'id': 292565793, 'name': 'zhyd1997/Eorg-Serve...
# 26  {'id': 42613329, 'name': 'coady/multimethod', ...
# 27  {'id': 2928944, 'name': 'Azure/azure-sdk-for-n...
# 28  {'id': 406634189, 'name': 'Asma-O/CI-CD', 'url...
# 29  {'id': 279757975, 'name': 'TooYoungTooSimp/flu...
#
#                                               payload  public  \
# 0   {'push_id': 7937021749, 'size': 0, 'distinct_s...    True
# 1   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 2   {'action': 'opened', 'issue': {'url': 'https:/...    True
# 3   {'ref': 'dependabot/bundler/dev/ci/docker_linu...    True
# 4   {'action': 'published', 'release': {'url': 'ht...    True
# 5   {'action': 'opened', 'number': 9, 'pull_reques...    True
# 6   {'push_id': 7937021727, 'size': 0, 'distinct_s...    True
# 7   {'push_id': 7937021726, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 7937021695, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 7937021731, 'size': 1, 'distinct_s...    True
# 10  {'action': 'closed', 'number': 126, 'pull_requ...    True
# 11  {'ref': 'nightly-2021-09-15-0-azure-test-r-rhu...    True
# 12  {'action': 'created', 'review': {'id': 7546965...    True
# 13  {'push_id': 7937021435, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 7937021692, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 7937021628, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 7937021675, 'size': 1, 'distinct_s...    True
# 17  {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 18  {'push_id': 7937021665, 'size': 1, 'distinct_s...    True
# 19  {'action': 'closed', 'issue': {'url': 'https:/...    True
# 20                              {'action': 'started'}    True
# 21  {'push_id': 7937021674, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 7937021691, 'size': 1, 'distinct_s...    True
# 23  {'comment': {'url': 'https://api.github.com/re...    True
# 24  {'push_id': 7937021672, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 7937021669, 'size': 1, 'distinct_s...    True
# 26  {'action': 'created', 'issue': {'url': 'https:...    True
# 27  {'push_id': 7937021626, 'size': 1, 'distinct_s...    True
# 28  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 29  {'action': 'opened', 'number': 8, 'pull_reques...    True
#
#               created_at                                                org
# 0   2021-09-15T06:07:45Z                                                NaN
# 1   2021-09-15T06:07:45Z                                                NaN
# 2   2021-09-15T06:07:45Z                                                NaN
# 3   2021-09-15T06:07:45Z                                                NaN
# 4   2021-09-15T06:07:45Z  {'id': 4855743, 'login': 'PaloAltoNetworks', '...
# 5   2021-09-15T06:07:45Z                                                NaN
# 6   2021-09-15T06:07:45Z                                                NaN
# 7   2021-09-15T06:07:45Z                                                NaN
# 8   2021-09-15T06:07:45Z                                                NaN
# 9   2021-09-15T06:07:45Z                                                NaN
# 10  2021-09-15T06:07:45Z  {'id': 79441688, 'login': 'wpeka', 'gravatar_i...
# 11  2021-09-15T06:07:45Z  {'id': 70039053, 'login': 'ursacomputing', 'gr...
# 12  2021-09-15T06:07:45Z  {'id': 67393586, 'login': 'mimiro-io', 'gravat...
# 13  2021-09-15T06:07:45Z  {'id': 1071563, 'login': 'cfpb', 'gravatar_id'...
# 14  2021-09-15T06:07:45Z                                                NaN
# 15  2021-09-15T06:07:45Z                                                NaN
# 16  2021-09-15T06:07:45Z  {'id': 38934544, 'login': 'AlibabaCloudDocs', ...
# 17  2021-09-15T06:07:45Z                                                NaN
# 18  2021-09-15T06:07:45Z  {'id': 58688935, 'login': 'scnu-sloth', 'grava...
# 19  2021-09-15T06:07:45Z                                                NaN
# 20  2021-09-15T06:07:45Z                                                NaN
# 21  2021-09-15T06:07:45Z                                                NaN
# 22  2021-09-15T06:07:45Z                                                NaN
# 23  2021-09-15T06:07:44Z                                                NaN
# 24  2021-09-15T06:07:45Z                                                NaN
# 25  2021-09-15T06:07:45Z  {'id': 63050151, 'login': 'zhyd1997', 'gravata...
# 26  2021-09-15T06:07:45Z                                                NaN
# 27  2021-09-15T06:07:44Z  {'id': 6844498, 'login': 'Azure', 'gravatar_id...
# 28  2021-09-15T06:07:44Z                                                NaN
# 29  2021-09-15T06:07:44Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id  ... payload.pull_request.merged_by.site_admin
# 0   16781608999  ...                                       NaN
# 1   16781608961  ...                                       NaN
# 2   16781609009  ...                                       NaN
# 3   16781608975  ...                                       NaN
# 4   16781608976  ...                                       NaN
# 5   16781608965  ...                                       NaN
# 6   16781608969  ...                                       NaN
# 7   16781608967  ...                                       NaN
# 8   16781608991  ...                                       NaN
# 9   16781608912  ...                                       NaN
# 10  16781608926  ...                                       NaN
# 11  16781608899  ...                                       NaN
# 12  16781608947  ...                                       NaN
# 13  16781608922  ...                                       NaN
# 14  16781608934  ...                                       NaN
# 15  16781608935  ...                                       NaN
# 16  16781608884  ...                                       NaN
# 17  16781608885  ...                                       NaN
# 18  16781608908  ...                                       NaN
# 19  16781608902  ...                                       NaN
# 20  16781608910  ...                                       NaN
# 21  16781608873  ...                                       NaN
# 22  16781608863  ...                                       NaN
# 23  16781608875  ...                                       NaN
# 24  16781608852  ...                                       NaN
# 25  16781608842  ...                                       NaN
# 26  16781608864  ...                                       NaN
# 27  16781608833  ...                                       NaN
# 28  16781608871  ...                                     False
# 29  16781608837  ...                                       NaN
#
# [30 rows x 523 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1631686757,
#  'iss_position': {'latitude': '-17.7053', 'longitude': '2.7178'}}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack Spain
coordinates = {"lat": 41.397730, "lon": 2.190290}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=41.39773&lon=2.19029")

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1631686788,
#   'latitude': 41.39773,
#   'longitude': 2.19029,
#   'passes': 5},
#  'response': [{'duration': 385, 'risetime': 1631728669},
#   {'duration': 645, 'risetime': 1631734306},
#   {'duration': 629, 'risetime': 1631740132},
#   {'duration': 576, 'risetime': 1631746020},
#   {'duration': 611, 'risetime': 1631751870}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1604442746)
# Out:
# datetime.datetime(2020, 11, 3, 23, 32, 26)

# %%
pd.to_datetime(1604442746, unit="s")
# Out:
# Timestamp('2020-11-03 22:32:26')

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1,'/content/drive/MyDrive/Credentials/')
from config import *

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2c5ac21603bb> in <module>
#       9
#      10 headers = {
# ---> 11     'x-rapidapi-key': x_rapidapi_key,
#      12     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      13     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1631658033, 'latitude': 41.39773, 'longitude': 2.19029, 'passes': 5}, 'response': [{'duration': 576, 'risetime': 1631662447}, {'duration': 628, 'risetime': 1631668284}, {'duration': 651, 'risetime': 1631674093}, {'duration': 421, 'risetime': 1631679977}, {'duration': 385, 'risetime': 1631728669}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %%
results['data']
# Out:
# [{'app_temp': 25.4,
#   'aqi': 68,
#   'city_name': 'Zarzalejo',
#   'clouds': 75,
#   'country_code': 'ES',
#   'datetime': '2021-06-15:08',
#   'dewpt': 12.4,
#   'dhi': 92.52,
#   'dni': 808.24,
#   'elev_angle': 34.18,
#   'ghi': 540.97,
#   'h_angle': -45,
#   'lat': 40.55,
#   'lon': -4.2,
#   'ob_time': '2021-06-15 08:00',
#   'pod': 'd',
#   'precip': 0,
#   'pres': 945.1,
#   'rh': 44,
#   'slp': 1018.9,
#   'snow': 0,
#   'solar_rad': 378.2,
#   'state_code': '29',
#   'station': 'F7959',
#   'sunrise': '04:44',
#   'sunset': '19:48',
#   'temp': 25.6,
#   'timezone': 'Europe/Madrid',
#   'ts': 1623744000,
#   'uv': 5.89272,
#   'vis': 5,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 44,
#   'wind_spd': 1}]

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...

# %%
results['data']
# Out:
# [{'app_temp': 22.4,
#   'clouds': 69,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 69,
#   'datetime': '2021-06-15:09',
#   'dewpt': 7.9,
#   'dhi': 103.41,
#   'dni': 868.79,
#   'ghi': 717.09,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.001953125,
#   'pres': 884.145,
#   'rh': 39,
#   'slp': 1018.79,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 564.782,
#   'temp': 23,
#   'timestamp_local': '2021-06-15T11:00:00',
#   'timestamp_utc': '2021-06-15T09:00:00',
#   'ts': 1623747600,
#   'uv': 2.81755,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 78,
#   'wind_gust_spd': 11.5571,
#   'wind_spd': 4.07371},
#  {'app_temp': 26.2,
#   'clouds': 38,
#   'clouds_hi': 2,
#   'clouds_low': 0,
#   'clouds_mid': 39,
#   'datetime': '2021-06-15:12',
#   'dewpt': 6,
#   'dhi': 117.62,
#   'dni': 937.94,
#   'ghi': 1002.88,
#   'ozone': 328,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 883.112,
#   'rh': 27,
#   'slp': 1016.89,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 974.853,
#   'temp': 26.8,
#   'timestamp_local': '2021-06-15T14:00:00',
#   'timestamp_utc': '2021-06-15T12:00:00',
#   'ts': 1623758400,
#   'uv': 7.58151,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 111,
#   'wind_gust_spd': 11.7118,
#   'wind_spd': 5.50618},
#  {'app_temp': 26.9,
#   'clouds': 76,
#   'clouds_hi': 43,
#   'clouds_low': 0,
#   'clouds_mid': 56,
#   'datetime': '2021-06-15:15',
#   'dewpt': 5.4,
#   'dhi': 107.98,
#   'dni': 892.15,
#   'ghi': 801.62,
#   'ozone': 323,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.048828125,
#   'pres': 881.339,
#   'rh': 24,
#   'slp': 1014.46,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 565.139,
#   'temp': 28.1,
#   'timestamp_local': '2021-06-15T17:00:00',
#   'timestamp_utc': '2021-06-15T15:00:00',
#   'ts': 1623769200,
#   'uv': 3.15302,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 164,
#   'wind_gust_spd': 12.2921,
#   'wind_spd': 4.28592},
#  {'app_temp': 25.8,
#   'clouds': 80,
#   'clouds_hi': 12,
#   'clouds_low': 0,
#   'clouds_mid': 78,
#   'datetime': '2021-06-15:18',
#   'dewpt': 6,
#   'dhi': 68.69,
#   'dni': 647.18,
#   'ghi': 262.69,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.021484375,
#   'pres': 880.719,
#   'rh': 28,
#   'slp': 1013.91,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 170.431,
#   'temp': 26.4,
#   'timestamp_local': '2021-06-15T20:00:00',
#   'timestamp_utc': '2021-06-15T18:00:00',
#   'ts': 1623780000,
#   'uv': 0.813903,
#   'vis': 19.2,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 169,
#   'wind_gust_spd': 10.1157,
#   'wind_spd': 4.75035},
#  {'app_temp': 20.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 8,
#   'clouds_mid': 81,
#   'datetime': '2021-06-15:21',
#   'dewpt': 9.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 319,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.095703125,
#   'pres': 881.045,
#   'rh': 48,
#   'slp': 1015.38,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 21.4,
#   'timestamp_local': '2021-06-15T23:00:00',
#   'timestamp_utc': '2021-06-15T21:00:00',
#   'ts': 1623790800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 7.37562,
#   'wind_spd': 2.08412},
#  {'app_temp': 18.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 4,
#   'clouds_mid': 70,
#   'datetime': '2021-06-16:00',
#   'dewpt': 11.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 324.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.33984375,
#   'pres': 881.915,
#   'rh': 67,
#   'slp': 1017.05,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.4,
#   'timestamp_local': '2021-06-16T02:00:00',
#   'timestamp_utc': '2021-06-16T00:00:00',
#   'ts': 1623801600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 90,
#   'wind_gust_spd': 9.4193,
#   'wind_spd': 1.0167},
#  {'app_temp': 17.4,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 24,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:03',
#   'dewpt': 11,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 323,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.068359375,
#   'pres': 879.474,
#   'rh': 67,
#   'slp': 1014.45,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 17.4,
#   'timestamp_local': '2021-06-16T05:00:00',
#   'timestamp_utc': '2021-06-16T03:00:00',
#   'ts': 1623812400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'ENE',
#   'wind_cdir_full': 'east-northeast',
#   'wind_dir': 62,
#   'wind_gust_spd': 11.6762,
#   'wind_spd': 3.34812},
#  {'app_temp': 17,
#   'clouds': 62,
#   'clouds_hi': 0,
#   'clouds_low': 21,
#   'clouds_mid': 54,
#   'datetime': '2021-06-16:06',
#   'dewpt': 10.8,
#   'dhi': 55.42,
#   'dni': 536.17,
#   'ghi': 159.75,
#   'ozone': 321.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.611,
#   'rh': 69,
#   'slp': 1014.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.165,
#   'temp': 17,
#   'timestamp_local': '2021-06-16T08:00:00',
#   'timestamp_utc': '2021-06-16T06:00:00',
#   'ts': 1623823200,
#   'uv': 0.894861,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 48,
#   'wind_gust_spd': 11.2242,
#   'wind_spd': 2.06524},
#  {'app_temp': 19.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 30,
#   'clouds_mid': 51,
#   'datetime': '2021-06-16:09',
#   'dewpt': 11.3,
#   'dhi': 103.38,
#   'dni': 868.55,
#   'ghi': 716.68,
#   'ozone': 318.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 879.427,
#   'rh': 60,
#   'slp': 1014.29,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 179.17,
#   'temp': 19.7,
#   'timestamp_local': '2021-06-16T11:00:00',
#   'timestamp_utc': '2021-06-16T09:00:00',
#   'ts': 1623834000,
#   'uv': 1.67897,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'E',
#   'wind_cdir_full': 'east',
#   'wind_dir': 97,
#   'wind_gust_spd': 11.2175,
#   'wind_spd': 2.20589},
#  {'app_temp': 22.9,
#   'clouds': 56,
#   'clouds_hi': 8,
#   'clouds_low': 30,
#   'clouds_mid': 38,
#   'datetime': '2021-06-16:12',
#   'dewpt': 11.1,
#   'dhi': 117.6,
#   'dni': 937.81,
#   'ghi': 1002.87,
#   'ozone': 320.5,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.146484375,
#   'pres': 878.984,
#   'rh': 48,
#   'slp': 1013.18,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 898.122,
#   'temp': 23.2,
#   'timestamp_local': '2021-06-16T14:00:00',
#   'timestamp_utc': '2021-06-16T12:00:00',
#   'ts': 1623844800,
#   'uv': 6.33404,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 13.1602,
#   'wind_spd': 4.33191},
#  {'app_temp': 23.8,
#   'clouds': 82,
#   'clouds_hi': 8,
#   'clouds_low': 64,
#   'clouds_mid': 63,
#   'datetime': '2021-06-16:15',
#   'dewpt': 8.7,
#   'dhi': 108,
#   'dni': 892.19,
#   'ghi': 802.25,
#   'ozone': 328.25,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.01171875,
#   'pres': 876.801,
#   'rh': 38,
#   'slp': 1010.28,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 495.815,
#   'temp': 24.3,
#   'timestamp_local': '2021-06-16T17:00:00',
#   'timestamp_utc': '2021-06-16T15:00:00',
#   'ts': 1623855600,
#   'uv': 2.88811,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 194,
#   'wind_gust_spd': 13.1986,
#   'wind_spd': 6.2823},
#  {'app_temp': 22.4,
#   'clouds': 82,
#   'clouds_hi': 19,
#   'clouds_low': 56,
#   'clouds_mid': 69,
#   'datetime': '2021-06-16:18',
#   'dewpt': 9.1,
#   'dhi': 68.79,
#   'dni': 647.94,
#   'ghi': 263.66,
#   'ozone': 326.75,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.06640625,
#   'pres': 876.411,
#   'rh': 42,
#   'slp': 1010.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 162.95,
#   'temp': 22.9,
#   'timestamp_local': '2021-06-16T20:00:00',
#   'timestamp_utc': '2021-06-16T18:00:00',
#   'ts': 1623866400,
#   'uv': 0.793887,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SW',
#   'wind_cdir_full': 'southwest',
#   'wind_dir': 220,
#   'wind_gust_spd': 11.1933,
#   'wind_spd': 3.96155},
#  {'app_temp': 18.1,
#   'clouds': 94,
#   'clouds_hi': 62,
#   'clouds_low': 56,
#   'clouds_mid': 84,
#   'datetime': '2021-06-16:21',
#   'dewpt': 10.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.193359375,
#   'pres': 878.112,
#   'rh': 59,
#   'slp': 1012.83,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.6,
#   'timestamp_local': '2021-06-16T23:00:00',
#   'timestamp_utc': '2021-06-16T21:00:00',
#   'ts': 1623877200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 126,
#   'wind_gust_spd': 7.01437,
#   'wind_spd': 1.32861},
#  {'app_temp': 15.8,
#   'clouds': 0,
#   'clouds_hi': 0,
#   'clouds_low': 0,
#   'clouds_mid': 0,
#   'datetime': '2021-06-17:00',
#   'dewpt': 10.5,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 327.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.269,
#   'rh': 72,
#   'slp': 1012.48,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 15.8,
#   'timestamp_local': '2021-06-17T02:00:00',
#   'timestamp_utc': '2021-06-17T00:00:00',
#   'ts': 1623888000,
#   'uv': 0,
#   'vis': 10.008,
#   'weather': {'code': 800, 'description': 'Clear Sky', 'icon': 'c01n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 327,
#   'wind_gust_spd': 6.08424,
#   'wind_spd': 1.71289},
#  {'app_temp': 14.8,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 27,
#   'clouds_mid': 2,
#   'datetime': '2021-06-17:03',
#   'dewpt': 10.6,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 330.75,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.7,
#   'rh': 78,
#   'slp': 1011.99,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.8,
#   'timestamp_local': '2021-06-17T05:00:00',
#   'timestamp_utc': '2021-06-17T03:00:00',
#   'ts': 1623898800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 2,
#   'wind_gust_spd': 5.55667,
#   'wind_spd': 1.72096},
#  {'app_temp': 15.5,
#   'clouds': 88,
#   'clouds_hi': 67,
#   'clouds_low': 37,
#   'clouds_mid': 45,
#   'datetime': '2021-06-17:06',
#   'dewpt': 11.7,
#   'dhi': 55.36,
#   'dni': 535.63,
#   'ghi': 159.4,
#   'ozone': 336,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.228,
#   'rh': 80,
#   'slp': 1011.42,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 81.9911,
#   'temp': 15.5,
#   'timestamp_local': '2021-06-17T08:00:00',
#   'timestamp_utc': '2021-06-17T06:00:00',
#   'ts': 1623909600,
#   'uv': 0.608304,
#   'vis': 10.728,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 5,
#   'wind_gust_spd': 4.37833,
#   'wind_spd': 1.08316},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 72,
#   'clouds_mid': 30,
#   'datetime': '2021-06-17:09',
#   'dewpt': 13.5,
#   'dhi': 103.34,
#   'dni': 868.31,
#   'ghi': 716.21,
#   'ozone': 339.25,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.75,
#   'pres': 876.576,
#   'rh': 80,
#   'slp': 1011.65,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 136.08,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T11:00:00',
#   'timestamp_utc': '2021-06-17T09:00:00',
#   'ts': 1623920400,
#   'uv': 1.66392,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 137,
#   'wind_gust_spd': 6.34957,
#   'wind_spd': 1.5818},
#  {'app_temp': 17.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 71,
#   'clouds_mid': 33,
#   'datetime': '2021-06-17:12',
#   'dewpt': 14.6,
#   'dhi': 117.59,
#   'dni': 937.68,
#   'ghi': 1002.82,
#   'ozone': 334.75,
#   'pod': 'd',
#   'pop': 45,
#   'precip': 0.89453125,
#   'pres': 876.039,
#   'rh': 87,
#   'slp': 1011.09,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 190.536,
#   'temp': 17.1,
#   'timestamp_local': '2021-06-17T14:00:00',
#   'timestamp_utc': '2021-06-17T12:00:00',
#   'ts': 1623931200,
#   'uv': 3.18526,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'ESE',
#   'wind_cdir_full': 'east-southeast',
#   'wind_dir': 116,
#   'wind_gust_spd': 5.97595,
#   'wind_spd': 1.59535},
#  {'app_temp': 17.2,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 73,
#   'clouds_mid': 18,
#   'datetime': '2021-06-17:15',
#   'dewpt': 14.8,
#   'dhi': 108.02,
#   'dni': 892.23,
#   'ghi': 802.82,
#   'ozone': 333,
#   'pod': 'd',
#   'pop': 30,
#   'precip': 0.4140625,
#   'pres': 874.932,
#   'rh': 87,
#   'slp': 1009.84,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 152.536,
#   'temp': 17.2,
#   'timestamp_local': '2021-06-17T17:00:00',
#   'timestamp_utc': '2021-06-17T15:00:00',
#   'ts': 1623942000,
#   'uv': 2.05182,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 9.99384,
#   'wind_spd': 1.89453},
#  {'app_temp': 16,
#   'clouds': 79,
#   'clouds_hi': 14,
#   'clouds_low': 73,
#   'clouds_mid': 16,
#   'datetime': '2021-06-17:18',
#   'dewpt': 13.9,
#   'dhi': 68.88,
#   'dni': 648.64,
#   'ghi': 264.57,
#   'ozone': 338.75,
#   'pod': 'd',
#   'pop': 65,
#   'precip': 1.90234375,
#   'pres': 875.149,
#   'rh': 89,
#   'slp': 1010.34,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 168.418,
#   'temp': 16,
#   'timestamp_local': '2021-06-17T20:00:00',
#   'timestamp_utc': '2021-06-17T18:00:00',
#   'ts': 1623952800,
#   'uv': 0.821966,
#   'vis': 24.128,
#   'weather': {'code': 201,
#    'description': 'Thunderstorm with rain',
#    'icon': 't02d'},
#   'wind_cdir': 'NE',
#   'wind_cdir_full': 'northeast',
#   'wind_dir': 55,
#   'wind_gust_spd': 11.0891,
#   'wind_spd': 0.200486},
#  {'app_temp': 14.9,
#   'clouds': 73,
#   'clouds_hi': 0,
#   'clouds_low': 49,
#   'clouds_mid': 55,
#   'datetime': '2021-06-17:21',
#   'dewpt': 13.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 344.5,
#   'pod': 'n',
#   'pop': 55,
#   'precip': 1.25390625,
#   'pres': 876.497,
#   'rh': 91,
#   'slp': 1012.01,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14.9,
#   'timestamp_local': '2021-06-17T23:00:00',
#   'timestamp_utc': '2021-06-17T21:00:00',
#   'ts': 1623963600,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04n'},
#   'wind_cdir': 'NNE',
#   'wind_cdir_full': 'north-northeast',
#   'wind_dir': 33,
#   'wind_gust_spd': 6.10028,
#   'wind_spd': 0.601711},
#  {'app_temp': 13.1,
#   'clouds': 12,
#   'clouds_hi': 2,
#   'clouds_low': 4,
#   'clouds_mid': 5,
#   'datetime': '2021-06-18:00',
#   'dewpt': 11.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 876.513,
#   'rh': 89,
#   'slp': 1012.39,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.1,
#   'timestamp_local': '2021-06-18T02:00:00',
#   'timestamp_utc': '2021-06-18T00:00:00',
#   'ts': 1623974400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 352,
#   'wind_gust_spd': 4.04717,
#   'wind_spd': 0.758533},
#  {'app_temp': 12,
#   'clouds': 50,
#   'clouds_hi': 1,
#   'clouds_low': 50,
#   'clouds_mid': 2,
#   'datetime': '2021-06-18:03',
#   'dewpt': 10.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 343.25,
#   'pod': 'n',
#   'pop': 15,
#   'precip': 0.03125,
#   'pres': 876.44,
#   'rh': 92,
#   'slp': 1012.57,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T05:00:00',
#   'timestamp_utc': '2021-06-18T03:00:00',
#   'ts': 1623985200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 345,
#   'wind_gust_spd': 6.70735,
#   'wind_spd': 0.87161},
#  {'app_temp': 12,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 78,
#   'clouds_mid': 30,
#   'datetime': '2021-06-18:06',
#   'dewpt': 10.7,
#   'dhi': 55.29,
#   'dni': 535,
#   'ghi': 158.97,
#   'ozone': 343.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 877.36,
#   'rh': 93,
#   'slp': 1013.68,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 66.33,
#   'temp': 12,
#   'timestamp_local': '2021-06-18T08:00:00',
#   'timestamp_utc': '2021-06-18T06:00:00',
#   'ts': 1623996000,
#   'uv': 0.593585,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 7.49278,
#   'wind_spd': 0.468219},
#  {'app_temp': 19.7,
#   'clouds': 90,
#   'clouds_hi': 90,
#   'clouds_low': 46,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:09',
#   'dewpt': 8.1,
#   'dhi': 103.3,
#   'dni': 868.06,
#   'ghi': 715.69,
#   'ozone': 345,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 45,
#   'slp': 1012.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 344.066,
#   'temp': 20.5,
#   'timestamp_local': '2021-06-18T11:00:00',
#   'timestamp_utc': '2021-06-18T09:00:00',
#   'ts': 1624006800,
#   'uv': 2.0374,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 138,
#   'wind_gust_spd': 5.41016,
#   'wind_spd': 3.7763},
#  {'app_temp': 22.4,
#   'clouds': 24,
#   'clouds_hi': 2,
#   'clouds_low': 24,
#   'clouds_mid': 0,
#   'datetime': '2021-06-18:12',
#   'dewpt': 8.8,
#   'dhi': 117.58,
#   'dni': 937.55,
#   'ghi': 1002.73,
#   'ozone': 344.25,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 40,
#   'slp': 1012,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 997.187,
#   'temp': 23,
#   'timestamp_local': '2021-06-18T14:00:00',
#   'timestamp_utc': '2021-06-18T12:00:00',
#   'ts': 1624017600,
#   'uv': 8.58676,
#   'vis': 24.128,
#   'weather': {'code': 802, 'description': 'Scattered clouds', 'icon': 'c02d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 147,
#   'wind_gust_spd': 6.69922,
#   'wind_spd': 4.54761},
#  {'app_temp': 23.5,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 63,
#   'clouds_mid': 32,
#   'datetime': '2021-06-18:15',
#   'dewpt': 7.5,
#   'dhi': 108.04,
#   'dni': 892.26,
#   'ghi': 803.36,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905,
#   'rh': 34,
#   'slp': 1009.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 200.84,
#   'temp': 24.2,
#   'timestamp_local': '2021-06-18T17:00:00',
#   'timestamp_utc': '2021-06-18T15:00:00',
#   'ts': 1624028400,
#   'uv': 2.04829,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 5.91797,
#   'wind_spd': 2.26834},
#  {'app_temp': 22.7,
#   'clouds': 64,
#   'clouds_hi': 57,
#   'clouds_low': 18,
#   'clouds_mid': 19,
#   'datetime': '2021-06-18:18',
#   'dewpt': 8.5,
#   'dhi': 68.97,
#   'dni': 649.29,
#   'ghi': 265.41,
#   'ozone': 343.5,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 904.5,
#   'rh': 38,
#   'slp': 1008.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 220.884,
#   'temp': 23.3,
#   'timestamp_local': '2021-06-18T20:00:00',
#   'timestamp_utc': '2021-06-18T18:00:00',
#   'ts': 1624039200,
#   'uv': 0.994731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'WSW',
#   'wind_cdir_full': 'west-southwest',
#   'wind_dir': 239,
#   'wind_gust_spd': 4.63281,
#   'wind_spd': 2.69643},
#  {'app_temp': 18.3,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 6,
#   'clouds_mid': 79,
#   'datetime': '2021-06-18:21',
#   'dewpt': 7.7,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 340.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 905.5,
#   'rh': 50,
#   'slp': 1010.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 18.3,
#   'timestamp_local': '2021-06-18T23:00:00',
#   'timestamp_utc': '2021-06-18T21:00:00',
#   'ts': 1624050000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 351,
#   'wind_gust_spd': 2.12695,
#   'wind_spd': 2.41283},
#  {'app_temp': 16.1,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 99,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:00',
#   'dewpt': 10.2,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 337.75,
#   'pod': 'n',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 905.5,
#   'rh': 68,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 16.1,
#   'timestamp_local': '2021-06-19T02:00:00',
#   'timestamp_utc': '2021-06-19T00:00:00',
#   'ts': 1624060800,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 338,
#   'wind_gust_spd': 0.812988,
#   'wind_spd': 0.61213},
#  {'app_temp': 13.4,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:03',
#   'dewpt': 12.9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 333.25,
#   'pod': 'n',
#   'pop': 90,
#   'precip': 7.4375,
#   'pres': 905,
#   'rh': 97,
#   'slp': 1011.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 13.4,
#   'timestamp_local': '2021-06-19T05:00:00',
#   'timestamp_utc': '2021-06-19T03:00:00',
#   'ts': 1624071600,
#   'uv': 0,
#   'vis': 1.0125,
#   'weather': {'code': 502, 'description': 'Heavy rain', 'icon': 'r03n'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 208,
#   'wind_gust_spd': 7.69922,
#   'wind_spd': 4.79758},
#  {'app_temp': 11.7,
#   'clouds': 100,
#   'clouds_hi': 100,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:06',
#   'dewpt': 9.4,
#   'dhi': 55.21,
#   'dni': 534.26,
#   'ghi': 158.47,
#   'ozone': 342.75,
#   'pod': 'd',
#   'pop': 40,
#   'precip': 0.6875,
#   'pres': 908,
#   'rh': 86,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 30.1093,
#   'temp': 11.7,
#   'timestamp_local': '2021-06-19T08:00:00',
#   'timestamp_utc': '2021-06-19T06:00:00',
#   'ts': 1624082400,
#   'uv': 0.472565,
#   'vis': 5.4,
#   'weather': {'code': 301, 'description': 'Drizzle', 'icon': 'd02d'},
#   'wind_cdir': 'SSW',
#   'wind_cdir_full': 'south-southwest',
#   'wind_dir': 199,
#   'wind_gust_spd': 5.59766,
#   'wind_spd': 2.69708},
#  {'app_temp': 11.4,
#   'clouds': 100,
#   'clouds_hi': 14,
#   'clouds_low': 100,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:09',
#   'dewpt': 10.3,
#   'dhi': 103.26,
#   'dni': 867.79,
#   'ghi': 715.12,
#   'ozone': 350.75,
#   'pod': 'd',
#   'pop': 10,
#   'precip': 0.125,
#   'pres': 907.5,
#   'rh': 93,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 71.512,
#   'temp': 11.4,
#   'timestamp_local': '2021-06-19T11:00:00',
#   'timestamp_utc': '2021-06-19T09:00:00',
#   'ts': 1624093200,
#   'uv': 1.65327,
#   'vis': 0.869,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 139,
#   'wind_gust_spd': 4.59766,
#   'wind_spd': 2.73987},
#  {'app_temp': 15.1,
#   'clouds': 92,
#   'clouds_hi': 8,
#   'clouds_low': 92,
#   'clouds_mid': 32,
#   'datetime': '2021-06-19:12',
#   'dewpt': 10,
#   'dhi': 117.56,
#   'dni': 937.42,
#   'ghi': 1002.62,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 15,
#   'precip': 0.0625,
#   'pres': 907.5,
#   'rh': 72,
#   'slp': 1014,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 434.972,
#   'temp': 15.1,
#   'timestamp_local': '2021-06-19T14:00:00',
#   'timestamp_utc': '2021-06-19T12:00:00',
#   'ts': 1624104000,
#   'uv': 3.7363,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 162,
#   'wind_gust_spd': 3.10547,
#   'wind_spd': 2.37379},
#  {'app_temp': 18,
#   'clouds': 69,
#   'clouds_hi': 55,
#   'clouds_low': 40,
#   'clouds_mid': 56,
#   'datetime': '2021-06-19:15',
#   'dewpt': 9.3,
#   'dhi': 108.05,
#   'dni': 892.29,
#   'ghi': 803.85,
#   'ozone': 352.75,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 56,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 633.115,
#   'temp': 18,
#   'timestamp_local': '2021-06-19T17:00:00',
#   'timestamp_utc': '2021-06-19T15:00:00',
#   'ts': 1624114800,
#   'uv': 3.45731,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03d'},
#   'wind_cdir': 'SSE',
#   'wind_cdir_full': 'south-southeast',
#   'wind_dir': 160,
#   'wind_gust_spd': 3.32227,
#   'wind_spd': 2.62303},
#  {'app_temp': 18.1,
#   'clouds': 10,
#   'clouds_hi': 10,
#   'clouds_low': 1,
#   'clouds_mid': 6,
#   'datetime': '2021-06-19:18',
#   'dewpt': 8.7,
#   'dhi': 69.05,
#   'dni': 649.88,
#   'ghi': 266.18,
#   'ozone': 351,
#   'pod': 'd',
#   'pop': 0,
#   'precip': 0,
#   'pres': 907,
#   'rh': 54,
#   'slp': 1013,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 266.103,
#   'temp': 18.1,
#   'timestamp_local': '2021-06-19T20:00:00',
#   'timestamp_utc': '2021-06-19T18:00:00',
#   'ts': 1624125600,
#   'uv': 1.657,
#   'vis': 24.128,
#   'weather': {'code': 801, 'description': 'Few clouds', 'icon': 'c02d'},
#   'wind_cdir': 'S',
#   'wind_cdir_full': 'south',
#   'wind_dir': 177,
#   'wind_gust_spd': 3.30078,
#   'wind_spd': 2.27588},
#  {'app_temp': 14,
#   'clouds': 100,
#   'clouds_hi': 21,
#   'clouds_low': 3,
#   'clouds_mid': 100,
#   'datetime': '2021-06-19:21',
#   'dewpt': 9,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 347.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 72,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 14,
#   'timestamp_local': '2021-06-19T23:00:00',
#   'timestamp_utc': '2021-06-19T21:00:00',
#   'ts': 1624136400,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'SE',
#   'wind_cdir_full': 'southeast',
#   'wind_dir': 144,
#   'wind_gust_spd': 1.125,
#   'wind_spd': 0.953986},
#  {'app_temp': 12.7,
#   'clouds': 64,
#   'clouds_hi': 64,
#   'clouds_low': 2,
#   'clouds_mid': 5,
#   'datetime': '2021-06-20:00',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 348.5,
#   'pod': 'n',
#   'pop': 0,
#   'precip': 0,
#   'pres': 908.5,
#   'rh': 79,
#   'slp': 1015,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 12.7,
#   'timestamp_local': '2021-06-20T02:00:00',
#   'timestamp_utc': '2021-06-20T00:00:00',
#   'ts': 1624147200,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 803, 'description': 'Broken clouds', 'icon': 'c03n'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 343,
#   'wind_gust_spd': 0.899902,
#   'wind_spd': 0.956497},
#  {'app_temp': 11.6,
#   'clouds': 72,
#   'clouds_hi': 0,
#   'clouds_low': 2,
#   'clouds_mid': 72,
#   'datetime': '2021-06-20:03',
#   'dewpt': 9.1,
#   'dhi': 0,
#   'dni': 0,
#   'ghi': 0,
#   'ozone': 350.75,
#   'pod': 'n',
#   'pop': 25,
#   'precip': 0.3125,
#   'pres': 908.5,
#   'rh': 85,
#   'slp': 1015.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 0,
#   'temp': 11.6,
#   'timestamp_local': '2021-06-20T05:00:00',
#   'timestamp_utc': '2021-06-20T03:00:00',
#   'ts': 1624158000,
#   'uv': 0,
#   'vis': 24.128,
#   'weather': {'code': 804, 'description': 'Overcast clouds', 'icon': 'c04n'},
#   'wind_cdir': 'N',
#   'wind_cdir_full': 'north',
#   'wind_dir': 6,
#   'wind_gust_spd': 1.10254,
#   'wind_spd': 1.19666},
#  {'app_temp': 13,
#   'clouds': 88,
#   'clouds_hi': 0,
#   'clouds_low': 22,
#   'clouds_mid': 88,
#   'datetime': '2021-06-20:06',
#   'dewpt': 10.2,
#   'dhi': 55.12,
#   'dni': 533.43,
#   'ghi': 157.9,
#   'ozone': 352,
#   'pod': 'd',
#   'pop': 50,
#   'precip': 1.0625,
#   'pres': 908,
#   'rh': 83,
#   'slp': 1014.5,
#   'snow': 0,
#   'snow_depth': 0,
#   'solar_rad': 73.4744,
#   'temp': 13,
#   'timestamp_local': '2021-06-20T08:00:00',
#   'timestamp_utc': '2021-06-20T06:00:00',
#   'ts': 1624168800,
#   'uv': 0.586461,
#   'vis': 12.568,
#   'weather': {'code': 520, 'description': 'Light shower rain', 'icon': 'r04d'},
#   'wind_cdir': 'NNW',
#   'wind_cdir_full': 'north-northwest',
#   'wind_dir': 348,
#   'wind_gust_spd': 0.911621,
#   'wind_spd': 0.800612}]

# %%
len(results['data'])
# Out:
# 40
